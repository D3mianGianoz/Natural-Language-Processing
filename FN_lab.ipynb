# %% [markdown]
# ## FrameNet API in nltk

# %%
import nltk
'''
    nltk.download('all')
o in alternativa
    nltk.download('framenet')
'''
from nltk.corpus import framenet as fn
from nltk.corpus.reader.framenet import PrettyList

from operator import itemgetter
from pprint import pprint

# %% [markdown]
# #### Credits
#
# - Collin F. Baker, Nathan Schneider, Miriam R. L. Petruck, and Michael Ellsworth. Tutorial *Getting the Roles Right: Using FrameNet in NLP* tenuto presso la North American Chapter of the Association for Computational Linguistics - Human Language Technology (NAACL HLT 2015),
#     - http://naacl.org/naacl-hlt-2015/tutorial-framenet.html
# - documentazione NLTK,
#     - https://www.nltk.org/api/nltk.corpus.reader.html

# %% [markdown]
# Documentazione all'URL [https://www.nltk.org/api/nltk.corpus.reader.html](https://www.nltk.org/api/nltk.corpus.reader.html)
#
# - nltk.corpus.reader.framenet module, Corpus reader for the FrameNet 1.7 lexicon and corpus.
#
# #### API Entry Points
# ```
#     frames([nameRegex])
#     frame(exactName)
#     frames_by_lemma(lemmaRegex)
#
#     lus([nameRegex])
#     fes([nameRegex])
#
#     semtypes()
#     propagate_semtypes()
#
#     frame_relations([frame, [frame2,]] [type]) frame_relation_types()
#     fe_relations()
# ```

# %% [markdown]
# ### Pretty{List,Dict}
# ```
#     >>> fn.frames('noise')
#     [<frame ID=801 name=Cause_to_make_noise>, <frame ID=60 name=Motion_noise>, ...]
#     >>> type(fn.frames('noise'))
#     <class 'nltk.corpus.reader.framenet.PrettyList'>
# ```
#
# PrettyList does 2 things:
# - limits the number of elements shown, and suppresses printing of their full details
#     - Otherwise, it is just a list
# - Similarly, PrettyDict suppresses printing of its values' details

# %%
#nltk.download('framenet_v17')
# Out:
# [nltk_data] Downloading package framenet_v17 to
# [nltk_data]     /Users/robertodemaria/nltk_data...
# [nltk_data]   Unzipping corpora/framenet_v17.zip.
# True

# %%
print(fn.frames(r'(?i)medical')) #ricerca di frame usando un'espressione regolare
# Out:
# [<frame ID=239 name=Medical_conditions>, <frame ID=257 name=Medical_instruments>, ...]

# %%
print(fn.frames('Medical_specialties')) #ricerca di frame per nome
# Out:
# [<frame ID=256 name=Medical_specialties>]

# %%
f = fn.frame(256) #ricerca di frame per id
f.name
# Out:
# 'Medical_specialties'

# %%
f.definition #accesso alla definizione del frame
# Out:
# "This frame includes words that name medical specialties and is closely related to the Medical_professionals frame.  The FE Type characterizing a sub-are in a Specialty may also be expressed. 'Ralph practices paediatric oncology.'"

# %%
def print_sep():
    print('\n_________________________________________________________\n\n')

f = fn.frame_by_name('Medical_specialties')
print(f) #accesso alle informazioni principali
print_sep()
print(fn.frame_by_name('Perception'))
print_sep()
print(fn.frame_by_name('Complaining'))
# Out:
# frame (256): Medical_specialties
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Medical_specialties.xml
#
# [definition]
#   This frame includes words that name medical specialties and is
#   closely related to the Medical_professionals frame.  The FE Type
#   characterizing a sub-are in a Specialty may also be expressed.
#   'Ralph practices paediatric oncology.'
#
# [semTypes] 0 semantic types
#
# [frameRelations] 1 frame relations
#   <Parent=Medical_interaction_scenario -- Using -> Child=Medical_specialties>
#
# [lexUnit] 29 lexical units
#   allopathy.n (4601), cardiology.n (4590), chiropractic.n (4598),
#   dentistry.n (4591), dermatology.n (4592), endocrinology.n (4593),
#   epidemiology.n (4594), gastroenterology.n (4595), gynaecology.n
#   (4596), haematology.n (4597), histology.n (4599), homeopathy.n
#   (4600), immunology.n (4605), medicine.n (4622), midwifery.n
#   (4602), neonatology.n (4610), nephrology.n (4611), neurology.n
#   (4612), obstetrics.n (4613), oncology.n (4614), orthopaedics.n
#   (4615), paediatrics.n (4616), podiatry.n (4617), psychoanalysis.n
#   (4604), psychotherapy.n (4603), radiology.n (4618),
#   rheumatology.n (4619), speech therapy.n (4632), therapy.n (4629)
#
#
# [FE] 4 frame elements
#             Core: Specialty (3618)
#       Peripheral: Affliction (9873), Body_system (9872), Type (3619)
#
# [FEcoreSets] 0 frame element core sets
#
#
#
# _________________________________________________________
#
#
# frame (8): Perception
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Perception.xml
#
# [definition]
#   A Perceiver perceives a Phenomenon. The general Perception frame
#   is an inherited background to all frames that have to do with
#   some sentient being responding to changes in the environment,
#   independently of the sensory modalities.  The inheriting frames
#   may specify the modalities (see, hear, taste, smell), or may
#   emphasize the experiences or acts of the perceiver (peek,
#   eavesdrop), or the properties of the perceived phenomena (clank,
#   rattle, thump).
#
# [semTypes] 1 semantic types
#   Non-Lexical Frame(16)
#
# [frameRelations] 9 frame relations
#   <Parent=Perception -- Inheritance -> Child=Becoming_aware>
#   <Parent=Perception -- Inheritance -> Child=Give_impression>
#   <Parent=Perception -- Inheritance -> Child=Perception_active>
#   <Parent=Perception -- Inheritance -> Child=Perception_experience>
#   <Parent=Perception -- Inheritance -> Child=Sensation>
#   <Parent=Becoming_visible -- Using -> Child=Perception>
#   <Parent=Perception -- Using -> Child=Location_of_light>
#   <Parent=Perception -- Using -> Child=Make_noise>
#   <Parent=Perception -- Using -> Child=Sounds>
#
# [lexUnit] 0 lexical units
#
#
#
# [FE] 3 frame elements
#             Core: Perceiver (31), Phenomenon (1546)
#   Extra-Thematic: Sought_phenomenon (32)
#
# [FEcoreSets] 0 frame element core sets
#
#
#
# _________________________________________________________
#
#
# frame (1621): Complaining
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Complaining.xml
#
# [definition]
#   A Complainer communicates their negative emotional reaction to
#   some state of affairs in a Complaint to an Addressee. As an
#   alternative to the specific Complaint, the Topic of the speaker's
#   Complaint may be specified. Likewise, instead of (or in addition
#   to) the Complainer, a Medium may be stated.    'The top US
#   commander in Iraq complained to the Pentagon last winter that his
#   supply situation was so poor that it threatened Army troops'
#   ability to fight.'   'He said he will lodge a complaint with the
#   ACCC. DNI'  'On the rare occasions I complained to him about
#   media bias, Peter immediately ordered up a story that included
#   conservative objections to mainstream reports .'  'The Op-Eds
#   were full of gripes about the recent tax hike.'
#
# [semTypes] 0 semantic types
#
# [frameRelations] 2 frame relations
#   <Parent=Statement -- Inheritance -> Child=Complaining>
#   <Source=Statement -- ReFraming_Mapping -> Target=Complaining>
#
# [lexUnit] 15 lexical units
#   belly-ache.v (12730), bitch.v (12725), complain.v (12723),
#   complaint.n (12726), grievance.n (17324), gripe.n (12763),
#   gripe.v (12729), grouse.v (12727), grousing.n (13176), grumble.v
#   (13002), lament.v (12728), moan.v (12724), piss and moan.v
#   (12847), whine.v (12722), whinge.v (12721)
#
#
# [FE] 17 frame elements
#             Core: Complainer (8975), Complaint (8977), Medium (8983), Topic (8978)
#       Peripheral: Addressee (8976), Degree (9060), Manner (8979), Means (8981), Occasion (9061), Place (8986), Time (8985)
#   Extra-Thematic: Depictive (8984), Explanation (10042), Frequency (8980), Internal_cause (8982), Particular_iteration (8988), Result (10043)
#
# [FEcoreSets] 2 frame element core sets
#   Complaint, Topic
#   Medium, Complainer

# %% [markdown]
# ## Struttura interna del frame
#
# The dict that is returned from the `frame` function will contain the
#         following information about the Frame:
#
#         - 'name'       : the name of the Frame (e.g. 'Birth', 'Apply_heat', etc.)
#         - 'definition' : textual definition of the Frame
#         - 'ID'         : the internal ID number of the Frame
#         - 'semTypes'   : a list of semantic types for this frame
#            - Each item in the list is a dict containing the following keys:
#               - 'name' : can be used with the semtype() function
#               - 'ID'   : can be used with the semtype() function
#
#         - 'lexUnit'    : a dict containing all of the LUs for this frame.
#                          The keys in this dict are the names of the LUs and
#                          the value for each key is itself a dict containing
#                          info about the LU (see the lu() function for more info.)
#
#         - 'FE' : a dict containing the Frame Elements that are part of this frame
#                  The keys in this dict are the names of the FEs (e.g. 'Body_system')
#                  and the values are dicts containing the following keys
#               - 'definition' : The definition of the FE
#               - 'name'       : The name of the FE e.g. 'Body_system'
#               - 'ID'         : The id number
#               - '_type'      : 'fe'
#               - 'abbrev'     : Abbreviation e.g. 'bod'
#               - 'coreType'   : one of "Core", "Peripheral", or "Extra-Thematic"
#               - 'semType'    : if not None, a dict with the following two keys:
#                  - 'name' : name of the semantic type. can be used with
#                             the semtype() function
#                  - 'ID'   : id number of the semantic type. can be used with
#                             the semtype() function
#               - 'requiresFE' : if not None, a dict with the following two keys:
#                  - 'name' : the name of another FE in this frame
#                  - 'ID'   : the id of the other FE in this frame
#               - 'excludesFE' : if not None, a dict with the following two keys:
#                  - 'name' : the name of another FE in this frame
#                  - 'ID'   : the id of the other FE in this frame
#
#         - 'frameRelation'      : a list of objects describing frame relations
#         - 'FEcoreSets'  : a list of Frame Element core sets for this frame
#            - Each item in the list is a list of FE objects
#
#         :param fn_fid_or_fname: The Framenet name or id number of the frame
#         :type fn_fid_or_fname: int or str
#         :param ignorekeys: The keys to ignore. These keys will not be
#             included in the output. (optional)
#         :type ignorekeys: list(str)
#         :return: Information about a frame
#         :rtype: dict

# %%
print(f)
# print(len(f.lexUnit))
print_sep()
print(sorted([x for x in f.FE])) #accedo selettivamente ai Frame Elements
print_sep()
print(sorted([x for x in f.lexUnit])) #accedo selettivamente alle LUs
print_sep()
print(f.frameRelations) #accedo selettivamente alle Frame Relations
print_sep()
# Out:
# frame (256): Medical_specialties
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Medical_specialties.xml
#
# [definition]
#   This frame includes words that name medical specialties and is
#   closely related to the Medical_professionals frame.  The FE Type
#   characterizing a sub-are in a Specialty may also be expressed.
#   'Ralph practices paediatric oncology.'
#
# [semTypes] 0 semantic types
#
# [frameRelations] 1 frame relations
#   <Parent=Medical_interaction_scenario -- Using -> Child=Medical_specialties>
#
# [lexUnit] 29 lexical units
#   allopathy.n (4601), cardiology.n (4590), chiropractic.n (4598),
#   dentistry.n (4591), dermatology.n (4592), endocrinology.n (4593),
#   epidemiology.n (4594), gastroenterology.n (4595), gynaecology.n
#   (4596), haematology.n (4597), histology.n (4599), homeopathy.n
#   (4600), immunology.n (4605), medicine.n (4622), midwifery.n
#   (4602), neonatology.n (4610), nephrology.n (4611), neurology.n
#   (4612), obstetrics.n (4613), oncology.n (4614), orthopaedics.n
#   (4615), paediatrics.n (4616), podiatry.n (4617), psychoanalysis.n
#   (4604), psychotherapy.n (4603), radiology.n (4618),
#   rheumatology.n (4619), speech therapy.n (4632), therapy.n (4629)
#
#
# [FE] 4 frame elements
#             Core: Specialty (3618)
#       Peripheral: Affliction (9873), Body_system (9872), Type (3619)
#
# [FEcoreSets] 0 frame element core sets
#
#
#
# _________________________________________________________
#
#
# ['Affliction', 'Body_system', 'Specialty', 'Type']
#
# _________________________________________________________
#
#
# ['allopathy.n', 'cardiology.n', 'chiropractic.n', 'dentistry.n', 'dermatology.n', 'endocrinology.n', 'epidemiology.n', 'gastroenterology.n', 'gynaecology.n', 'haematology.n', 'histology.n', 'homeopathy.n', 'immunology.n', 'medicine.n', 'midwifery.n', 'neonatology.n', 'nephrology.n', 'neurology.n', 'obstetrics.n', 'oncology.n', 'orthopaedics.n', 'paediatrics.n', 'podiatry.n', 'psychoanalysis.n', 'psychotherapy.n', 'radiology.n', 'rheumatology.n', 'speech therapy.n', 'therapy.n']
#
# _________________________________________________________
#
#
# [<Parent=Medical_interaction_scenario -- Using -> Child=Medical_specialties>]
#
# _________________________________________________________

# %% [markdown]
# You can also search for Frames by their Lexical Units (LUs). The **frames_by_lemma()** function returns a list of all frames that contain LUs in which the 'name' attribute of the LU matches the given regular expression. Note that LU names are composed of "lemma.POS", where the "lemma" part can be made up of either a single lexeme (e.g. 'run') or multiple lexemes (e.g. 'a little') (see below).

# %%
print(fn.frames_by_lemma(r'(?i)epidemiol')) #cerco un frame che contenga "epidemiol" tra le LUs
# Out:
# [<frame ID=256 name=Medical_specialties>]

# %%
frame_list = PrettyList(fn.frames(r'(?i)crim'), maxReprSize=0, breakLines=True)
frame_list.sort(key=itemgetter('ID'))

for f in frame_list:
    print('======================\nNAME: ' + str(f.name))
    print('======================\nDEF:  ' + str(f.definition))
    print('======================\nFEs:  ' + str(f.FE))
    print('======================\nLUs:  ' + str(f.lexUnit))
# Out:
# ======================
# NAME: Criminal_process
# ======================
# DEF:  A Suspect is arrested by Authorities on Charges related to an Offense, then is arraigned as a Defendant.  If at any time the Defendant pleads guilty, then the Defendant is sentenced, otherwise the Defendant first goes to trial. During trial, the Defense and Prosecution present arguments on behalf of and against the Defendant, respectively. If the Jury comes up with a guilty verdict at the end of the trial, the Defendant is sentenced.  In the end, the Defendant is either released or is given a Sentence by a Judge at the sentencing.  ''  The Core roles in this frame and its subframes include Authorities, Charges, Court, Defendant, Defense, Judge, Jury, Offense, Prosecution, and Suspect.   Non-Core roles include Place, Time, Victim, and Witness.
# ======================
# FEs:  [Court] frame element (1624): Court
#     of Criminal_process(200)
# [definition]
#   This FE identifies the Court involved in a trial.
# [abbrev] Crt
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Place] frame element (1625): Place
#     of Criminal_process(200)
# [definition]
#   This FE identifies the Place where the event occurs.
# [abbrev] P
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Locative_relation(182)
#
# [Time] frame element (1626): Time
#     of Criminal_process(200)
# [definition]
#   This FE identifies the Time when the event occurs.
# [abbrev] T
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Time(141)
#
# [Defendant] frame element (1627): Defendant
#     of Criminal_process(200)
# [definition]
#   The Defendant is charged with an Offense.
# [abbrev] Dfnd
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Judge] frame element (1628): Judge
#     of Criminal_process(200)
# [definition]
#   The Judge heads the Court where arraignment occurs and the case
#   is tried.
# [abbrev] Judge
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Sentient(5)
#
# [Prosecution] frame element (1629): Prosecution
#     of Criminal_process(200)
# [definition]
#   This FE identifies the attorney(s) prosecuting the Defendant.
# [abbrev] Prsc
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Charges] frame element (1630): Charges
#     of Criminal_process(200)
# [definition]
#   This FE identifies the Charges brought against the Defendant.
# [abbrev] Chrg
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Defense] frame element (1631): Defense
#     of Criminal_process(200)
# [definition]
#   The Defense represents the interests of the Defendant.
# [abbrev] Dfns
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Jury] frame element (1632): Jury
#     of Criminal_process(200)
# [definition]
#   This FE identifies the people who are charged by the Court to
#   listen to the testimony, evidence, and arguments, and come to a
#   consensus about the guilt or innocence of the Defendant.
# [abbrev] Jury
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Offense] frame element (2755): Offense
#     of Criminal_process(200)
# [definition]
#   This FE identifies the Offense which the Defendant is accused of
#   committing.
# [abbrev] Off
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Authorities] frame element (16730): Authorities
#     of Criminal_process(200)
# [definition]
#   The Authorities charge the Suspect with commiting a crime, and
#   take him/her into custody.
# [abbrev] Auth
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Suspect] frame element (16731): Suspect
#     of Criminal_process(200)
# [definition]
#   The Suspect is taken into custody by the Authorities, under
#   suspicion of having committed a crime.
# [abbrev] Susp
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Witness] frame element (16732): Witness
#     of Criminal_process(200)
# [definition]
#   A person who is present in a courtroom in order to give some form
#   of evidence, has been sworn in, and is being examined by the
#   Prosecution or Defense.
# [abbrev] Wit
# [coreType] Extra-Thematic
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Victim] frame element (16733): Victim
#     of Criminal_process(200)
# [definition]
#   The Victim is the person (or other sentient being or group) that
#   has in some way been harmed or wronged by the Defendant.
# [abbrev] Vic
# [coreType] Extra-Thematic
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
#
# ======================
# LUs:
# ======================
# NAME: Criminal_investigation
# ======================
# DEF:  This frame describes the process that involves the inquiry and determination by an authority, the Investigator, of the circumstances surrounding an Incident perpetrated by a Suspect.  'The police are investigating the bank's reported loss of several thousand dollars from their downtown branch's top security vault. DNI ' 'Authorities are investigating several murders. DNI'
# ======================
# FEs:  [Investigator] frame element (4041): Investigator
#     of Criminal_investigation(500)
# [definition]
#   The Investigator is the person or agency that investigates the
#   Suspect of a crime (Incident).
# [abbrev] Inv
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Sentient(5)
#
# [Incident] frame element (4045): Incident
#     of Criminal_investigation(500)
# [definition]
#   The Investigator attempts to determine the exact circumstances
#   surrounding the Incident, which is typically a criminal act
#   (murder, robbery) or the result of such an act (death, loss of
#   money).
# [abbrev] Inc
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Time] frame element (4075): Time
#     of Criminal_investigation(500)
# [definition]
#   When the Investigator investigates the Incident. 'Our guys are
#   currently investigating her disappearance.'
# [abbrev] Time
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Time(141)
#
# [Duration] frame element (4096): Duration
#     of Criminal_investigation(500)
# [definition]
#   The length of the investigation. 'The police carried out a two-
#   year investigation into terrorist kidnappings.'
# [abbrev] Dur
# [coreType] Extra-Thematic
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Duration(142)
#
# [Suspect] frame element (4693): Suspect
#     of Criminal_investigation(500)
# [definition]
#   This FE denotes the Suspect that is investigated by the
#   Investigator. 'The police are investigating Dr. Phil.'
# [abbrev] Sus
# [coreType] Core
# [requiresFE] Incident(4045)
# [excludesFE] <None>
# [semType]
#   Goal(153)
#
#
# ======================
# LUs:  [inquiry.n] lexical unit (7958): inquiry.n
#
# [definition]
#   COD: an official investigation.
#
# [frame] Criminal_investigation(500)
#
# [POS] N
#
# [status] Created
#
# [lexemes] inquiry/N
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu7958.xml
#
# [subCorpus] 1 subcorpora
#   manually-added
#
# [exemplars] 1 sentences across all subcorpora
#
# [probe.n] lexical unit (7959): probe.n
#
# [definition]
#   COD: an investigation.
#
# [frame] Criminal_investigation(500)
#
# [POS] N
#
# [status] Finished_Initial
#
# [lexemes] probe/N
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu7959.xml
#
# [subCorpus] 13 subcorpora
#   01-T-PPby-(1), 01-T-PPinto-(1), 01-T-PPof-(1),
#   01-Wpolice,enforcement,yard-T-(2), 02-Wnn-T-(1),
#   03-Wmurder,arson-T-(1), 04-T-PPpolice,authority,sheriff-(1),
#   05-T-PPmurder,arson,crime-(1),
#   06-Wlaunch,start,initiate-T-(1), other-matched-(1), other-
#   matched-(2), other-unmatched-(1), other-unmatched-(2)
#
# [exemplars] 10 sentences across all subcorpora
#
# [investigate.v] lexical unit (7963): investigate.v
#
# [definition]
#   COD: carry out a systematic or formal inquiry into (an incident,
#   person or allegation) so as to establish the truth of a criminal
#   event.
#
# [frame] Criminal_investigation(500)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] investigate/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu7963.xml
#
# [subCorpus] 20 subcorpora
#   01-NPpolice,sherrif,officer-T-(1), 01-T-NP-
#   PPmurder,violation,robbery-(2), 02-T-NP-PPfor-(2),
#   02-T-NPallegation-(1), 02-T-NPcase-(1), 02-T-NPcrime-(1),
#   02-T-NPmurder-(1), 02-T-NPpolice-(1), 03-T-PPfor-(2),
#   03-T-Wwhether-(1), 03-T-Wwrb-(1), 04-T-NPperson,human-(2),
#   05-T-XPperson-(2), 06-T-NPreport,allegation,call-(2),
#   07-T-PPinto-(2), 08-T-NP-PPconnection-(2), other-
#   matched-(1), other-matched-(2), other-unmatched-(1), other-
#   unmatched-(2)
#
# [exemplars] 37 sentences across all subcorpora
#
# [inquire.v] lexical unit (7965): inquire.v
#
# [definition]
#   FN: to ask questions and gather evidence about a possible crime
#   "The police began to inquire into the circumstances of his
#   death."
#
# [frame] Criminal_investigation(500)
#
# [POS] V
#
# [status] Created
#
# [lexemes] inquire/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu7965.xml
#
# [subCorpus] 0 subcorpora
#
#
# [exemplars] 0 sentences across all subcorpora
#
# [probe.v] lexical unit (7966): probe.v
#
# [definition]
#   COD: enquire into closely.
#
# [frame] Criminal_investigation(500)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] probe/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu7966.xml
#
# [subCorpus] 15 subcorpora
#   01-T-NPcrime,allegation,murder-(1), 01-T-PPfor-(3),
#   01-T-PPinto-(2), 02-T-PPby-(1), 03-NPpolice-T-(1),
#   04-T-PPin,on,at-(1), 05-T-PPof,from-(1), 06-T-PPwith,to-(1),
#   manually-added, other-matched-(1), other-matched-(2), other-
#   matched-(3), other-unmatched-(1), other-unmatched-(2),
#   other-unmatched-(3)
#
# [exemplars] 17 sentences across all subcorpora
#
# [investigation.n] lexical unit (8046): investigation.n
#
# [definition]
#   FN: a systematic search or inquiry into an incident
#
# [frame] Criminal_investigation(500)
#
# [POS] N
#
# [status] Finished_Initial
#
# [lexemes] investigation/N
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu8046.xml
#
# [subCorpus] 10 subcorpora
#   01-Wcriminal,judicial,for-T-(1), 02-NPpolice,murder-T-(1),
#   03-T-PPOF-(1), 03-T-PPinto-(1), 04-T-PPby-(1),
#   05-T-PPfor-(1), 06-T-NPprosecution-(1), manually-added,
#   other-matched-(1), other-unmatched-(1)
#
# [exemplars] 57 sentences across all subcorpora
#
# [lead.n] lexical unit (8402): lead.n
#
# [definition]
#   COD: a clue to be followed in the resolution of a problem.
#
# [frame] Criminal_investigation(500)
#
# [POS] N
#
# [status] Created
#
# [lexemes] lead/N
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu8402.xml
#
# [subCorpus] 0 subcorpora
#
#
# [exemplars] 0 sentences across all subcorpora
#
# [clue.n] lexical unit (8403): clue.n
#
# [definition]
#   COD: a fact or piece of evidence serving to reveal a hidden truth
#   or solve a problem.
#
# [frame] Criminal_investigation(500)
#
# [POS] N
#
# [status] Created
#
# [lexemes] clue/N
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu8403.xml
#
# [subCorpus] 0 subcorpora
#
#
# [exemplars] 0 sentences across all subcorpora
#
# [case.n] lexical unit (18702): case.n
#
# [definition]
#   FN: a situation which is under investigation by legal authorities
#   to determine if a crime has been comitted and a prosecution is
#   appropriate.
#
# [frame] Criminal_investigation(500)
#
# [POS] N
#
# [status] Created
#
# [lexemes] case/N
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu18702.xml
#
# [subCorpus] 1 subcorpora
#   manually-added
#
# [exemplars] 1 sentences across all subcorpora
#
#
# ======================
# NAME: Crime_scenario
# ======================
# DEF:  A (putative) Crime is committed and comes to the attention of the Authorities.  In response, there is a Criminal_investigation and (often) Arrest and criminal court proceedings.  The Investigation, Arrest, and other parts of the Criminal_Process are pursued in order to find a Suspect (who then may enter the Criminal_process to become the Defendant) and determine if this Suspect matches the Perpetrator of the Crime, and also to determine if the Charges match the Crime.  If the Suspect is deemed to have committed the Crime, then they are generally given some punishment commensurate with the Charges.
# ======================
# FEs:  [Suspect] frame element (4589): Suspect
#     of Crime_scenario(692)
# [definition]
#   The individual which is under suspicion of having committed the
#   Crime.
# [abbrev]
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Perpetrator] frame element (4590): Perpetrator
#     of Crime_scenario(692)
# [definition]
#   The individual that commits a Crime.
# [abbrev]
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Sentient(5)
#
# [Crime] frame element (4591): Crime
#     of Crime_scenario(692)
# [definition]
#   An act, generally intentional, that matches the description that
#   belongs to an official Charge.
# [abbrev]
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Charge] frame element (4592): Charge
#     of Crime_scenario(692)
# [definition]
#   A description of a type of act that is not permissable according
#   to the law of society.
# [abbrev]
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Authorities] frame element (4593): Authorities
#     of Crime_scenario(692)
# [definition]
#   The group which is responsible for the maintenance of law and
#   order, and as such have been given the power to investigate
#   Crimes, find Suspects and determine if a Suspect should be
#   submitted to the Criminal_process.
# [abbrev]
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
#
# ======================
# LUs:
# ======================
# NAME: Committing_crime
# ======================
# DEF:  A Perpetrator (generally intentionally) commits a Crime, i.e. does something not permitted by the laws of society.  'They perpetrated a felony by substituting a lie for negotiations.'  'The suspect had allegedly committed the crime to gain the attention of a female celebrity.'
# ======================
# FEs:  [Perpetrator] frame element (4600): Perpetrator
#     of Committing_crime(700)
# [definition]
#   The individual that commits a Crime.  'How can he commit treason
#   against the King of England in a foreign country , if he is not
#   English?'  'He perpetrated a crime against mother nature.'
# [abbrev] Perp
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Sentient(5)
#
# [Crime] frame element (4601): Crime
#     of Committing_crime(700)
# [definition]
#   An act, generally intentional, that has been formally forbidden
#   by law.  'How can he commit treason against the King of England
#   in a foreign country , if he is not English?'  'He perpetrated a
#   crime against mother nature.'
# [abbrev] Cr
# [coreType] Core-Unexpressed
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Purpose] frame element (4603): Purpose
#     of Committing_crime(700)
# [definition]
#   The action that the Perpetrator was trying to accomplish in the
#   Crime.  'People don't generally perpetrate a felony in order to
#   go to jail.'
# [abbrev] Purp
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   State_of_affairs(177)
#
# [Manner] frame element (4604): Manner
#     of Committing_crime(700)
# [definition]
#   A description of secondary effects (quietly, loudly), and general
#   descriptions comparing events (the same way). It may indicate
#   salient characteristics of the Perpetrator that also affect the
#   action (presumptuously, coldly, deliberately, eagerly,
#   carefully).  'He committed each crime coldly and deliberately.'
# [abbrev] Man
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Manner(173)
#
# [Means] frame element (4605): Means
#     of Committing_crime(700)
# [definition]
#   An action performed by the Perpetrator in order to accomplish the
#   Crime.  'He perpetrated each heinous act by calculating what
#   would do the most damage and then finding a patsy to do it.'
# [abbrev] Mns
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   State_of_affairs(177)
#
# [Explanation] frame element (4606): Explanation
#     of Committing_crime(700)
# [definition]
#   A state of affairs that the Perpetrator is responding to in their
#   Crime.  'Many of the poor commit petty crimes because they have
#   no recourse.'
# [abbrev] exp
# [coreType] Extra-Thematic
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   State_of_affairs(177)
#
# [Time] frame element (4607): Time
#     of Committing_crime(700)
# [definition]
#   When the Crime was committed.  'A murder perpetrated at 1:08AM
#   this morning was not investigated until noon today.'
# [abbrev] Time
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Time(141)
#
# [Place] frame element (4608): Place
#     of Committing_crime(700)
# [definition]
#   The location where the Crime occurs.  'We have jurisdiction over
#   crimes committed in Woodside County.'
# [abbrev]
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Locative_relation(182)
#
# [Instrument] frame element (4792): Instrument
#     of Committing_crime(700)
# [definition]
#   The Instrument used in committing the crime. 'Most crimes are
#   committed with a firearm.'
# [abbrev] Inst
# [coreType] Extra-Thematic
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Physical_entity(70)
#
# [Frequency] frame element (5430): Frequency
#     of Committing_crime(700)
# [definition]
#   The frequency with which a Crime is committed.  'The average
#   serial killer commits a crime every five years.'
# [abbrev] Freq
# [coreType] Extra-Thematic
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
#
# ======================
# LUs:  [commit.v] lexical unit (8770): commit.v
#
# [definition]
#   COD: perpetrate or carry out (a mistake, crime, or immoral act)
#
# [frame] Committing_crime(700)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] commit/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu8770.xml
#
# [subCorpus] 10 subcorpora
#   01-NPcrime,violation,offence-T-(1),
#   02-T-NPcrime,violation,offence-(1), 03-T-PPby-(1),
#   04-T-PPin,on,at-(1), 05-T-PPagainst-(1), 05-T-PPfor-(1),
#   05-T-PPwith-(1), manually-added, other-matched-(1), other-
#   unmatched-(1)
#
# [exemplars] 24 sentences across all subcorpora
#
# [perpetrate.v] lexical unit (8771): perpetrate.v
#
# [definition]
#   COD: carry out or commit (a harmful, illegal, or immoral action).
#
# [frame] Committing_crime(700)
#
# [POS] V
#
# [status] Finished_Initial
#
# [lexemes] perpetrate/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu8771.xml
#
# [subCorpus] 10 subcorpora
#   02-T-PPin-(1), 02-T-PPon-(1), 02-T-PPupon-(1),
#   03-T-PPagainst-(1), 04-NPcrime,offence,horror-T-(1),
#   05-T-PPby-(1), 06-T-NPcrime,offence,horror-(1), manually-
#   added, other-matched-(1), other-unmatched-(1)
#
# [exemplars] 20 sentences across all subcorpora
#
# [crime.n] lexical unit (11424): crime.n
#
# [definition]
#   COD: an action which constitutes a serious offence against an
#   individual or the state and is punishable by law.
#
# [frame] Committing_crime(700)
#
# [POS] N
#
# [status] Created
#
# [lexemes] crime/N
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu11424.xml
#
# [subCorpus] 1 subcorpora
#   manually-added
#
# [exemplars] 10 sentences across all subcorpora
#
# [commission.n] lexical unit (12702): commission.n
#
# [definition]
#   COD: the action of committing a crime or offence.
#
# [frame] Committing_crime(700)
#
# [POS] N
#
# [status] Created
#
# [lexemes] commission/N
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu12702.xml
#
# [subCorpus] 0 subcorpora
#
#
# [exemplars] 0 sentences across all subcorpora

# %%
""" Also see the ``frame()`` function for details about what is
    contained in the dict that is returned.
"""

f = fn.frame_by_id(256)

print('NAME: {}[{}]\tDEF: {}'.format(f.name, f.ID, f.definition))

print('\n____ FEs ____')
FEs = f.FE.keys()
for fe in FEs:
    fed = f.FE[fe]
    print('\tFE: {}\tDEF: {}'.format(fe, fed.definition))
    # print(fed.definition)
    
print('\n____ LUs ____')
LUs = f.lexUnit.keys()
for lu in LUs:
    print(lu)

#    print('\tFE-DEF: ' + fe.definition)
# Out:
# NAME: Medical_specialties[256]	DEF: This frame includes words that name medical specialties and is closely related to the Medical_professionals frame.  The FE Type characterizing a sub-are in a Specialty may also be expressed. 'Ralph practices paediatric oncology.'
#
# ____ FEs ____
# 	FE: Specialty	DEF: This FE identifies the medical Specialty that someone practices.  'Ralph practices paediatric oncology.'
# 	FE: Type	DEF: This FE identifies the Type of medical Specialty . 'Ralph practices paediatric oncology.'
# 	FE: Body_system	DEF: The sub-part or sub-system of the body which is studied.  This is normally incorporated in the LUs of the frame.  'Dr. Steppenhame was a specialist in intestinal epidemiology.'
# 	FE: Affliction	DEF: The disease or disorder that a specialist attempts to treat.  This concept is normally incorporated in the name of the Specialty.  'She briefly worked as diabetic endocrinology intern.'
#
# ____ LUs ____
# cardiology.n
# dentistry.n
# dermatology.n
# endocrinology.n
# epidemiology.n
# gastroenterology.n
# gynaecology.n
# haematology.n
# chiropractic.n
# histology.n
# homeopathy.n
# allopathy.n
# midwifery.n
# psychotherapy.n
# psychoanalysis.n
# immunology.n
# neonatology.n
# nephrology.n
# neurology.n
# obstetrics.n
# oncology.n
# orthopaedics.n
# paediatrics.n
# podiatry.n
# radiology.n
# rheumatology.n
# medicine.n
# therapy.n
# speech therapy.n

# %% [markdown]
# ### Lexical Units
#
# A lexical unit (LU) is a pairing of a word with a meaning. For example, the "Apply_heat" Frame describes a common situation involving a Cook, some Food, and a Heating Instrument, and is _evoked_ by words such as bake, blanch, boil, broil, brown, simmer, steam, etc. These frame-evoking words are the LUs in the Apply_heat frame. Each sense of a polysemous word is a different LU.
#
# We have used the word "word" in talking about LUs. The reality is actually rather complex. When we say that the word "bake" is polysemous, we mean that the lemma "bake.v" (which has the word-forms "bake", "bakes", "baked", and "baking") is linked to three different frames:
#
# - Apply_heat: "Michelle baked the potatoes for 45 minutes."
# - Cooking_creation: "Michelle baked her mother a cake for her birthday."
# - Absorb_heat: "The potatoes have to bake for more than 30 minutes."
#
# These constitute three different LUs, with different definitions.
#
# Framenet provides multiple annotated examples of each sense of a word (i.e. each LU). Moreover, the set of examples (approximately 20 per LU) illustrates all of the combinatorial possibilities of the lexical unit.
#
# Each LU is linked to a Frame, and hence to the other words which evoke that Frame. This makes the FrameNet database similar to a thesaurus, grouping together semantically similar words.
#
# In the simplest case, frame-evoking words are verbs such as "fried" in:
#
# "Matilde fried the catfish in a heavy iron skillet."
# Sometimes event nouns may evoke a Frame. For example, "reduction" evokes "Cause_change_of_scalar_position" in:
#
# "...the reduction of debt levels to $665 million from $2.6 billion."
# Adjectives may also evoke a Frame. For example, "asleep" may evoke the "Sleep" frame as in:
#
# "They were asleep for hours."
#
# Many common nouns, such as artifacts like "hat" or "tower", typically serve as dependents rather than clearly evoking their own frames.
#
# Details for a specific lexical unit can be obtained using this class's lus() function, which takes an optional regular expression pattern that will be matched against the name of the lexical unit:

# %%
print(fn.lus(r'(?i)a little')) #ricerca esplicitamente all'interno delle LUs
print(fn.lus(r'foresee'))

print(fn.frames_by_lemma(r'(?i)little')) #ricerca esplicitamente all'interno dei Frames
# Out:
# [<lu ID=14744 name=a little bit.adv>, <lu ID=14743 name=a little.adv>, ...]
# [<lu ID=256 name=foresee.v>, <lu ID=3588 name=foreseeable.a>, ...]
# [<frame ID=2001 name=Degree>, <frame ID=219 name=Judgment_communication>, ...]

# %% [raw]
# quanti LUs sono presenti in FN??

# %%
print(len(fn.lus()))
# Out:
# 13572

# %% [markdown]
# consideriamo la LU di `foresee.v`

# %%
print(fn.lu(256).frame.name)
print(fn.lu(256).definition)
print(fn.lu(256).lexemes[0].name)
# Out:
# Expectation
# COD: be aware of beforehand; predict.
# foresee

# %% [markdown]
# ---
#
# ### Vendetta!
#
# Immaginiamo di accedere al frame 'Revenge'. Prima visualizziamo tutto il suo contenuto, e poi accediamo a Frame Elements (FEs) e Lexical Units (LUs).

# %%
f = fn.frame('Revenge')
print(f)
# Out:
# frame (347): Revenge
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Revenge.xml
#
# [definition]
#   This frame concerns the infliction of punishment in return for a
#   wrong suffered. An Avenger performs a Punishment on a Offender as
#   a consequence of an earlier action by the Offender, the Injury.
#   The Avenger inflicting thePunishment need not be the same as the
#   Injured_Party who suffered the Injury,  but the Avenger does have
#   to share the judgment that the Offender's action was wrong. The
#   judgment that the Offender had inflicted an Injury  is made
#   without regard to the law.  '(1) They took revenge for the deaths
#   of two loyalist prisoners.' '(2) Lachlan went out to avenge
#   them.' '(3) The next day, the Roman forces took revenge on their
#   enemies..'
#
# [semTypes] 0 semantic types
#
# [frameRelations] 1 frame relations
#   <Parent=Rewards_and_punishments -- Inheritance -> Child=Revenge>
#
# [lexUnit] 18 lexical units
#   avenge.v (6056), avenger.n (6057), get back (at).v (10003), get
#   even.v (6075), payback.n (10124), retaliate.v (6065),
#   retaliation.n (6071), retribution.n (6070), retributive.a (6074),
#   retributory.a (6076), revenge.n (6067), revenge.v (6066),
#   revengeful.a (6073), revenger.n (6072), sanction.n (10676),
#   vengeance.n (6058), vengeful.a (6068), vindictive.a (6069)
#
#
# [FE] 14 frame elements
#             Core: Avenger (3009), Injured_party (3022), Injury (3018), Offender (3012), Punishment (3015)
#       Peripheral: Degree (3010), Duration (12060), Instrument (3013), Manner (3014), Place (3016), Purpose (3017), Time (3021)
#   Extra-Thematic: Depictive (3011), Result (3020)
#
# [FEcoreSets] 2 frame element core sets
#   Injury, Injured_party
#   Avenger, Punishment

# %%
print(f.FE)
# Out:
# [Avenger] frame element (3009): Avenger
#     of Revenge(347)
# [definition]
#   The Avenger exacts revenge from the Offender for the Injury.  '
#   We want to avenge her. '
# [abbrev] Agt
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Sentient(5)
#
# [Degree] frame element (3010): Degree
#     of Revenge(347)
# [definition]
#   This FE identifies the Degree to which an event occurs. 'Marie
#   took terrible revenge on Trevor.'
# [abbrev] Degr
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Degree(172)
#
# [Depictive] frame element (3011): Depictive
#     of Revenge(347)
# [definition]
#   Depictive identifies a phrase describing the actor of an action.
# [abbrev] Depict
# [coreType] Extra-Thematic
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Offender] frame element (3012): Offender
#     of Revenge(347)
# [definition]
#   The Offender has committed the earlier Injury for which the
#   Avenger seeks revenge.  'Jo had the affair as a kind of revenge
#   against Pat.' 'Marie took terrible revenge on Trevor.'
# [abbrev] Off
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Instrument] frame element (3013): Instrument
#     of Revenge(347)
# [definition]
#   This FE identifies the Instrument with which the revenge is
#   performed.
# [abbrev] Ins
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Physical_entity(70)
#
# [Manner] frame element (3014): Manner
#     of Revenge(347)
# [definition]
#   This frame element refers to the Manner in which the Avenger
#   exacts their revenge from the Offender.  'They took brutal
#   revenge on the criminal.'
# [abbrev] Manr
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Manner(173)
#
# [Punishment] frame element (3015): Punishment
#     of Revenge(347)
# [definition]
#   The Avenger carries out a Punishment in order to exact revenge on
#   the Offender.  'The team took revenge with a resounding victory.'
# [abbrev] Pun
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Place] frame element (3016): Place
#     of Revenge(347)
# [definition]
#   This FE identifies the Place where the revenge occurs.
# [abbrev] Place
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Locative_relation(182)
#
# [Purpose] frame element (3017): Purpose
#     of Revenge(347)
# [definition]
#   This FE identifies the Purpose for which the revenge is
#   performed.
# [abbrev] Purp
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   State_of_affairs(177)
#
# [Injury] frame element (3018): Injury
#     of Revenge(347)
# [definition]
#   The Injury is the injurious action committed by the Offender
#   against the Injured_Party. This Frame Element need not always be
#   realized, although it is conceptually necessary.   'The team
#   sought revenge for their 4-1 defeat last month.'
# [abbrev] Injry
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Result] frame element (3020): Result
#     of Revenge(347)
# [definition]
#   This FE identifies the Result of  inflicting punishment for a
#   wrong suffered.
# [abbrev] Result
# [coreType] Extra-Thematic
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Time] frame element (3021): Time
#     of Revenge(347)
# [definition]
#   This FE identifies the Time when the revenge occurs.
# [abbrev] Time
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType]
#   Time(141)
#
# [Injured_party] frame element (3022): Injured_party
#     of Revenge(347)
# [definition]
#   This frame element identifies the constituent that encodes who or
#   what suffered the Injury at the hands of the Offender. Sometimes,
#   an abstract concept such a person's honour or their blood is
#   presented as the element that has suffered the Injury. These also
#   constitute instances of  Injured_party   'Sam's brothers avenged
#   him.' 'We will decide later how to avenge the blood of the
#   fallen.'
# [abbrev] Injrd_prty
# [coreType] Core
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>
#
# [Duration] frame element (12060): Duration
#     of Revenge(347)
# [definition]
#   The length of time that the Avenger seeks revenge for the Injury.
# [abbrev]
# [coreType] Peripheral
# [requiresFE] <None>
# [excludesFE] <None>
# [semType] <None>

# %% [markdown]
# è possibile inoltre vedere la definzione associata a un certo FE

# %%
f.FE['Injury'].definition
# Out:
# "The Injury is the injurious action committed by the Offender against the Injured_Party. This Frame Element need not always be realized, although it is conceptually necessary.   'The team sought revenge for their 4-1 defeat last month.'"

# %% [markdown]
# elenco delle LUs del frame

# %%
f.lexUnit.keys()
# Out:
# dict_keys(['avenge.v', 'avenger.n', 'vengeance.n', 'retaliate.v', 'revenge.v', 'revenge.n', 'vengeful.a', 'vindictive.a', 'retribution.n', 'retaliation.n', 'revenger.n', 'revengeful.a', 'retributive.a', 'get even.v', 'retributory.a', 'get back (at).v', 'payback.n', 'sanction.n'])

# %% [markdown]
# selezione di tutti i frame che hanno un FE che ha a che fare con 'location':

# %%
fn.fes('location')

{fe.name for fe in fn.fes("location")}
# Out:
# {'Body_location',
#  'Connected_locations',
#  'Constant_location',
#  'Fixed_location',
#  'Holding_location',
#  'Host_location',
#  'Intended_wearing_location',
#  'Location',
#  'Location_of_appearance',
#  'Location_of_assailant',
#  'Location_of_confinement',
#  'Location_of_event',
#  'Location_of_protagonist',
#  'Location_of_representation',
#  'Location_of_sound_source',
#  'Normal_location',
#  'Orientational_location',
#  'Relative_location',
#  'Target_location',
#  'Textual_location',
#  'Undesirable_location',
#  'Useful_location'}

# %% [markdown]
# e per ciascuno dei FEs che ha a che fare con 'location' possiamo risalire al relativo Frame:

# %%
for fe in fn.fes("location"): #FEs che hanno a che fare con "location"
    print(fe.frame.name + '.' + fe.name)
# Out:
# Abounding_with.Location
# Access_scenario.Useful_location
# Accoutrements.Body_location
# Achieving_first.Location_of_appearance
# Aiming.Target_location
# Aiming.Location_of_protagonist
# Arranging.Location
# Assigned_location.Relative_location
# Attempt_distant_interaction_scenario.Target_location
# Being_in_captivity.Holding_location
# Being_located.Location
# Biological_area.Relative_location
# Body_decoration.Body_location
# Body_parts.Orientational_location
# Boundary.Relative_location
# Bounded_entity.Relative_location
# Breaking_out_captive.Location_of_confinement
# Bringing.Constant_location
# Buildings.Relative_location
# Cause_to_make_noise.Location_of_protagonist
# Cause_to_move_in_place.Fixed_location
# Change_accessibility.Useful_location
# Change_posture.Location
# Clothing.Body_location
# Clothing_parts.Body_location
# Coming_up_with.Location_of_appearance
# Connecting_architecture.Connected_locations
# Connectors.Fixed_location
# Contacting.Location_of_protagonist
# Containers.Relative_location
# Create_physical_artwork.Location_of_representation
# Defending.Location_of_protagonist
# Defending.Location_of_assailant
# Desiring.Location_of_event
# Detaining.Holding_location
# Distributed_abundance.Location
# Distributed_position.Location
# Dressing.Body_location
# Drop_in_on.Normal_location
# Drop_in_on.Host_location
# Escaping.Undesirable_location
# Expected_location_of_person.Location
# Firing_point.Relative_location
# Foreign_or_domestic_country.Relative_location
# Freeing_from_confinement.Location_of_confinement
# Give_impression.Location_of_protagonist
# Graph_shape.Location
# Guest_and_host.Host_location
# Hair_configuration.Location
# Having_or_lacking_access.Useful_location
# Hit_or_miss.Target_location
# Improvised_explosive_device.Location
# Inhibit_motion_scenario.Holding_location
# Inhibit_movement.Holding_location
# Inspecting.Location_of_protagonist
# Installing.Location_of_protagonist
# Installing.Fixed_location
# Isolated_places.Relative_location
# Key.Location
# Leaving_traces.Location
# Level_of_light.Location
# Linguistic_meaning.Textual_location
# Lively_place.Location
# Locale.Relative_location
# Locale_by_characteristic_entity.Relative_location
# Locale_by_collocation.Relative_location
# Locale_by_event.Relative_location
# Locale_by_ownership.Relative_location
# Locale_by_use.Relative_location
# Locating.Location
# Make_noise.Location_of_protagonist
# Making_faces.Location_of_protagonist
# Moving_in_place.Fixed_location
# Natural_features.Relative_location
# Obviousness.Location_of_protagonist
# Openness.Useful_location
# Operational_testing.Location_of_protagonist
# Patrolling.Location_of_protagonist
# People_by_residence.Location
# Perception_active.Location_of_protagonist
# Perception_experience.Location_of_protagonist
# Political_locales.Relative_location
# Posture.Location
# Precariousness.Location
# Preference.Location_of_event
# Presence.Location
# Prison.Location
# Punctual_perception.Location_of_protagonist
# Reading_activity.Textual_location
# Relational_location.Relative_location
# Relational_natural_features.Relative_location
# Relational_political_locales.Relative_location
# Releasing.Location_of_confinement
# Releasing_from_custody.Holding_location
# Remainder.Location
# Residence.Location
# Reveal_secret.Location_of_protagonist
# Roadways.Relative_location
# Smuggling.Constant_location
# Sound_movement.Location_of_sound_source
# Sounds.Location_of_sound_source
# Spelling_and_pronouncing.Textual_location
# Storing.Location
# Take_place_of.Textual_location
# Temporary_leave.Location
# Temporary_stay.Location
# Undressing.Body_location
# Visit_host.Normal_location
# Visit_host.Host_location
# Visit_host_arrival.Normal_location
# Visit_host_arrival.Host_location
# Visit_host_departure.Host_location
# Visit_host_stay.Normal_location
# Visit_host_stay.Host_location
# Visiting.Normal_location
# Visiting_scenario.Normal_location
# Visiting_scenario_arrival.Normal_location
# Visiting_scenario_stay.Normal_location
# Visitor_and_host.Normal_location
# Visitor_and_host.Host_location
# Visitor_arrival.Normal_location
# Visitor_scenario.Normal_location
# Vocalizations.Location_of_sound_source
# Wearing.Intended_wearing_location
# Wearing.Relative_location

# %% [markdown]
# ### Frame relations
#
# Elenco delle possibili relazioni fra frame

# %%
import nltk
import re
import sys

#relazioni che intercorrono tra coppie di Frame
def get_fn_relations(fn_rel_list):
    frame_rels = []

    for f in fn_rel_list:
        text = str(f)
        try:
            found = re.search('.*-- (.+?) ->.*', text).group(1)
            # print(found)
            frame_rels.append(found)
        except AttributeError:
            print('the expression \n\t{}\n does not contain the searched pattern'.format(f))
            sys.exit(1)
    
    # rels_set = set(frame_rels)
    # print(rels_set)
    return set(frame_rels)

fn_rels = get_fn_relations(fn.frame_relations())
for fr in fn_rels:
    print('\t' + fr)
# Out:
# 	Precedes
# 	Using
# 	See_also
# 	Metaphor
# 	Causative_of
# 	Perspective_on
# 	Inheritance
# 	Inchoative_of
# 	Subframe
# 	ReFraming_Mapping

# %% [markdown]
# Possibile utilizzo: che cosa viene causato da 'Make_noise'?

# %%
#a quale altri frame è legato un certo frame lungo una relazione (type) specifica
fn.frame_relations(frame='Make_noise', type='Causative_of')
# Out:
# [<Causative=Cause_to_make_noise -- Causative_of -> Inchoative/state=Make_noise>]

# %% [markdown]
# e più in generale, con quali altri frame è in relazione '`Make_noise`'?

# %%
rels = fn.frame_relations(frame='Make_noise')
for rel in rels:
    print(rel)
# Out:
# <Parent=Make_noise -- Using -> Child=Communication_noise>
# <Parent=Perception -- Using -> Child=Make_noise>
# <MainEntry=Make_noise -- See_also -> ReferringEntry=Cause_impact>
# <MainEntry=Make_noise -- See_also -> ReferringEntry=Cause_to_make_noise>
# <MainEntry=Make_noise -- See_also -> ReferringEntry=Friction>
# <MainEntry=Make_noise -- See_also -> ReferringEntry=Impact>
# <MainEntry=Make_noise -- See_also -> ReferringEntry=Motion_noise>
# <MainEntry=Make_noise -- See_also -> ReferringEntry=Sound_movement>
# <MainEntry=Make_noise -- See_also -> ReferringEntry=Sounds>
# <Source=Cause_impact -- ReFraming_Mapping -> Target=Make_noise>
# <Source=Make_noise -- ReFraming_Mapping -> Target=Absorb_heat>
# <Source=Make_noise -- ReFraming_Mapping -> Target=Cause_to_make_noise>
# <Source=Make_noise -- ReFraming_Mapping -> Target=Fluidic_motion>
# <Source=Make_noise -- ReFraming_Mapping -> Target=Friction>
# <Source=Make_noise -- ReFraming_Mapping -> Target=Impact>
# <Source=Make_noise -- ReFraming_Mapping -> Target=Motion_noise>
# <Source=Make_noise -- ReFraming_Mapping -> Target=Sounds>
# <Causative=Cause_to_make_noise -- Causative_of -> Inchoative/state=Make_noise>

# %% [markdown]
# Accesso alle **annotazioni**

# %%
input_term = 'revenge'
count = 0

while count < 10:
    print(fn.exemplars(input_term)[count].FE)
    # print(fn.exemplars(input_term)[count].POS)
    print(fn.exemplars(input_term)[count].annotationSet[0])
    count += 1
    print_sep()
# Out:
# ([(68, 89, 'Offender')], {})
# POS annotation set (1312469) BNC in sentence 929297:
#
# I   thought it  probable the police were right   ,   he  had
# -   ------- --  -------- --- ------ ---- -----   -   --  ---
# PNP VVD     PNP AJ0      AT0 NN2    VBD  AJ0-AV0 PUN PNP VHD
#
# sought revenge against Imogen Surkov for separating him from his
# ------ ------- ------- ------ ------ --- ---------- --- ---- ---
# VVN    NN1-VVB PRP     NP0    NP0    PRP VVG        PNP PRP  DPS
#
# nice third wife ,   Vera ,   and their son .
# ---- ----- ---- -   ---- -   --- ----- --- -
# AJ0  ORD   NN1  PUN NP0  PUN CJC DPS   NN1 PUN
#
#
# _________________________________________________________
#
#
# ([(117, 131, 'Offender')], {})
# POS annotation set (1312491) BNC in sentence 929308:
#
# An  estimated 50,000 Shias attended Musawi 's  funeral on  Feb.
# --  --------- ------ ----- -------- ------ --  ------- --  ----
# AT0 AJ0       CRD    NP0   VVD      NP0    POS NN1     PRP NP0
#
# 17  in  the southern outskirts of  Beirut ,   vowing revenge
# --  --  --- -------- --------- --  ------ -   ------ -------
# CRD PRP AT0 AJ0      NN2       PRF NP0    PUN VVG    NN1
#
# against Israel .
# ------- ------ -
# PRP     NP0    PUN
#
#
# _________________________________________________________
#
#
# ([(0, 10, 'Punishment'), (34, 126, 'Avenger')], {'Offender': 'INI', 'Injury': 'INI'})
# POS annotation set (1312515) BNC in sentence 929320:
#
# The plunge was partly the revenge of  a   group of  investors
# --- ------ --- ------ --- ------- --  -   ----- --  ---------
# AT0 NN1    VBD AV0    AT0 NN1     PRF AT0 NN0   PRF NN2
#
# invited to  sample the Disney rides in  a   pre-opening visit on
# ------- --  ------ --- ------ ----- --  -   ----------- ----- --
# VVD     TO0 VVI    AT0 NP0    VVZ   PRP AT0 AJ0         NN1   PRP
#
#  Tuesday .
#  ------- -
#  NP0     PUN
#
#
# _________________________________________________________
#
#
# ([(152, 166, 'Punishment'), (182, 198, 'Avenger'), (199, 207, 'Offender')], {'Injury': 'INI'})
# POS annotation set (1312541) BNC in sentence 929333:
#
# She claimed that    ,   `   in  a   culture whose already
# --- ------- ----    -   -   --  -   ------- ----- -------
# PNP VVD     CJT-DT0 PUN PUQ PRP AT0 NN1     DTQ   AV0
#
# classical dilemma is  the hypertrophy of  the intellect at  the
# --------- ------- --  --- ----------- --  --- --------- --  ---
# AJ0       NN1     VBZ AT0 NN1         PRF AT0 NN1       PRP AT0
#
# expense of  energy and sensual capability ,   interpretation is
# ------- --  ------ --- ------- ---------- -   -------------- --
# NN1     PRF NN1    CJC AJ0     NN1        PUN NN1            VBZ
#
# the revenge of  the intellect upon art "   .
# --- ------- --  --- --------- ---- --- -   -
# AT0 NN1     PRF AT0 NN1       PRP  NN1 PUQ PUN
#
#
# _________________________________________________________
#
#
# ([(19, 39, 'Avenger')], {'Injury': 'INI', 'Offender': 'INI'})
# POS annotation set (1312555) BNC in sentence 929340:
#
# Peru fears revenge of  Blackburn vampire
# ---- ----- ------- --  --------- -------
# NP0  VVZ   NN1     PRF NP0       NN1-VVB
#
#
# _________________________________________________________
#
#
# ([(40, 42, 'Punishment'), (47, 50, 'Avenger'), (59, 88, 'Offender')], {'Injury': 'INI'})
# POS annotation set (1312565) BNC in sentence 929345:
#
# This appearance of  naïvety was a   mask ;   it  was his revenge
# ---- ---------- --  ------- --- -   ---- -   --  --- --- -------
# DT0  NN1        PRF NN1     VBD AT0 NN1  PUN PNP VBD DPS NN1
#
# on  lesser people than himself .
# --  ------ ------ ---- ------- -
# PRP AJ0    NN0    CJS  PNX     PUN
#
#
# _________________________________________________________
#
#
# ([(46, 55, 'Punishment'), (59, 62, 'Avenger'), (71, 85, 'Offender')], {'Injury': 'INI'})
# POS annotation set (1312575) BNC in sentence 929350:
#
# What we  did n't know for a   long time was that this book is
# ---- --  --- --- ---- --- -   ---- ---- --- ---- ---- ---- --
# DTQ  PNP VDD XX0 VVI  PRP AT0 AJ0  NN1  VBD CJT  DT0  NN1  VBZ
#
# his revenge on  his parents .
# --- ------- --  --- ------- -
# DPS NN1     PRP DPS NN2     PUN
#
#
# _________________________________________________________
#
#
# ([(0, 9, 'Avenger'), (30, 54, 'Offender')], {'Injury': 'DNI'})
# POS annotation set (1312587) BNC in sentence 929356:
#
# Edward 's  extravagant revenge on  his erstwhile enemies --  the
# ------ --  ----------- ------- --  --- --------- ------- --  ---
# NP0    POS AJ0-NN1     NN1     PRP DPS AJ0       NN2     PUN AT0
#
# so-called Contrariants --  was hardly calculated to  reconcile
# --------- ------------ --  --- ------ ---------- --  ---------
# AJ0       NN2          PUN VBD AV0    VVN        TO0 VVI
#
# them and was too excessive to  repress them .
# ---- --- --- --- --------- --  ------- ---- -
# PNP  CJC VBD AV0 AJ0       TO0 VVI     PNP  PUN
#
#
# _________________________________________________________
#
#
# ([(0, 4, 'Punishment'), (9, 11, 'Avenger'), (20, 26, 'Offender'), (29, 59, 'Injury')], {})
# POS annotation set (1312593) BNC in sentence 929359:
#
# That was my  revenge on  you ,   for causing me  so  much trouble
# ---- --- --  ------- --  --- -   --- ------- --  --  ---- -------
# DT0  VBD DPS NN1     PRP PNP PUN PRP VVG     PNP AV0 DT0  NN1
#
#  !   "   she cried angrily .
#  -   -   --- ----- ------- -
#  PUN PUQ PNP VVD   AV0     PUN
#
#
# _________________________________________________________
#
#
# ([], {})
# POS annotation set (1312613) BNC in sentence 929369:
#
# However ,   he  played down    speculation that the Government
# ------- -   --  ------ ----    ----------- ---- --- ----------
# AV0     PUN PNP VVD    AVP-PRP NN1         CJT  AT0 NN0
#
# would seek revenge for alleged anti-Tory bias in  BBC coverage
# ----- ---- ------- --- ------- --------- ---- --  --- --------
# VM0   VVI  NN1     PRP AJ0     AJ0       NN1  PRP NP0 NN1
#
# of  the election .
# --  --- -------- -
# PRF AT0 NN1      PUN
#
#
# _________________________________________________________

# %% [markdown]
# ---
# ### getFrameSetForStudent
#
# Funzione per assegnare a ciascuno un insieme di frame.

# %%
import hashlib
import random
from random import randint
from random import seed

def print_frames_with_IDs():
    for x in fn.frames():
        print('{}\t{}'.format(x.ID, x.name))

def get_frams_IDs():
    return [f.ID for f in fn.frames()]   

def getFrameSetForStudent(surname, list_len=5):
    nof_frames = len(fn.frames())
    base_idx = (abs(int(hashlib.sha512(surname.encode('utf-8')).hexdigest(), 16)) % nof_frames)
    print('\nstudent: ' + surname)
    framenet_IDs = get_frams_IDs()
    i = 0
    offset = 0 
    seed(1)
    while i < list_len:
        fID = framenet_IDs[(base_idx+offset)%nof_frames]
        f = fn.frame(fID)
        fNAME = f.name
        print('\tID: {a:4d}\tframe: {framename}'.format(a=fID, framename=fNAME))
        offset = randint(0, nof_frames)
        i += 1        


getFrameSetForStudent('Radicioni')
# Out:
# student: Radicioni
# 	ID:  233	frame: Process
# 	ID: 2717	frame: Tool_purpose
# 	ID: 1071	frame: People_by_vocation
# 	ID:  246	frame: Rope_manipulation
# 	ID:  272	frame: Breathing

# %% [markdown]
# ## ESERCITAZIONE

# %%
import nltk
'''
    nltk.download('all')
o in alternativa
    nltk.download('framenet')
'''
from nltk.corpus import framenet as fn
from nltk.corpus.reader.framenet import PrettyList

from operator import itemgetter
from pprint import pprint

from nltk.corpus import wordnet as wn

# %%
#Individuazione del Frame Set
getFrameSetForStudent('Demaria')
# Out:
# student: Demaria
# 	ID:  141	frame: Certainty
# 	ID: 2662	frame: Firing_point
# 	ID:  272	frame: Breathing
# 	ID: 1344	frame: Delivery
# 	ID:  238	frame: Motion_scenario

# %%
Frame_Set = ["Certainty", "Firing_point", "Breathing", "Delivery", "Motion_scenario"]

# %%
def print_sep():
    print('\n_________________________________________________________\n\n')

#accesso alle informazioni principali sui frame assegnati
f1 = fn.frame_by_name('Certainty')
print(f1) 
print_sep()

f2 = fn.frame_by_name('Firing_point')
print(f2)
print_sep()

f3 = fn.frame_by_name('Breathing')
print(f3)
print_sep()

f4 = fn.frame_by_name('Delivery')
print(f4)
print_sep()

f5 = fn.frame_by_name('Motion_scenario')
print(f5)
# Out:
# frame (141): Certainty
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Certainty.xml
#
# [definition]
#   This frame concerns a Cognizer's certainty about the correctness
#   of beliefs  or expectations. It only includes uses where a
#   Cognizer is expressed.  'Lermontov was certain he would come to
#   the party.'
#
# [semTypes] 0 semantic types
#
# [frameRelations] 6 frame relations
#   <Parent=Certainty -- Inheritance -> Child=Trust>
#   <Parent=Gradable_attributes -- Inheritance -> Child=Certainty>
#   <Parent=Awareness -- Using -> Child=Certainty>
#   <Parent=Certainty -- Using -> Child=Reliance_on_expectation>
#   <MainEntry=Awareness -- See_also -> ReferringEntry=Certainty>
#   <Source=Certainty -- ReFraming_Mapping -> Target=Likelihood>
#
# [lexUnit] 20 lexical units
#   believe.v (2756), certain.a (2745), certainty.n (2753),
#   confidence.n (2749), confident.a (2747), convinced.a (2750),
#   doubt.n (3401), doubt.v (2754), doubtful.a (2755), dubious.a
#   (2752), know.v (15553), positive.a (2751), skeptic.n (14305),
#   skeptical.a (14303), skepticism.n (14304), sure.a (2748), trust.v
#   (12113), uncertain.a (2746), uncertainty.n (2757), unsure.a
#   (3285)
#
#
# [FE] 8 frame elements
#             Core: Cognizer (1091), Content (1093), Expressor (1549), Topic (1092)
#       Peripheral: Degree (1099), Manner (1102)
#   Extra-Thematic: Concessive (11077), Explanation (12035)
#
# [FEcoreSets] 2 frame element core sets
#   Expressor, Cognizer
#   Topic, Content
#
#
# _________________________________________________________
#
#
# frame (2662): Firing_point
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Firing_point.xml
#
# [definition]
#   A location from which a Detonator activates a distantly-located
#   explosive device.  'Locating the firing point of remote control
#   IEDs is no easy task.'  'The first task is to determine where he
#   located his firing point.'
#
# [semTypes] 0 semantic types
#
# [frameRelations] 2 frame relations
#   <Parent=Locale_by_event -- Inheritance -> Child=Firing_point>
#   <Parent=Distant_operated_IED -- Using -> Child=Firing_point>
#
# [lexUnit] 1 lexical units
#   firing point.n (16655)
#
#
# [FE] 5 frame elements
#             Core: Firing_point (15089)
#       Peripheral: Detonator (15095), Relative_location (15091)
#   Extra-Thematic: Descriptor (15093), Name (15094)
#
# [FEcoreSets] 0 frame element core sets
#
#
#
# _________________________________________________________
#
#
# frame (272): Breathing
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Breathing.xml
#
# [definition]
#   An Agent causes Air to move in a direction, usually specifying
#   either in or out of the body.  'Lee breathed the hot desert air.'
#
# [semTypes] 0 semantic types
#
# [frameRelations] 1 frame relations
#   <Parent=Fluidic_motion -- Using -> Child=Breathing>
#
# [lexUnit] 20 lexical units
#   blow.v (11963), breath.n (4959), breathe.v (4957), exhalation
#   [act].n (4964), exhalation.n (4963), exhale.v (4960), expire.v
#   (11964), gasp.v (4961), huff.v (4967), inhalation [breath].n
#   (4966), inhalation.n (4965), inhale.v (4958), inspire.v (11966),
#   insufflate.v (11967), pant.v (11968), puff.v (4968), respire.v
#   (11969), sigh.n (4962), sigh.v (4992), suspire.v (11970)
#
#
# [FE] 18 frame elements
#             Core: Agent (2337), Air (2338)
#       Peripheral: Degree (2344), Distance (4541), Duration (2348), Goal (2339), Instrument (5405), Manner (2340), Means (2341), Path (2343), Place (2346), Purpose (8002), Source (2342), Time (5406)
#   Extra-Thematic: Circumstances (8001), Depictive (2345), External_cause (8000), Internal_cause (7999)
#
# [FEcoreSets] 0 frame element core sets
#
#
#
# _________________________________________________________
#
#
# frame (1344): Delivery
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Delivery.xml
#
# [definition]
#   A Deliverer hands off a Theme to a Recipient or (more indirectly)
#   a Goal location, which is accessible to the Recipient.    'The
#   staff of Ebags delivered the umbrella well ahead of schedule.'
#   'In each class a dove flew in and delivered a red rose to Ginny.'
#   'The Pontifical Delegation for the delivery of the Icon of the
#   Kazan Mother of God will arrive tomorrow. '
#
# [semTypes] 0 semantic types
#
# [frameRelations] 2 frame relations
#   <Parent=Delivery -- Inheritance -> Child=Product_delivery>
#   <Parent=Sending -- Using -> Child=Delivery>
#
# [lexUnit] 2 lexical units
#   deliver.v (11664), delivery.n (11665)
#
#
# [FE] 21 frame elements
#             Core: Deliverer (7587), Goal (7589), Recipient (7597), Theme (7591)
#       Peripheral: Manner (7596), Means (7947), Path (7948), Place (7603), Purpose (7598), Source (7946), Speed (7943), Time (7600), Vehicle (7592)
#   Extra-Thematic: Beneficiary (10952), Circumstances (7944), Container (7602), Cotheme (7601), Depictive (7594), Event_description (10953), Explanation (7599), Period_of_iterations (10954)
#
# [FEcoreSets] 0 frame element core sets
#
#
#
# _________________________________________________________
#
#
# frame (238): Motion_scenario
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Motion_scenario.xml
#
# [definition]
#   This frame binds together the various parts of movement, from
#   setting out, to traveling, to arriving.
#
# [semTypes] 1 semantic types
#   Non-Lexical Frame(16)
#
# [frameRelations] 5 frame relations
#   <Parent=Motion_scenario -- Using -> Child=Operate_vehicle_scenario>
#   <Neutral=Motion_scenario -- Perspective_on -> Perspectivized=Motion>
#   <Neutral=Motion_scenario -- Perspective_on -> Perspectivized=Source_of_getting>
#   <Neutral=Motion_scenario -- Perspective_on -> Perspectivized=Source_path_goal>
#   <Neutral=Motion_scenario -- Perspective_on -> Perspectivized=Traversing>
#
# [lexUnit] 0 lexical units
#
#
#
# [FE] 11 frame elements
#             Core: Area (2054), Cotheme (2055), Distance (2056), Duration (2052), Goal (2057), Mode_of_transportation (2062), Path (2058), Source (2059), Speed (2060), Theme (2061)
#       Peripheral: Time (2053)
#
# [FEcoreSets] 1 frame element core sets
#   Goal, Path, Source

# %%
#Considero FEs, LUs e Relazioni di "Certainty"
print(sorted([x for x in f5.FE])) #accedo selettivamente ai Frame Elements
print_sep()
print(sorted([x for x in f5.lexUnit])) #accedo selettivamente alle LUs
print_sep()
print(f5.frameRelations) #accedo selettivamente alle Frame Relations
print_sep()
# Out:
# ['Area', 'Cotheme', 'Distance', 'Duration', 'Goal', 'Mode_of_transportation', 'Path', 'Source', 'Speed', 'Theme', 'Time']
#
# _________________________________________________________
#
#
# []
#
# _________________________________________________________
#
#
# [<Parent=Motion_scenario -- Using -> Child=Operate_vehicle_scenario>, <Neutral=Motion_scenario -- Perspective_on -> Perspectivized=Motion>, ...]
#
# _________________________________________________________

# %%
#Creo delle liste con i FEs e LUs per ogni frame e le definizioni
Certainty_FE = []
Certainty_LU = []
Certainty_DEF = f1.definition
Firing_point_FE = []
Firing_point_LU = []
Firing_point_DEF = f2.definition 
Breathing_FE = []
Breathing_LU = []
Breathing_DEF = f3.definition
Delivery_FE = []
Delivery_LU = []
Delivery_DEF = f4.definition
Motion_scenario_FE = []
Motion_scenario_LU = []
Motion_scenario_DEF = f5.definition


for fes in sorted(f1.FE):
    Certainty_FE.append(fes)
for lus in sorted(f1.lexUnit):
    Certainty_LU.append(lus)
    
for fes in sorted(f2.FE):
    Firing_point_FE.append(fes)
for lus in sorted(f2.lexUnit):
    Firing_point_LU.append(lus)
    
for fes in sorted(f3.FE):
    Breathing_FE.append(fes)
for lus in sorted(f3.lexUnit):
    Breathing_LU.append(lus)
    
for fes in sorted(f4.FE):
    Delivery_FE.append(fes)
for lus in sorted(f4.lexUnit):
    Delivery_LU.append(lus)
    
for fes in sorted(f5.FE):
    Motion_scenario_FE.append(fes)
for lus in sorted(f5.lexUnit):
    Motion_scenario_LU.append(lus)

print("Certainty")
print(Certainty_FE)
print()
print(Certainty_LU)
print_sep()
print("Firing_point")
print(Firing_point_FE)
print()
print(Firing_point_LU)
print_sep()
print("Breathing")
print(Breathing_FE)
print()
print(Breathing_LU)
print_sep()
print("Delivery")
print(Delivery_FE)
print()
print(Delivery_LU)
print_sep()
print("Motion_scenario")
print(Motion_scenario_FE)
print()
print(Motion_scenario_LU)
# Out:
# Certainty
# ['Cognizer', 'Concessive', 'Content', 'Degree', 'Explanation', 'Expressor', 'Manner', 'Topic']
#
# ['believe.v', 'certain.a', 'certainty.n', 'confidence.n', 'confident.a', 'convinced.a', 'doubt.n', 'doubt.v', 'doubtful.a', 'dubious.a', 'know.v', 'positive.a', 'skeptic.n', 'skeptical.a', 'skepticism.n', 'sure.a', 'trust.v', 'uncertain.a', 'uncertainty.n', 'unsure.a']
#
# _________________________________________________________
#
#
# Firing_point
# ['Descriptor', 'Detonator', 'Firing_point', 'Name', 'Relative_location']
#
# ['firing point.n']
#
# _________________________________________________________
#
#
# Breathing
# ['Agent', 'Air', 'Circumstances', 'Degree', 'Depictive', 'Distance', 'Duration', 'External_cause', 'Goal', 'Instrument', 'Internal_cause', 'Manner', 'Means', 'Path', 'Place', 'Purpose', 'Source', 'Time']
#
# ['blow.v', 'breath.n', 'breathe.v', 'exhalation [act].n', 'exhalation.n', 'exhale.v', 'expire.v', 'gasp.v', 'huff.v', 'inhalation [breath].n', 'inhalation.n', 'inhale.v', 'inspire.v', 'insufflate.v', 'pant.v', 'puff.v', 'respire.v', 'sigh.n', 'sigh.v', 'suspire.v']
#
# _________________________________________________________
#
#
# Delivery
# ['Beneficiary', 'Circumstances', 'Container', 'Cotheme', 'Deliverer', 'Depictive', 'Event_description', 'Explanation', 'Goal', 'Manner', 'Means', 'Path', 'Period_of_iterations', 'Place', 'Purpose', 'Recipient', 'Source', 'Speed', 'Theme', 'Time', 'Vehicle']
#
# ['deliver.v', 'delivery.n']
#
# _________________________________________________________
#
#
# Motion_scenario
# ['Area', 'Cotheme', 'Distance', 'Duration', 'Goal', 'Mode_of_transportation', 'Path', 'Source', 'Speed', 'Theme', 'Time']
#
# []

# %%
for frames in Frame_Set:
    print(frames)
# Out:
# Certainty
# Firing_point
# Breathing
# Delivery
# Motion_scenario

# %%
#Stampa synsets e definizioni di "Certainty"
for ss in wn.synsets("time"):
    print(ss.name())
    print(f'def: {ss.definition()}\n')
# Out:
# time.n.01
# def: an instance or single occasion for some event
#
# time.n.02
# def: a period of time considered as a resource under your control and sufficient to accomplish something
#
# time.n.03
# def: an indefinite period (usually marked by specific attributes or activities)
#
# time.n.04
# def: a suitable moment
#
# time.n.05
# def: the continuum of experience in which events pass from the future through the present to the past
#
# time.n.06
# def: a person's experience on a particular occasion
#
# clock_time.n.01
# def: a reading of a point in time as given by a clock
#
# fourth_dimension.n.01
# def: the fourth coordinate that is required (along with three spatial dimensions) to specify a physical event
#
# meter.n.04
# def: rhythm as given by division into parts of equal duration
#
# prison_term.n.01
# def: the period of time a prisoner is imprisoned
#
# clock.v.01
# def: measure the time or duration of an event or action or the person who performs an action in a certain period of time
#
# time.v.02
# def: assign a time for an activity or event
#
# time.v.03
# def: set the speed, duration, or execution of
#
# time.v.04
# def: regulate or set the time of
#
# time.v.05
# def: adjust so that a force is applied and an action occurs at the desired time

# %%
#accedo ai synsets di term, alla definizione

term = "certainty"
    
for ss in wn.synsets(term):
    print(ss.name())
    print(f'def: {ss.definition()}')
    print(f'examples: {ss.examples()}')
    print('--- Hyponyms ---')
    for hypon in ss.hyponyms(): #trovo gli iponimi
        print(f'hypon: {str(hypon)}')
    print('--- Hypernyms ---')
    for hyper in ss.hypernyms(): #trovo gli iperonimi
        print(f'hyper: {str(hyper)}')
    print()
# Out:
# certainty.n.01
# def: the state of being certain
# examples: ['his certainty reassured the others']
# --- Hyponyms ---
# hypon: Synset('assurance.n.01')
# hypon: Synset('certitude.n.01')
# hypon: Synset('reliance.n.01')
# --- Hypernyms ---
# hyper: Synset('cognitive_state.n.01')
#
# certainty.n.02
# def: something that is certain
# examples: ['his victory is a certainty']
# --- Hyponyms ---
# hypon: Synset('cert.n.01')
# hypon: Synset('indisputability.n.01')
# hypon: Synset('ineluctability.n.01')
# hypon: Synset('inevitability.n.01')
# hypon: Synset('moral_certainty.n.01')
# hypon: Synset('predictability.n.01')
# hypon: Synset('slam_dunk.n.01')
# hypon: Synset('surety.n.01')
# --- Hypernyms ---
# hyper: Synset('quality.n.01')

# %%
#Ricerco i WN synsets del Frame Set e le definizioni
for frames in Frame_Set:
    for ss in wn.synsets(frames):
        print(ss.name())
        print(f'def: {ss.definition()}\n')
    print()
# Out:
# certainty.n.01
# def: the state of being certain
#
# certainty.n.02
# def: something that is certain
#
#
#
# breathing.n.01
# def: the bodily process of inhalation and exhalation; the process of taking in oxygen from inhaled air and releasing carbon dioxide by exhalation
#
# breathe.v.01
# def: draw air into, and expel out of, the lungs
#
# breathe.v.02
# def: be alive
#
# breathe.v.03
# def: impart as if by breathing
#
# breathe.v.04
# def: allow the passage of air through
#
# breathe.v.05
# def: utter or tell
#
# breathe.v.06
# def: manifest or evince
#
# rest.v.02
# def: take a short break from one's activities in order to relax
#
# breathe.v.08
# def: reach full flavor by absorbing air and being let to stand after having been uncorked
#
# emit.v.01
# def: expel (gases or odors)
#
# breathing.a.01
# def: passing or able to pass air in and out of the lungs normally; sometimes used in combination
#
#
# delivery.n.01
# def: the act of delivering or distributing something (as goods or mail)
#
# delivery.n.02
# def: the event of giving birth
#
# manner_of_speaking.n.01
# def: your characteristic style or manner of expressing yourself orally
#
# delivery.n.04
# def: the voluntary transfer of something (title or possession) from one party to another
#
# pitch.n.02
# def: (baseball) the act of throwing a baseball by a pitcher to a batter
#
# rescue.n.01
# def: recovery or preservation from loss or danger
#
# delivery.n.07
# def: the act of delivering a child

# %% [markdown]
# Definizioni dei vari FEs

# %%
for fes in (Motion_scenario_FE):
        print(fes)
# Out:
# Area
# Cotheme
# Distance
# Duration
# Goal
# Mode_of_transportation
# Path
# Source
# Speed
# Theme
# Time

# %%
for fes in (Motion_scenario_LU):
        print(fes)

# %%
for fes in Certainty_FE:
    print(f'FEs: {fes}')
    for ss in wn.synsets(fes): 
        print(ss.name())
        print(f'def: {ss.definition()}\n')
    print()
# Out:
# FEs: Cognizer
#
# FEs: Concessive
# concessive.a.01
# def: of or pertaining to concession
#
#
# FEs: Content
# content.n.01
# def: everything that is included in a collection and that is held or included in something
#
# message.n.02
# def: what a communication that is about something is about
#
# content.n.03
# def: the proportion of a substance that is contained in a mixture or alloy etc.
#
# capacity.n.03
# def: the amount that can be contained
#
# content.n.05
# def: the sum or range of what has been perceived, discovered, or learned
#
# contentedness.n.01
# def: the state of being contented with your situation in life
#
# subject.n.02
# def: something (a person or object or scene) selected by an artist or photographer for graphic representation
#
# content.v.01
# def: satisfy in a limited way
#
# content.v.02
# def: make content
#
# contented.a.01
# def: satisfied or showing satisfaction with things as they are
#
#
# FEs: Degree
# degree.n.01
# def: a position on a scale of intensity or amount or quality
#
# degree.n.02
# def: a specific identifiable position in a continuum or series or especially in a process
#
# academic_degree.n.01
# def: an award conferred by a college or university signifying that the recipient has satisfactorily completed a course of study
#
# degree.n.04
# def: a measure for arcs and angles
#
# degree.n.05
# def: the highest power of a term or variable
#
# degree.n.06
# def: a unit of temperature on a specified scale
#
# degree.n.07
# def: the seriousness of something (e.g., a burn or crime)
#
#
# FEs: Explanation
# explanation.n.01
# def: a statement that makes something comprehensible by describing the relevant structure or operation or circumstances etc.
#
# explanation.n.02
# def: thought that makes something comprehensible
#
# explanation.n.03
# def: the act of explaining; making something plain or intelligible
#
#
# FEs: Expressor
#
# FEs: Manner
# manner.n.01
# def: how something is done or how it happens
#
# manner.n.02
# def: a way of acting or behaving
#
# manner.n.03
# def: a kind
#
#
# FEs: Topic
# subject.n.01
# def: the subject matter of a conversation or discussion
#
# topic.n.02
# def: some situation or event that is thought about

# %%
for fes in Firing_point_FE:
    print(f'FEs: {fes}')
    for ss in wn.synsets(fes): 
        print(ss.name())
        print(f'def: {ss.definition()}\n')
    print()
# Out:
# FEs: Descriptor
# form.n.01
# def: the phonological or orthographic sound or appearance of a word that can be used to describe or identify something
#
# descriptor.n.02
# def: a piece of stored information that is used to identify an item in an information storage and retrieval system
#
#
# FEs: Detonator
# detonator.n.01
# def: a mechanical or electrical explosive device or a small amount of explosive; can be used to initiate the reaction of a disrupting explosive
#
#
# FEs: Firing_point
#
# FEs: Name
# name.n.01
# def: a language unit by which a person or thing is known
#
# name.n.02
# def: a person's reputation
#
# name.n.03
# def: family based on male descent
#
# name.n.04
# def: a well-known or notable person
#
# name.n.05
# def: by the sanction or authority of
#
# name.n.06
# def: a defamatory or abusive word or phrase
#
# name.v.01
# def: assign a specified (usually proper) proper name to
#
# name.v.02
# def: give the name or identifying characteristics of; refer to by name or some other identifying characteristic property
#
# name.v.03
# def: charge with a function; charge to be
#
# appoint.v.01
# def: create and charge with a task or function
#
# name.v.05
# def: mention and identify by name
#
# mention.v.01
# def: make reference to
#
# identify.v.05
# def: identify as in botany or biology, for example
#
# list.v.01
# def: give or make a list of; name individually; give the names of
#
# diagnose.v.01
# def: determine or distinguish the nature of a problem or an illness through a diagnostic analysis
#
#
# FEs: Relative_location

# %%
for fes in Breathing_FE:
    print(f'FEs: {fes}')
    for ss in wn.synsets(fes): 
        print(ss.name())
        print(f'def: {ss.definition()}\n')
    print()
# Out:
# FEs: Agent
# agent.n.01
# def: an active and efficient cause; capable of producing a certain effect
#
# agent.n.02
# def: a representative who acts on behalf of other persons or organizations
#
# agent.n.03
# def: a substance that exerts some force or effect
#
# agent.n.04
# def: a businessman who buys or sells for another in exchange for a commission
#
# agent.n.05
# def: any agent or representative of a federal agency or bureau
#
# agentive_role.n.01
# def: the semantic role of the animate entity that instigates or causes the happening denoted by the verb in the clause
#
#
# FEs: Air
# air.n.01
# def: a mixture of gases (especially oxygen) required for breathing; the stuff that the wind consists of
#
# air.n.02
# def: the region above the ground
#
# air.n.03
# def: a distinctive but intangible quality surrounding a person or thing
#
# breeze.n.01
# def: a slight wind (usually refreshing)
#
# atmosphere.n.03
# def: the mass of air surrounding the Earth
#
# air.n.06
# def: once thought to be one of four elements composing the universe (Empedocles)
#
# tune.n.01
# def: a succession of notes forming a distinctive sequence
#
# air.n.08
# def: medium for radio and television broadcasting
#
# air_travel.n.01
# def: travel via aircraft
#
# air_out.v.01
# def: expose to fresh air
#
# air.v.02
# def: be broadcast
#
# air.v.03
# def: broadcast over the airwaves, as in radio or television
#
# publicize.v.01
# def: make public
#
# air.v.05
# def: expose to warm or heated air, so as to dry
#
# vent.v.02
# def: expose to cool or cold air so as to cool or freshen
#
#
# FEs: Circumstances
# fortune.n.04
# def: your overall circumstances or condition in life (including everything that happens to you)
#
# circumstances.n.02
# def: a person's financial situation (good or bad)
#
# circumstance.n.01
# def: a condition that accompanies or influences some event or activity
#
# context.n.02
# def: the set of facts or circumstances that surround a situation or event
#
# circumstance.n.03
# def: information that should be kept in mind when making a decision
#
# circumstance.n.04
# def: formal ceremony about important occasions
#
#
# FEs: Degree
# degree.n.01
# def: a position on a scale of intensity or amount or quality
#
# degree.n.02
# def: a specific identifiable position in a continuum or series or especially in a process
#
# academic_degree.n.01
# def: an award conferred by a college or university signifying that the recipient has satisfactorily completed a course of study
#
# degree.n.04
# def: a measure for arcs and angles
#
# degree.n.05
# def: the highest power of a term or variable
#
# degree.n.06
# def: a unit of temperature on a specified scale
#
# degree.n.07
# def: the seriousness of something (e.g., a burn or crime)
#
#
# FEs: Depictive
# delineative.s.01
# def: depicted in a recognizable manner
#
#
# FEs: Distance
# distance.n.01
# def: the property created by the space between two objects or points
#
# distance.n.02
# def: a distant region
#
# distance.n.03
# def: size of the gap between two places
#
# distance.n.04
# def: indifference by personal withdrawal
#
# distance.n.05
# def: the interval between two times
#
# distance.n.06
# def: a remote point in time
#
# distance.v.01
# def: keep at a distance
#
# outdistance.v.01
# def: go far ahead of
#
#
# FEs: Duration
# duration.n.01
# def: the period of time during which something continues
#
# duration.n.02
# def: the property of enduring or continuing in time
#
# duration.n.03
# def: continuance in time
#
#
# FEs: External_cause
#
# FEs: Goal
# goal.n.01
# def: the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it
#
# finish.n.04
# def: the place designated as the end (as of a race or journey)
#
# goal.n.03
# def: game equipment consisting of the place toward which players of a game try to advance a ball or puck in order to score points
#
# goal.n.04
# def: a successful attempt at scoring
#
#
# FEs: Instrument
# instrument.n.01
# def: a device that requires skill for proper use
#
# instrument.n.02
# def: the means whereby some act is accomplished
#
# instrument.n.03
# def: a person used by another to gain an end
#
# legal_document.n.01
# def: (law) a document that states some contractual relationship or grants some right
#
# instrumental_role.n.01
# def: the semantic role of the entity (usually inanimate) that the agent uses to perform an action or start a process
#
# musical_instrument.n.01
# def: any of various devices or contrivances that can be used to produce musical tones or sounds
#
# instrument.v.01
# def: equip with instruments for measuring, recording, or controlling
#
# instrument.v.02
# def: write an instrumental score for
#
# instrument.v.03
# def: address a legal document to
#
#
# FEs: Internal_cause
#
# FEs: Manner
# manner.n.01
# def: how something is done or how it happens
#
# manner.n.02
# def: a way of acting or behaving
#
# manner.n.03
# def: a kind
#
#
# FEs: Means
# means.n.01
# def: how a result is obtained or an end is achieved
#
# means.n.02
# def: an instrumentality for accomplishing some end
#
# means.n.03
# def: considerable capital (wealth or income)
#
# mean.n.01
# def: an average of n numbers computed by adding some function of the numbers and dividing by some function of n
#
# mean.v.01
# def: mean or intend to express or convey
#
# entail.v.01
# def: have as a logical consequence
#
# mean.v.03
# def: denote or connote
#
# intend.v.01
# def: have in mind as a purpose
#
# mean.v.05
# def: have a specified degree of importance
#
# think_of.v.04
# def: intend to refer to
#
# mean.v.07
# def: destine or designate for a certain purpose
#
#
# FEs: Path
# way.n.05
# def: a course of conduct
#
# path.n.02
# def: a way especially designed for a particular use
#
# path.n.03
# def: an established line of travel or access
#
# path.n.04
# def: a line or route along which something travels or moves
#
#
# FEs: Place
# topographic_point.n.01
# def: a point located with respect to surface features of some region
#
# place.n.02
# def: any area set aside for a particular purpose
#
# place.n.03
# def: an abstract mental location
#
# place.n.04
# def: a general vicinity
#
# stead.n.01
# def: the post or function properly or customarily occupied or served by another
#
# place.n.06
# def: a particular situation
#
# home.n.01
# def: where you live at a particular time
#
# position.n.06
# def: a job in an organization
#
# position.n.01
# def: the particular portion of space occupied by something
#
# place.n.10
# def: proper or designated social situation
#
# seat.n.01
# def: a space reserved for sitting (as in a theater or on a train or airplane)
#
# place.n.12
# def: the passage that is being read
#
# place.n.13
# def: proper or appropriate position or location
#
# plaza.n.01
# def: a public square with room for pedestrians
#
# place.n.15
# def: an item on a list or in a sequence
#
# space.n.07
# def: a blank area
#
# put.v.01
# def: put into a certain place or abstract location
#
# place.v.02
# def: place somebody in a particular situation or location
#
# rate.v.01
# def: assign a rank or rating to
#
# locate.v.03
# def: assign a location to
#
# place.v.05
# def: to arrange for
#
# place.v.06
# def: take a place in a competition; often followed by an ordinal
#
# target.v.01
# def: intend (something) to move towards a certain goal
#
# identify.v.01
# def: recognize as being; establish the identity of someone or something
#
# place.v.09
# def: assign to (a job or a home)
#
# set.v.09
# def: locate
#
# place.v.11
# def: estimate
#
# place.v.12
# def: identify the location or place of
#
# invest.v.01
# def: make an investment
#
# station.v.01
# def: assign to a station
#
# place.v.15
# def: finish second or better in a horse or dog race
#
# place.v.16
# def: sing a note with the correct pitch
#
#
# FEs: Purpose
# purpose.n.01
# def: an anticipated outcome that is intended or that guides your planned actions
#
# function.n.02
# def: what something is used for
#
# determination.n.02
# def: the quality of being determined to do or achieve something; firmness of purpose
#
# aim.v.02
# def: propose or intend
#
# purpose.v.02
# def: reach a decision
#
#
# FEs: Source
# beginning.n.04
# def: the place where something begins, where it springs into being
#
# source.n.02
# def: a document (or organization) from which information is obtained
#
# source.n.03
# def: anything that provides inspiration for later work
#
# source.n.04
# def: a facility where something is available
#
# informant.n.01
# def: a person who supplies information
#
# generator.n.03
# def: someone who originates or causes or initiates something
#
# source.n.07
# def: (technology) a process by which energy or a substance enters a system
#
# reservoir.n.04
# def: anything (a person or animal or plant or substance) in which an infectious agent normally lives and multiplies
#
# reference.n.08
# def: a publication (or a passage from a publication) that is referred to
#
# source.v.01
# def: get (a product) from another country or business
#
# source.v.02
# def: specify the origin of
#
#
# FEs: Time
# time.n.01
# def: an instance or single occasion for some event
#
# time.n.02
# def: a period of time considered as a resource under your control and sufficient to accomplish something
#
# time.n.03
# def: an indefinite period (usually marked by specific attributes or activities)
#
# time.n.04
# def: a suitable moment
#
# time.n.05
# def: the continuum of experience in which events pass from the future through the present to the past
#
# time.n.06
# def: a person's experience on a particular occasion
#
# clock_time.n.01
# def: a reading of a point in time as given by a clock
#
# fourth_dimension.n.01
# def: the fourth coordinate that is required (along with three spatial dimensions) to specify a physical event
#
# meter.n.04
# def: rhythm as given by division into parts of equal duration
#
# prison_term.n.01
# def: the period of time a prisoner is imprisoned
#
# clock.v.01
# def: measure the time or duration of an event or action or the person who performs an action in a certain period of time
#
# time.v.02
# def: assign a time for an activity or event
#
# time.v.03
# def: set the speed, duration, or execution of
#
# time.v.04
# def: regulate or set the time of
#
# time.v.05
# def: adjust so that a force is applied and an action occurs at the desired time

# %%
for fes in Delivery_FE:
    print(f'FEs: {fes}')
    for ss in wn.synsets(fes): 
        print(ss.name())
        print(f'def: {ss.definition()}\n')
    print()
# Out:
# FEs: Beneficiary
# beneficiary.n.01
# def: the recipient of funds or other benefits
#
# benefactive_role.n.01
# def: the semantic role of the intended recipient who benefits from the happening denoted by the verb in the clause
#
# beneficiary.a.01
# def: having or arising from a benefice
#
#
# FEs: Circumstances
# fortune.n.04
# def: your overall circumstances or condition in life (including everything that happens to you)
#
# circumstances.n.02
# def: a person's financial situation (good or bad)
#
# circumstance.n.01
# def: a condition that accompanies or influences some event or activity
#
# context.n.02
# def: the set of facts or circumstances that surround a situation or event
#
# circumstance.n.03
# def: information that should be kept in mind when making a decision
#
# circumstance.n.04
# def: formal ceremony about important occasions
#
#
# FEs: Container
# container.n.01
# def: any object that can be used to hold things (especially a large metal boxlike object of standardized dimensions that can be loaded from one form of transport to another)
#
#
# FEs: Cotheme
#
# FEs: Deliverer
# jesus.n.01
# def: a teacher and prophet born in Bethlehem and active in Nazareth; his life and sermons form the basis for Christianity (circa 4 BC - AD 29)
#
# savior.n.02
# def: a person who rescues you from harm or danger
#
# deliveryman.n.01
# def: someone employed to make deliveries
#
# deliverer.n.04
# def: a person who gives up or transfers money or goods
#
#
# FEs: Depictive
# delineative.s.01
# def: depicted in a recognizable manner
#
#
# FEs: Event_description
#
# FEs: Explanation
# explanation.n.01
# def: a statement that makes something comprehensible by describing the relevant structure or operation or circumstances etc.
#
# explanation.n.02
# def: thought that makes something comprehensible
#
# explanation.n.03
# def: the act of explaining; making something plain or intelligible
#
#
# FEs: Goal
# goal.n.01
# def: the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it
#
# finish.n.04
# def: the place designated as the end (as of a race or journey)
#
# goal.n.03
# def: game equipment consisting of the place toward which players of a game try to advance a ball or puck in order to score points
#
# goal.n.04
# def: a successful attempt at scoring
#
#
# FEs: Manner
# manner.n.01
# def: how something is done or how it happens
#
# manner.n.02
# def: a way of acting or behaving
#
# manner.n.03
# def: a kind
#
#
# FEs: Means
# means.n.01
# def: how a result is obtained or an end is achieved
#
# means.n.02
# def: an instrumentality for accomplishing some end
#
# means.n.03
# def: considerable capital (wealth or income)
#
# mean.n.01
# def: an average of n numbers computed by adding some function of the numbers and dividing by some function of n
#
# mean.v.01
# def: mean or intend to express or convey
#
# entail.v.01
# def: have as a logical consequence
#
# mean.v.03
# def: denote or connote
#
# intend.v.01
# def: have in mind as a purpose
#
# mean.v.05
# def: have a specified degree of importance
#
# think_of.v.04
# def: intend to refer to
#
# mean.v.07
# def: destine or designate for a certain purpose
#
#
# FEs: Path
# way.n.05
# def: a course of conduct
#
# path.n.02
# def: a way especially designed for a particular use
#
# path.n.03
# def: an established line of travel or access
#
# path.n.04
# def: a line or route along which something travels or moves
#
#
# FEs: Period_of_iterations
#
# FEs: Place
# topographic_point.n.01
# def: a point located with respect to surface features of some region
#
# place.n.02
# def: any area set aside for a particular purpose
#
# place.n.03
# def: an abstract mental location
#
# place.n.04
# def: a general vicinity
#
# stead.n.01
# def: the post or function properly or customarily occupied or served by another
#
# place.n.06
# def: a particular situation
#
# home.n.01
# def: where you live at a particular time
#
# position.n.06
# def: a job in an organization
#
# position.n.01
# def: the particular portion of space occupied by something
#
# place.n.10
# def: proper or designated social situation
#
# seat.n.01
# def: a space reserved for sitting (as in a theater or on a train or airplane)
#
# place.n.12
# def: the passage that is being read
#
# place.n.13
# def: proper or appropriate position or location
#
# plaza.n.01
# def: a public square with room for pedestrians
#
# place.n.15
# def: an item on a list or in a sequence
#
# space.n.07
# def: a blank area
#
# put.v.01
# def: put into a certain place or abstract location
#
# place.v.02
# def: place somebody in a particular situation or location
#
# rate.v.01
# def: assign a rank or rating to
#
# locate.v.03
# def: assign a location to
#
# place.v.05
# def: to arrange for
#
# place.v.06
# def: take a place in a competition; often followed by an ordinal
#
# target.v.01
# def: intend (something) to move towards a certain goal
#
# identify.v.01
# def: recognize as being; establish the identity of someone or something
#
# place.v.09
# def: assign to (a job or a home)
#
# set.v.09
# def: locate
#
# place.v.11
# def: estimate
#
# place.v.12
# def: identify the location or place of
#
# invest.v.01
# def: make an investment
#
# station.v.01
# def: assign to a station
#
# place.v.15
# def: finish second or better in a horse or dog race
#
# place.v.16
# def: sing a note with the correct pitch
#
#
# FEs: Purpose
# purpose.n.01
# def: an anticipated outcome that is intended or that guides your planned actions
#
# function.n.02
# def: what something is used for
#
# determination.n.02
# def: the quality of being determined to do or achieve something; firmness of purpose
#
# aim.v.02
# def: propose or intend
#
# purpose.v.02
# def: reach a decision
#
#
# FEs: Recipient
# recipient.n.01
# def: a person who receives something
#
# recipient_role.n.01
# def: the semantic role of the animate entity that is passively involved in the happening denoted by the verb in the clause
#
#
# FEs: Source
# beginning.n.04
# def: the place where something begins, where it springs into being
#
# source.n.02
# def: a document (or organization) from which information is obtained
#
# source.n.03
# def: anything that provides inspiration for later work
#
# source.n.04
# def: a facility where something is available
#
# informant.n.01
# def: a person who supplies information
#
# generator.n.03
# def: someone who originates or causes or initiates something
#
# source.n.07
# def: (technology) a process by which energy or a substance enters a system
#
# reservoir.n.04
# def: anything (a person or animal or plant or substance) in which an infectious agent normally lives and multiplies
#
# reference.n.08
# def: a publication (or a passage from a publication) that is referred to
#
# source.v.01
# def: get (a product) from another country or business
#
# source.v.02
# def: specify the origin of
#
#
# FEs: Speed
# speed.n.01
# def: distance travelled per unit time
#
# speed.n.02
# def: a rate (usually rapid) at which something happens
#
# speed.n.03
# def: changing location rapidly
#
# focal_ratio.n.01
# def: the ratio of the focal length to the diameter of a (camera) lens system
#
# amphetamine.n.01
# def: a central nervous system stimulant that increases energy and decreases appetite; used to treat narcolepsy and some forms of depression
#
# rush.v.01
# def: move fast
#
# accelerate.v.01
# def: move faster
#
# travel_rapidly.v.01
# def: move very fast
#
# speed.v.04
# def: travel at an excessive or illegal velocity
#
# accelerate.v.02
# def: cause to move faster
#
#
# FEs: Theme
# subject.n.01
# def: the subject matter of a conversation or discussion
#
# theme.n.02
# def: a unifying idea that is a recurrent element in literary or artistic work
#
# theme.n.03
# def: (music) melodic subject of a musical composition
#
# composition.n.08
# def: an essay (especially one written as an assignment)
#
# root.n.03
# def: (linguistics) the form of a word after all affixes are removed
#
# theme.v.01
# def: provide with a particular theme or motive
#
#
# FEs: Time
# time.n.01
# def: an instance or single occasion for some event
#
# time.n.02
# def: a period of time considered as a resource under your control and sufficient to accomplish something
#
# time.n.03
# def: an indefinite period (usually marked by specific attributes or activities)
#
# time.n.04
# def: a suitable moment
#
# time.n.05
# def: the continuum of experience in which events pass from the future through the present to the past
#
# time.n.06
# def: a person's experience on a particular occasion
#
# clock_time.n.01
# def: a reading of a point in time as given by a clock
#
# fourth_dimension.n.01
# def: the fourth coordinate that is required (along with three spatial dimensions) to specify a physical event
#
# meter.n.04
# def: rhythm as given by division into parts of equal duration
#
# prison_term.n.01
# def: the period of time a prisoner is imprisoned
#
# clock.v.01
# def: measure the time or duration of an event or action or the person who performs an action in a certain period of time
#
# time.v.02
# def: assign a time for an activity or event
#
# time.v.03
# def: set the speed, duration, or execution of
#
# time.v.04
# def: regulate or set the time of
#
# time.v.05
# def: adjust so that a force is applied and an action occurs at the desired time
#
#
# FEs: Vehicle
# vehicle.n.01
# def: a conveyance that transports people or objects
#
# vehicle.n.02
# def: a medium for the expression or achievement of something
#
# vehicle.n.03
# def: any substance that facilitates the use of a drug or pigment or other material that is mixed with it
#
# fomite.n.01
# def: any inanimate object (as a towel or money or clothing or dishes or books or toys etc.) that can transmit infectious agents from one person to another

# %%
for fes in Motion_scenario_FE:
    print(f'FEs: {fes}')
    for ss in wn.synsets(fes): 
        print(ss.name())
        print(f'def: {ss.definition()}\n')
    print()
# Out:
# FEs: Area
# area.n.01
# def: a particular geographical region of indefinite boundary (usually serving some special purpose or distinguished by its people or culture or geography)
#
# area.n.02
# def: a subject of study
#
# area.n.03
# def: a part of an animal that has a special function or is supplied by a given artery or nerve
#
# sphere.n.01
# def: a particular environment or walk of life
#
# area.n.05
# def: a part of a structure having some specific characteristic or function
#
# area.n.06
# def: the extent of a 2-dimensional surface enclosed within a boundary
#
#
# FEs: Cotheme
#
# FEs: Distance
# distance.n.01
# def: the property created by the space between two objects or points
#
# distance.n.02
# def: a distant region
#
# distance.n.03
# def: size of the gap between two places
#
# distance.n.04
# def: indifference by personal withdrawal
#
# distance.n.05
# def: the interval between two times
#
# distance.n.06
# def: a remote point in time
#
# distance.v.01
# def: keep at a distance
#
# outdistance.v.01
# def: go far ahead of
#
#
# FEs: Duration
# duration.n.01
# def: the period of time during which something continues
#
# duration.n.02
# def: the property of enduring or continuing in time
#
# duration.n.03
# def: continuance in time
#
#
# FEs: Goal
# goal.n.01
# def: the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it
#
# finish.n.04
# def: the place designated as the end (as of a race or journey)
#
# goal.n.03
# def: game equipment consisting of the place toward which players of a game try to advance a ball or puck in order to score points
#
# goal.n.04
# def: a successful attempt at scoring
#
#
# FEs: Mode_of_transportation
#
# FEs: Path
# way.n.05
# def: a course of conduct
#
# path.n.02
# def: a way especially designed for a particular use
#
# path.n.03
# def: an established line of travel or access
#
# path.n.04
# def: a line or route along which something travels or moves
#
#
# FEs: Source
# beginning.n.04
# def: the place where something begins, where it springs into being
#
# source.n.02
# def: a document (or organization) from which information is obtained
#
# source.n.03
# def: anything that provides inspiration for later work
#
# source.n.04
# def: a facility where something is available
#
# informant.n.01
# def: a person who supplies information
#
# generator.n.03
# def: someone who originates or causes or initiates something
#
# source.n.07
# def: (technology) a process by which energy or a substance enters a system
#
# reservoir.n.04
# def: anything (a person or animal or plant or substance) in which an infectious agent normally lives and multiplies
#
# reference.n.08
# def: a publication (or a passage from a publication) that is referred to
#
# source.v.01
# def: get (a product) from another country or business
#
# source.v.02
# def: specify the origin of
#
#
# FEs: Speed
# speed.n.01
# def: distance travelled per unit time
#
# speed.n.02
# def: a rate (usually rapid) at which something happens
#
# speed.n.03
# def: changing location rapidly
#
# focal_ratio.n.01
# def: the ratio of the focal length to the diameter of a (camera) lens system
#
# amphetamine.n.01
# def: a central nervous system stimulant that increases energy and decreases appetite; used to treat narcolepsy and some forms of depression
#
# rush.v.01
# def: move fast
#
# accelerate.v.01
# def: move faster
#
# travel_rapidly.v.01
# def: move very fast
#
# speed.v.04
# def: travel at an excessive or illegal velocity
#
# accelerate.v.02
# def: cause to move faster
#
#
# FEs: Theme
# subject.n.01
# def: the subject matter of a conversation or discussion
#
# theme.n.02
# def: a unifying idea that is a recurrent element in literary or artistic work
#
# theme.n.03
# def: (music) melodic subject of a musical composition
#
# composition.n.08
# def: an essay (especially one written as an assignment)
#
# root.n.03
# def: (linguistics) the form of a word after all affixes are removed
#
# theme.v.01
# def: provide with a particular theme or motive
#
#
# FEs: Time
# time.n.01
# def: an instance or single occasion for some event
#
# time.n.02
# def: a period of time considered as a resource under your control and sufficient to accomplish something
#
# time.n.03
# def: an indefinite period (usually marked by specific attributes or activities)
#
# time.n.04
# def: a suitable moment
#
# time.n.05
# def: the continuum of experience in which events pass from the future through the present to the past
#
# time.n.06
# def: a person's experience on a particular occasion
#
# clock_time.n.01
# def: a reading of a point in time as given by a clock
#
# fourth_dimension.n.01
# def: the fourth coordinate that is required (along with three spatial dimensions) to specify a physical event
#
# meter.n.04
# def: rhythm as given by division into parts of equal duration
#
# prison_term.n.01
# def: the period of time a prisoner is imprisoned
#
# clock.v.01
# def: measure the time or duration of an event or action or the person who performs an action in a certain period of time
#
# time.v.02
# def: assign a time for an activity or event
#
# time.v.03
# def: set the speed, duration, or execution of
#
# time.v.04
# def: regulate or set the time of
#
# time.v.05
# def: adjust so that a force is applied and an action occurs at the desired time

# %%
import hashlib
from random import randint
from random import seed

from nltk.corpus import framenet as fn
from nltk.corpus import wordnet as wn


def read_correct_synsets(path):
    """
    Support function, it parse the txt file. Each line is compose by
    a couple of terms and their annotation.
    Params:
        path: input path of the CSV file
    Returns:
         a list, representation of the input file. Its format will be [(syn)]
    """
    correct_synset = []
    with open(path, "r") as f:
        syn = f.read()
        synset = syn.split("\n")
        for syn in synset:
            if "#" not in syn:
                correct_synset.append(syn)
    return correct_synset


"""
    The functions below these lines were made by professor Radicioni
"""


def get_frame_set_for_student(surname, list_len=5):
    ids_list = []
    nof_frames = len(fn.frames())
    base_idx = (abs(int(hashlib.sha512(surname.encode('utf-8')).hexdigest(), 16)) % nof_frames)
    print('\nstudent: ' + surname)
    framenet_IDs = get_frames_ids()
    i = 0
    offset = 0
    seed(1)
    while i < list_len:
        fID = framenet_IDs[(base_idx+offset)%nof_frames]
        f = fn.frame(fID)
        ids_list.append(fID)
        fNAME = f.name
        print('\tID: {a:4d}\tframe: {framename}'.format(a=fID, framename=fNAME))
        offset = randint(0, nof_frames)
        i += 1
    return ids_list

def print_frames_with_ids():
    for x in fn.frames():
        print('{}\t{}'.format(x.ID, x.name))


def get_frames_ids():
    return [f.ID for f in fn.frames()]

# %%
from pathlib import Path

from nltk.corpus import framenet as fn

surnames = ['Demaria']
"""
In this file, we executes Task 2 (FrameNet Disambiguation)
"""

if __name__ == "__main__":
    correct_synsets_path = Path('.') 
    output_path = Path('.') / 'output'

    with open(output_path / 'results.csv', "w", encoding="utf-8") as out:

        print("Assigning Synsets...")

        for surname in surnames:
            frame_ids = get_frame_set_for_student(surname)

            surname_path = correct_synsets_path / (surname + '.txt')
            read_correct_synsets(surname_path)
            for fID in frame_ids:
                frame = fn.frame_by_id(fID)

                # calculate context ctx_f and ctx_w
# Out:
# Assigning Synsets...
#
# student: Demaria
# 	ID:  141	frame: Certainty
# 	ID: 2662	frame: Firing_point
# 	ID:  272	frame: Breathing
# 	ID: 1344	frame: Delivery
# 	ID:  238	frame: Motion_scenario

# %%
read_correct_synsets('Demaria.txt')
# Out:
# ['Synset(‘certainty.n.01’)',
#  'None',
#  'Synset(‘concessive.a.01’)',
#  'Synset(‘content.n.05’)',
#  'Synset(‘degree.n.01’)',
#  'Synset(‘explanation.n.01’)',
#  'None',
#  'Synset(‘manner.n.01’)',
#  'Synset(‘topic.n.02’)',
#  'Synset(‘believe.v.01’)',
#  'Synset(‘certain.a.03’)',
#  'Synset(‘certainty.n.01’)',
#  'Synset(‘confidence.n.01’)',
#  'Synset(‘confident.a.01’)',
#  'Synset(‘convinced.a.02’)',
#  'Synset(‘doubt.n.02’)',
#  'Synset(‘doubt.v.02’)',
#  'None',
#  'None',
#  'Synset(‘know.v.01’)',
#  'Synset(‘positive.a.01’)',
#  'Synset(‘skeptic.n.01’)',
#  'None',
#  'Synset(‘incredulity.n.01’)',
#  'Synset(‘certain.a.02’)',
#  'Synset(‘trust.v.01’)',
#  'Synset(‘uncertain.a.02’)',
#  'Synset(‘uncertainty.n.01’)',
#  'None',
#  '',
#  'Synset(‘point.n.02’)',
#  'Synset(‘descriptor.n.01’)',
#  'Synset(‘detonator.n.01’)',
#  'None',
#  'Synset(‘name.n.01’)',
#  'Synset(‘localization.n.01’)',
#  'None',
#  '',
#  'Synset(‘breathing.n.01’)',
#  'Synset(‘agentive_role.n.01’)',
#  'Synset(‘air.n.01’)',
#  'Synset(‘context.n.02’)',
#  'Synset(‘degree.n.01’)',
#  'Synset(‘delineative.s.01’)',
#  'Synset(‘distance.n.03’)',
#  'Synset(‘duration.n.01’)',
#  'Synset(‘cause.n.01’)',
#  'Synset(‘finish.n.04’)',
#  'Synset(‘instrument.n.02’)',
#  'None',
#  'Synset(‘manner.n.01’)',
#  'Synset(‘means.n.01’)',
#  'Synset(‘path.n.04’)',
#  'Synset(‘place.n.13’)',
#  'Synset(‘purpose.n.01’)',
#  'Synset(‘beginning.n.04’)',
#  'Synset(‘time.n.02’)',
#  'Synset(‘blow.v.02’)',
#  'Synset(‘breath.n.01’)',
#  'Synset(‘breathe.v.01’)',
#  'Synset(‘exhalation.n.02’)',
#  'Synset(‘halitus.n.01’)',
#  'Synset(‘exhale.v.01’)',
#  'Synset(‘exhale.v.01’)',
#  'Synset(‘pant.v.01’)',
#  'Synset(‘puff.v.08’)',
#  'Synset(‘inhalation.n.01’)',
#  'Synset(‘inhalant.n.02’)',
#  'Synset(‘inhale.v.01’)',
#  'Synset(‘inhale.v.02’)',
#  'Synset(‘insufflate.v.02’)',
#  'Synset(‘pant.v.02’)',
#  'Synset(‘puff.v.01’)',
#  'Synset(‘respire.v.02’)',
#  'Synset(‘sigh.n.01’)',
#  'Synset(‘sigh.v.01’)',
#  'Synset(‘sigh.v.01’)',
#  '',
#  'Synset(‘delivery.n.01’)',
#  'Synset(‘beneficiary.n.01’)',
#  'Synset(‘context.n.02’)',
#  'Synset(‘container.n.01’)',
#  'None',
#  'Synset(‘deliveryman.n.01’)',
#  'Synset(‘delineative.s.01’)',
#  'None',
#  'Synset(‘explanation.n.01’)',
#  'Synset(‘finish.n.04’)',
#  'Synset(‘manner.n.01’)',
#  'Synset(‘means.n.01’)',
#  'Synset(‘pant.v.01’)',
#  'Synset(‘time_period.n.01’)',
#  'Synset(‘topographic_point.n.01’)',
#  'Synset(‘purpose.n.01’)',
#  'Synset(‘recipient.n.01’)',
#  'Synset(‘beginning.n.04’)',
#  'Synset(‘speed.n.02’)',
#  'Synset(‘subject.n.01’)',
#  'Synset(‘time.n.01’)',
#  'Synset(‘vehicle.n.02’)',
#  'Synset(‘deliver.v.02’)',
#  'Synset(‘delivery.n.01’)',
#  '',
#  'Synset(‘motion.n.04’)',
#  'Synset(‘area.n.05’)',
#  'None',
#  'Synset(‘distance.n.03’)',
#  'Synset(‘duration.n.01’)',
#  'Synset(‘finish.n.04’)',
#  'Synset(‘transportation.n.02’)',
#  'Synset(‘path.n.04’)',
#  'Synset(‘beginning.n.04’)',
#  'Synset(‘speed.n.02’)',
#  'Synset(‘subject.n.01’)',
#  'Synset(‘time.n.01’)',
#  'None',
#  '']

# %%
def find_between( s, first, last ):
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[start:end]
    except ValueError:
        return ""

# %%
import re

#Separo il synset name dal resto
start = 'Synset(‘'
end = '’)'

syn_name = []

for syn in read_correct_synsets('Demaria.txt'):
    if syn == 'None':
        syn_name.append(syn)
    else:
        syn_name.append(find_between(syn, start, end))
    
syn_name
# Out:
# ['certainty.n.01',
#  'None',
#  'concessive.a.01',
#  'content.n.05',
#  'degree.n.01',
#  'explanation.n.01',
#  'None',
#  'manner.n.01',
#  'topic.n.02',
#  'believe.v.01',
#  'certain.a.03',
#  'certainty.n.01',
#  'confidence.n.01',
#  'confident.a.01',
#  'convinced.a.02',
#  'doubt.n.02',
#  'doubt.v.02',
#  'None',
#  'None',
#  'know.v.01',
#  'positive.a.01',
#  'skeptic.n.01',
#  'None',
#  'incredulity.n.01',
#  'certain.a.02',
#  'trust.v.01',
#  'uncertain.a.02',
#  'uncertainty.n.01',
#  'None',
#  'point.n.02',
#  'descriptor.n.01',
#  'detonator.n.01',
#  'None',
#  'name.n.01',
#  'localization.n.01',
#  'None',
#  'breathing.n.01',
#  'agentive_role.n.01',
#  'air.n.01',
#  'context.n.02',
#  'degree.n.01',
#  'delineative.s.01',
#  'distance.n.03',
#  'duration.n.01',
#  'cause.n.01',
#  'finish.n.04',
#  'instrument.n.02',
#  'None',
#  'manner.n.01',
#  'means.n.01',
#  'path.n.04',
#  'place.n.13',
#  'purpose.n.01',
#  'beginning.n.04',
#  'time.n.02',
#  'blow.v.02',
#  'breath.n.01',
#  'breathe.v.01',
#  'exhalation.n.02',
#  'halitus.n.01',
#  'exhale.v.01',
#  'exhale.v.01',
#  'pant.v.01',
#  'puff.v.08',
#  'inhalation.n.01',
#  'inhalant.n.02',
#  'inhale.v.01',
#  'inhale.v.02',
#  'insufflate.v.02',
#  'pant.v.02',
#  'puff.v.01',
#  'respire.v.02',
#  'sigh.n.01',
#  'sigh.v.01',
#  'sigh.v.01',
#  'delivery.n.01',
#  'beneficiary.n.01',
#  'context.n.02',
#  'container.n.01',
#  'None',
#  'deliveryman.n.01',
#  'delineative.s.01',
#  'None',
#  'explanation.n.01',
#  'finish.n.04',
#  'manner.n.01',
#  'means.n.01',
#  'pant.v.01',
#  'time_period.n.01',
#  'topographic_point.n.01',
#  'purpose.n.01',
#  'recipient.n.01',
#  'beginning.n.04',
#  'speed.n.02',
#  'subject.n.01',
#  'time.n.01',
#  'vehicle.n.02',
#  'deliver.v.02',
#  'delivery.n.01',
#  'motion.n.04',
#  'area.n.05',
#  'None',
#  'distance.n.03',
#  'duration.n.01',
#  'finish.n.04',
#  'transportation.n.02',
#  'path.n.04',
#  'beginning.n.04',
#  'speed.n.02',
#  'subject.n.01',
#  'time.n.01']

# %%
#rimuovo i None
while 'None' in syn_name:
    syn_name.remove('None')

# %%
syn_name
# Out:
# ['certainty.n.01',
#  'concessive.a.01',
#  'content.n.05',
#  'degree.n.01',
#  'explanation.n.01',
#  'manner.n.01',
#  'topic.n.02',
#  'believe.v.01',
#  'certain.a.03',
#  'certainty.n.01',
#  'confidence.n.01',
#  'confident.a.01',
#  'convinced.a.02',
#  'doubt.n.02',
#  'doubt.v.02',
#  'know.v.01',
#  'positive.a.01',
#  'skeptic.n.01',
#  'incredulity.n.01',
#  'certain.a.02',
#  'trust.v.01',
#  'uncertain.a.02',
#  'uncertainty.n.01',
#  '',
#  'point.n.02',
#  'descriptor.n.01',
#  'detonator.n.01',
#  'name.n.01',
#  'localization.n.01',
#  '',
#  'breathing.n.01',
#  'agentive_role.n.01',
#  'air.n.01',
#  'context.n.02',
#  'degree.n.01',
#  'delineative.s.01',
#  'distance.n.03',
#  'duration.n.01',
#  'cause.n.01',
#  'finish.n.04',
#  'instrument.n.02',
#  'manner.n.01',
#  'means.n.01',
#  'path.n.04',
#  'place.n.13',
#  'purpose.n.01',
#  'beginning.n.04',
#  'time.n.02',
#  'blow.v.02',
#  'breath.n.01',
#  'breathe.v.01',
#  'exhalation.n.02',
#  'halitus.n.01',
#  'exhale.v.01',
#  'exhale.v.01',
#  'pant.v.01',
#  'puff.v.08',
#  'inhalation.n.01',
#  'inhalant.n.02',
#  'inhale.v.01',
#  'inhale.v.02',
#  'insufflate.v.02',
#  'pant.v.02',
#  'puff.v.01',
#  'respire.v.02',
#  'sigh.n.01',
#  'sigh.v.01',
#  'sigh.v.01',
#  '',
#  'delivery.n.01',
#  'beneficiary.n.01',
#  'context.n.02',
#  'container.n.01',
#  'deliveryman.n.01',
#  'delineative.s.01',
#  'explanation.n.01',
#  'finish.n.04',
#  'manner.n.01',
#  'means.n.01',
#  'pant.v.01',
#  'time_period.n.01',
#  'topographic_point.n.01',
#  'purpose.n.01',
#  'recipient.n.01',
#  'beginning.n.04',
#  'speed.n.02',
#  'subject.n.01',
#  'time.n.01',
#  'vehicle.n.02',
#  'deliver.v.02',
#  'delivery.n.01',
#  '',
#  'motion.n.04',
#  'area.n.05',
#  'distance.n.03',
#  'duration.n.01',
#  'finish.n.04',
#  'transportation.n.02',
#  'path.n.04',
#  'beginning.n.04',
#  'speed.n.02',
#  'subject.n.01',
#  'time.n.01',
#  '']

# %%
#creo un array con solo i synsets name per ogni frame
list_synsets = [[],[],[],[],[]]
j = 0

for i in syn_name:
    if i != '' and j != 5:
        list_synsets[j].append(i)
    else:
        j += 1

# %%
list_synsets
# Out:
# [['certainty.n.01',
#   'concessive.a.01',
#   'content.n.05',
#   'degree.n.01',
#   'explanation.n.01',
#   'manner.n.01',
#   'topic.n.02',
#   'believe.v.01',
#   'certain.a.03',
#   'certainty.n.01',
#   'confidence.n.01',
#   'confident.a.01',
#   'convinced.a.02',
#   'doubt.n.02',
#   'doubt.v.02',
#   'know.v.01',
#   'positive.a.01',
#   'skeptic.n.01',
#   'incredulity.n.01',
#   'certain.a.02',
#   'trust.v.01',
#   'uncertain.a.02',
#   'uncertainty.n.01'],
#  ['point.n.02',
#   'descriptor.n.01',
#   'detonator.n.01',
#   'name.n.01',
#   'localization.n.01'],
#  ['breathing.n.01',
#   'agentive_role.n.01',
#   'air.n.01',
#   'context.n.02',
#   'degree.n.01',
#   'delineative.s.01',
#   'distance.n.03',
#   'duration.n.01',
#   'cause.n.01',
#   'finish.n.04',
#   'instrument.n.02',
#   'manner.n.01',
#   'means.n.01',
#   'path.n.04',
#   'place.n.13',
#   'purpose.n.01',
#   'beginning.n.04',
#   'time.n.02',
#   'blow.v.02',
#   'breath.n.01',
#   'breathe.v.01',
#   'exhalation.n.02',
#   'halitus.n.01',
#   'exhale.v.01',
#   'exhale.v.01',
#   'pant.v.01',
#   'puff.v.08',
#   'inhalation.n.01',
#   'inhalant.n.02',
#   'inhale.v.01',
#   'inhale.v.02',
#   'insufflate.v.02',
#   'pant.v.02',
#   'puff.v.01',
#   'respire.v.02',
#   'sigh.n.01',
#   'sigh.v.01',
#   'sigh.v.01'],
#  ['delivery.n.01',
#   'beneficiary.n.01',
#   'context.n.02',
#   'container.n.01',
#   'deliveryman.n.01',
#   'delineative.s.01',
#   'explanation.n.01',
#   'finish.n.04',
#   'manner.n.01',
#   'means.n.01',
#   'pant.v.01',
#   'time_period.n.01',
#   'topographic_point.n.01',
#   'purpose.n.01',
#   'recipient.n.01',
#   'beginning.n.04',
#   'speed.n.02',
#   'subject.n.01',
#   'time.n.01',
#   'vehicle.n.02',
#   'deliver.v.02',
#   'delivery.n.01'],
#  ['motion.n.04',
#   'area.n.05',
#   'distance.n.03',
#   'duration.n.01',
#   'finish.n.04',
#   'transportation.n.02',
#   'path.n.04',
#   'beginning.n.04',
#   'speed.n.02',
#   'subject.n.01',
#   'time.n.01']]

# %%
#Creo un array con le definizioni per ogni synset
def_list = [[],[],[],[],[]]

j = 0

for ss in list_synsets:
    for i in ss:
        if j != 5:
            s1 = wn.synset(i)
            def_list[j].append(s1.definition())
    j +=1

def_list
# Out:
# [['the state of being certain',
#   'of or pertaining to concession',
#   'the sum or range of what has been perceived, discovered, or learned',
#   'a position on a scale of intensity or amount or quality',
#   'a statement that makes something comprehensible by describing the relevant structure or operation or circumstances etc.',
#   'how something is done or how it happens',
#   'some situation or event that is thought about',
#   'accept as true; take to be true',
#   'established beyond doubt or question; definitely known',
#   'the state of being certain',
#   'freedom from doubt; belief in yourself and your abilities',
#   'having or marked by confidence or assurance',
#   'having a strong belief or conviction',
#   'uncertainty about the truth or factuality or existence of something',
#   'lack confidence in or have doubts about',
#   'be cognizant or aware of a fact or a specific piece of information; possess knowledge or information about',
#   'characterized by or displaying affirmation or acceptance or certainty etc.',
#   'someone who habitually doubts accepted beliefs',
#   'doubt about the truth of something',
#   'having or feeling no doubt or uncertainty; confident and assured',
#   'have confidence or faith in',
#   'not established beyond doubt; still undecided or unknown',
#   'being unsettled or in doubt or dependent on chance',
#   'the precise location of something; a spatially limited location',
#   'the phonological or orthographic sound or appearance of a word that can be used to describe or identify something',
#   'a mechanical or electrical explosive device or a small amount of explosive; can be used to initiate the reaction of a disrupting explosive',
#   'a language unit by which a person or thing is known',
#   'a determination of the place where something is',
#   'the bodily process of inhalation and exhalation; the process of taking in oxygen from inhaled air and releasing carbon dioxide by exhalation',
#   'the semantic role of the animate entity that instigates or causes the happening denoted by the verb in the clause',
#   'a mixture of gases (especially oxygen) required for breathing; the stuff that the wind consists of',
#   'the set of facts or circumstances that surround a situation or event',
#   'a position on a scale of intensity or amount or quality',
#   'depicted in a recognizable manner',
#   'size of the gap between two places',
#   'the period of time during which something continues',
#   'events that provide the generative force that is the origin of something',
#   'the place designated as the end (as of a race or journey)',
#   'the means whereby some act is accomplished',
#   'how something is done or how it happens',
#   'how a result is obtained or an end is achieved',
#   'a line or route along which something travels or moves',
#   'proper or appropriate position or location',
#   'an anticipated outcome that is intended or that guides your planned actions',
#   'the place where something begins, where it springs into being',
#   'a period of time considered as a resource under your control and sufficient to accomplish something',
#   'be blowing or storming',
#   'the process of taking in and expelling air during breathing',
#   'draw air into, and expel out of, the lungs',
#   'the act of expelling air from the lungs',
#   'exhaled breath',
#   'expel air',
#   'expel air',
#   'breathe noisily, as when one is exhausted',
#   'blow hard and loudly',
#   'the act of inhaling; the drawing in of air (or other gases) as in breathing',
#   'a medication to be taken by inhaling it',
#   'draw deep into the lungs in by breathing',
#   'draw in (air)',
#   'treat by blowing a powder or vapor into a bodily cavity',
#   'utter while panting, as if out of breath',
#   'smoke and exhale strongly',
#   'undergo the biomedical and metabolic processes of respiration by taking up oxygen and producing carbon monoxide',
#   'an utterance made by exhaling audibly',
#   'heave or utter a sigh; breathe deeply and heavily',
#   'heave or utter a sigh; breathe deeply and heavily',
#   'the act of delivering or distributing something (as goods or mail)',
#   'the recipient of funds or other benefits',
#   'the set of facts or circumstances that surround a situation or event',
#   'any object that can be used to hold things (especially a large metal boxlike object of standardized dimensions that can be loaded from one form of transport to another)',
#   'someone employed to make deliveries',
#   'depicted in a recognizable manner',
#   'a statement that makes something comprehensible by describing the relevant structure or operation or circumstances etc.',
#   'the place designated as the end (as of a race or journey)',
#   'how something is done or how it happens',
#   'how a result is obtained or an end is achieved',
#   'breathe noisily, as when one is exhausted',
#   'an amount of time',
#   'a point located with respect to surface features of some region',
#   'an anticipated outcome that is intended or that guides your planned actions',
#   'a person who receives something',
#   'the place where something begins, where it springs into being',
#   'a rate (usually rapid) at which something happens',
#   'the subject matter of a conversation or discussion',
#   'an instance or single occasion for some event',
#   'a medium for the expression or achievement of something',
#   'bring to a destination, make a delivery',
#   'the act of delivering or distributing something (as goods or mail)',
#   'a state of change',
#   'a part of a structure having some specific characteristic or function',
#   'size of the gap between two places',
#   'the period of time during which something continues',
#   'the place designated as the end (as of a race or journey)',
#   'the act of moving something from one location to another',
#   'a line or route along which something travels or moves',
#   'the place where something begins, where it springs into being',
#   'a rate (usually rapid) at which something happens',
#   'the subject matter of a conversation or discussion',
#   'an instance or single occasion for some event'],
#  [],
#  [],
#  [],
#  []]

# %% [markdown]
# Approccio Bag of Words (BoW)

# %%
from nltk.corpus import stopwords

def bag_of_word(sent):
    """Auxiliary function for the Lesk algorithm. Transforms the given sentence
    according to the bag of words approach, apply lemmatization, stop words
    and punctuation removal.
    Params:
        sent: sentence
    Returns:
        bag of words
    """

    stop_words = set(stopwords.words('english'))
    punctuation = {',', ';', '(', ')', '{', '}', ':', '?', '!'}
    # Returns the input word unchanged if it cannot be found in WordNet.
    wnl = nltk.WordNetLemmatizer()
    # Return a tokenized copy of text, using NLTK’s recommended word tokenizer (Treebank + PunkSentence)
    tokens = nltk.word_tokenize(sent)
    tokens = list(filter(lambda x: x not in stop_words and x not in punctuation, tokens))
    return set(wnl.lemmatize(t) for t in tokens)

# %%
#concateno le definizioni di ogni frame

j = 0
frase = ''
frase1 = ''
frase2 = ''
frase3 = ''
frase4 = ''

for d in def_list:
    for f in d:
        if j == 0:
            frase = frase + f + ' '
        if j == 1:
            frase1 = frase1 + f + ' '
        if j == 2:
            frase2 = frase2 + f + ' '
        if j == 3:
            frase3 = frase3 + f + ' '
        if j == 4:
            frase4 = frase4 + f + ' '
    j = j + 1

# %%
#Creo le BoW per ogni frase

Certainty_bow = bag_of_word(str(frase))
Firing_point_bow = bag_of_word(str(frase1))
Breathing_bow = bag_of_word(str(frase2))
Delivery_bow = bag_of_word(str(frase3))
Motion_scenario_bow = bag_of_word(str(frase4))

# %%
print(Certainty_bow)
print_sep()
print(Firing_point_bow)
print_sep()
print(Breathing_bow)
print_sep()
print(Delivery_bow)
print_sep()
print(Motion_scenario_bow)
# Out:
# {'happens', 'chance', 'thought', 'take', 'state', 'faith', 'intensity', 'comprehensible', 'describing', 'situation', 'freedom', 'aware', 'accept', 'make', 'known', 'concession', 'relevant', 'uncertainty', 'pertaining', 'habitually', 'posse', 'discovered', 'fact', 'someone', 'truth', 'ability', 'learned', 'marked', 'position', 'true', 'existence', 'operation', 'factuality', 'knowledge', 'acceptance', 'belief', 'unsettled', 'confident', 'accepted', 'unknown', 'assurance', 'done', 'structure', 'dependent', 'sum', 'strong', 'feeling', 'lack', 'assured', 'something', 'certain', 'piece', 'event', 'definitely', 'question', 'quality', 'characterized', 'conviction', 'beyond', 'undecided', 'affirmation', 'statement', 'certainty', 'range', 'established', 'specific', '.', 'circumstance', 'scale', 'cognizant', 'information', 'perceived', 'still', 'confidence', 'amount', 'doubt', 'etc', 'displaying'}
#
# _________________________________________________________
#
#
# {'used', 'place', 'person', 'precise', 'something', 'language', 'word', 'appearance', 'determination', 'unit', 'thing', 'small', 'limited', 'disrupting', 'identify', 'initiate', 'known', 'sound', 'describe', 'amount', 'phonological', 'spatially', 'explosive', 'device', 'orthographic', 'mechanical', 'electrical', 'reaction', 'location'}
#
# _________________________________________________________
#
#
# {'happens', 'producing', 'provide', 'especially', 'surround', 'continues', 'route', 'time', 'intensity', 'considered', 'two', 'gas', 'situation', 'inhaled', 'size', 'storming', 'line', 'deep', 'semantic', 'action', 'sigh', 'cause', 'guide', 'required', 'fact', 'expelling', 'depicted', 'location', 'noisily', 'breathing', 'result', 'process', 'accomplished', 'entity', 'end', 'expel', 'recognizable', 'oxygen', 'intended', 'hard', 'exhaled', 'taken', 'heave', 'accomplish', 'smoke', 'loudly', 'position', 'carbon', 'gap', 'obtained', 'breath', 'verb', 'journey', 'one', 'outcome', 'move', 'spring', 'instigates', 'force', 'undergo', 'bodily', 'respiration', 'set', 'monoxide', 'panting', 'releasing', 'biomedical', 'done', 'appropriate', 'wind', 'stuff', 'dioxide', 'happening', 'place', 'something', 'breathe', 'audibly', 'act', 'utterance', 'inhaling', 'blow', 'mixture', 'event', 'drawing', 'planned', 'blowing', 'race', 'exhalation', 'quality', 'achieved', 'designated', 'draw', 'deeply', 'lung', 'exhaling', 'clause', 'taking', 'utter', 'strongly', 'vapor', 'begin', 'sufficient', 'period', 'exhale', 'inhalation', 'powder', 'travel', 'animate', 'along', 'circumstance', 'mean', 'denoted', 'origin', 'treat', 'medication', 'role', 'scale', 'control', 'metabolic', 'manner', 'generative', 'consists', 'proper', 'resource', 'anticipated', 'exhausted', 'made', 'amount', 'air', 'heavily', 'cavity', 'whereby'}
#
# _________________________________________________________
#
#
# {'happens', 'especially', 'surround', 'time', 'comprehensible', 'describing', 'situation', 'expression', 'destination', 'make', 'relevant', 'action', 'object', 'guide', 'fact', 'depicted', 'noisily', 'large', 'result', 'good', 'someone', 'used', 'end', 'recognizable', 'region', 'intended', 'delivering', 'employed', 'rate', 'standardized', 'obtained', 'operation', 'journey', 'one', 'thing', 'feature', 'outcome', 'form', 'spring', 'boxlike', 'another', 'hold', 'set', 'metal', 'distributing', 'done', 'structure', 'respect', 'person', 'benefit', 'place', 'breathe', 'something', 'rapid', 'single', 'act', 'point', 'event', 'planned', 'fund', 'surface', 'race', 'usually', 'achieved', 'matter', 'designated', 'instance', 'transport', 'located', 'recipient', 'discussion', 'begin', 'statement', 'occasion', 'bring', '.', 'circumstance', 'conversation', 'manner', 'exhausted', 'anticipated', 'subject', 'achievement', 'dimension', 'receives', 'amount', 'mail', 'loaded', 'etc', 'medium', 'delivery'}
#
# _________________________________________________________
#
#
# {'happens', 'travel', 'occasion', 'end', 'specific', 'place', 'along', 'something', 'rate', 'rapid', 'state', 'single', 'continues', 'act', 'conversation', 'characteristic', 'time', 'route', 'gap', 'two', 'event', 'journey', 'one', 'race', 'move', 'size', 'usually', 'line', 'spring', 'designated', 'matter', 'another', 'instance', 'subject', 'function', 'discussion', 'part', 'begin', 'period', 'structure', 'change', 'moving', 'location'}

# %%
def get_wordnet_context(word):
    """
       Params:
            word: word for which we need to find meaning
       Returns:
            a dictionary of Synset associated to the given word
    """
    synsets = wn.synsets(word)
    ret = {}  # return variable

    for syns in synsets:
        if syns.examples():
            t = [syns.lemma_names()[0], syns.examples()[0]]
        else:
            t = [syns.lemma_names()[0], []]

            # 3 è una costante fornita dalla consegna,
            # non si considerano path più lunghi
            i = 0
            for hypo in syns.hyponyms():
                if i == 3:
                    break
                if hypo.lemma_names():
                    t.append(hypo.lemma_names()[0])
                if hypo.examples():
                    t.append(hypo.examples()[0])
                i += 1

            i = 0
            for hyper in syns.hypernyms():
                if i == 3:
                    break
                if hyper.lemma_names():
                    t.append(hyper.lemma_names()[0])
                if hyper.examples():
                    t.append(hyper.examples()[0])
                i += 1

        ret[syns.name()] = t

    return ret

# %%
my_list = ['Certainty', 'point', 'Breathing', 'Delivery', 'Motion']

# %%
for word in my_list:
    print(get_wordnet_context(word))
    print()
# Out:
# {'certainty.n.01': ['certainty', 'his certainty reassured the others'], 'certainty.n.02': ['certainty', 'his victory is a certainty']}
#
# {'point.n.01': ['point', 'a point is defined by its coordinates'], 'point.n.02': ['point', 'she walked to a point where she could survey the whole street'], 'point.n.03': ['point', 'get to the point'], 'detail.n.01': ['detail', 'several of the details are similar'], 'degree.n.02': ['degree', 'a remarkable degree of frankness'], 'point.n.06': ['point', 'at that point I had to leave'], 'point.n.07': ['point', 'what is the point of discussing it?'], 'point.n.08': ['point', "the cannibal's teeth were filed to sharp points"], 'point.n.09': ['point', 'a row of points'], 'point.n.10': ['point', 'he scored 20 points in the first half'], 'point.n.11': ['point', 'they sailed south around the point'], 'item.n.01': ['item', 'he noticed an item in the New York Times'], 'point.n.13': ['point', [], 'relevance'], 'point.n.14': ['point', 'his acting was one of the high points of the movie'], 'point.n.15': ['point', 'he stuck the point of the knife into a tree'], 'compass_point.n.01': ['compass_point', 'he checked the point on his compass'], 'point.n.17': ['point', [], 'linear_unit'], 'point.n.18': ['point', [], 'loan'], 'period.n.07': ['period', 'in England they call a period a stop'], 'point.n.20': ['point', 'the point of the arrow was due north'], 'decimal_point.n.01': ['decimal_point', [], 'mathematical_notation'], 'point.n.22': ['point', [], 'taper'], 'point.n.23': ['point', 'he knows my bad points as well as my good points'], 'point.n.24': ['point', 'he held me up at the point of a gun'], 'point.n.25': ['point', [], 'wall_socket'], 'distributor_point.n.01': ['distributor_point', [], 'contact', 'they forget to solder the contacts'], 'indicate.v.02': ['indicate', 'I showed the customer the glove section'], 'orient.v.01': ['orient', 'The weather vane points North'], 'charge.v.17': ['charge', 'point a gun'], 'steer.v.01': ['steer', [], 'channel', 'channel information towards a broad audience', 'conn', 'corner', 'control', 'control the budget'], 'bespeak.v.01': ['bespeak', 'These symptoms indicate a serious illness'], 'luff.v.01': ['luff', [], 'sail', 'I love sailing, especially on the open sea'], 'point.v.07': ['point', [], 'tag', 'label these bottles'], 'point.v.08': ['point', 'point the letter'], 'point.v.09': ['point', [], 'tag', 'label these bottles'], 'point.v.10': ['point', 'The gun points with ease'], 'target.v.01': ['target', "He aimed his fists towards his opponent's face"], 'point.v.12': ['point', 'the dog pointed the dead duck'], 'sharpen.v.07': ['sharpen', 'The candles are tapered'], 'point.v.14': ['point', 'point a chimney']}
#
# {'breathing.n.01': ['breathing', [], 'abdominal_breathing', 'abdominal breathing is practiced by singers', 'artificial_respiration', 'eupnea', 'bodily_process', 'respiratory activity'], 'breathe.v.01': ['breathe', 'I can breathe better when the air is clean'], 'breathe.v.02': ['breathe', 'Every creature that breathes'], 'breathe.v.03': ['breathe', 'He breathed new life into the old house'], 'breathe.v.04': ['breathe', 'Our new synthetic fabric breathes and is perfect for summer wear'], 'breathe.v.05': ['breathe', 'not breathe a word'], 'breathe.v.06': ['breathe', 'She breathes the Christian spirit'], 'rest.v.02': ['rest', [], 'pause', 'We pause for station identification'], 'breathe.v.08': ['breathe', 'This rare Bordeaux must be allowed to breathe for at least 2 hours'], 'emit.v.01': ['emit', [], 'bubble', 'The soup was bubbling', 'burp', 'In China it is polite to burp at the table', 'exhale', 'The chimney exhales a thick smoke', 'exhaust', 'combustion products are exhausted in the engine'], 'breathing.a.01': ['breathing', 'the boy was disappointed to find only skeletons instead of living breathing dinosaurs']}
#
# {'delivery.n.01': ['delivery', 'his reluctant delivery of bad news'], 'delivery.n.02': ['delivery', 'she had a difficult delivery'], 'manner_of_speaking.n.01': ['manner_of_speaking', 'his manner of speaking was quite abrupt'], 'delivery.n.04': ['delivery', [], 'bailment', 'surrender', 'conveyance'], 'pitch.n.02': ['pitch', [], 'balk', 'ball', 'he threw nine straight balls before the manager yanked him', 'beanball', 'throw', 'the catcher made a good throw to second base'], 'rescue.n.01': ['rescue', 'work is the deliverance of mankind'], 'delivery.n.07': ['delivery', [], 'breech_delivery', 'cesarean_delivery', 'forceps_delivery', 'act']}
#
# {'gesture.n.02': ['gesture', [], 'beck', 'bow', 'curtsy', 'visual_communication'], 'movement.n.03': ['movement', [], 'approach', 'bending', 'Brownian_movement', 'happening'], 'motion.n.03': ['motion', 'the reflex motion of his eyebrows revealed his surprise'], 'motion.n.04': ['motion', 'they were in a state of steady motion'], 'motion.n.05': ['motion', 'he made a motion to adjourn'], 'motion.n.06': ['motion', 'police controlled the motion of the crowd'], 'apparent_motion.n.01': ['apparent_motion', 'the cinema relies on apparent motion'], 'gesticulate.v.01': ['gesticulate', 'He gestured his desire to leave']}

# %%
import csv
import re
from pathlib import Path

import nltk
from nltk.corpus import framenet as fn
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
wnl = nltk.WordNetLemmatizer()

def clean_word(word):
    stop_words = set(stopwords.words('english'))
    word = re.sub('[^A-Za-z0-9 ]+', '', word)
    # Returns the input word unchanged if it cannot be found in WordNet.
    wnl = nltk.WordNetLemmatizer()
    if word not in stop_words:
        return wnl.lemmatize(word)
    return ""


def get_main_clause(frame_name):
    """Get of the main clause from the frame name ("reggente").
    Params:
        frame_name: the name of the frame
    Returns:
         the main clause inside the frame name
    """
    tokens = nltk.word_tokenize(re.sub('_', ' ', frame_name))
    tokens = nltk.pos_tag(tokens)

    for elem in reversed(tokens):
        if elem[1] == "NN" or elem[1] == "NNS":
            return elem[0]
        
def populate_contexts(f, mode: str):
    """It populates 2 disambiguation context (one for Framenet and one for Wordnet)
    given a frame name.
    Params:
        frame: the frame name.
        mode: a string indicating the way to create context the possibility are: "Frame name", "FEs" and "LUs".
    Returns:
         two list (context_w, context_s) representing the populated contexts.
    """
    context_w = []  # the Framenet context
    context_s = []  # the Wordnet context

    if mode == "Frame name":
        if "Motion" in f.name:
            main_clause = "Motion"
        elif "_" in f.name:
            main_clause = get_main_clause(f.name)
        else:
            main_clause = f.name
        # The context in this case contains the frame name and his definition.
        context_w = [main_clause, f.definition]

        print(context_w)
        # Here, the context is a list of synset associated to the frame name.
        # In each synset are usually present word, glosses and examples.
        context_s = get_wordnet_context(main_clause)

    elif mode == "FEs":
        # Populating ctx_w for FEs
        for key in sorted(f.FE):
            if "_" in key:
                main_clause = get_main_clause(key)
            else:
                main_clause = key
            fe = f.FE[key]
            context_w.append([main_clause, fe.definition])

            # appending the value to ctx_s list.
            context_s.append(get_wordnet_context(main_clause))

    elif mode == "LUs":
        # Populating ctx_w for LUs
        for key in sorted(f.lexUnit):
            lu_key = re.sub('\.[a-z]+', '', key)
            context_w.append(lu_key)

            # appending the value to ctx_s list.
            context_s.append(get_wordnet_context(lu_key))
        

    return context_w, context_s

def bag_of_words(ctx_fn, ctx_wn):
    """ Given two disambiguation context, it returns the best sense using the
     bag of words mapping between the input arguments.
    Params:
        sent: sentence
    Returns:
        the best sense
    """
    sentences_fn = set()  # set of all Framenet FEs and their descriptions
    sentences_wn = {}  # dictionary of all Wordnet sysnset, glosses and examples.
    temp_max = -1
    ret = False

    for sentence in ctx_fn:
        for word in sentence.split():
            word_clean = clean_word(word)
            sentences_fn.add(word_clean)

    # transform the ctx_w dictionary into a set, in order to compute
    # intersection.
    for key in ctx_wn:  # for each WN synset
        temp_set = set()
        for sentence in ctx_wn[key]:  # for each sentence inside WN synset
            if sentence:
                for word in sentence.split():
                    #print(f"Parola da pulire {word}")
                    word = clean_word(word)
                    #print(f"Parola da pulita {word}")
                    temp_set.add(word)  # add words to temp_set

        # computing intersection between temp_set and sentences_fn.
        # Putting the result inside sentences_wn[key].
        # Each entry in sentences_wn will have the cardinality of the
        # intersection as his "score" at the first position.
        sentences_wn[key] = (len(temp_set & sentences_fn), temp_set)

        # update max score and save the associated sentence.
        if temp_max < sentences_wn[key][0]:
            temp_max = sentences_wn[key][0]
            ret = (key, sentences_wn[key])

    # return the best sense maximizing the score
    if ret:
        return ret[0]
    else:
        return None
    
def evaluate_performance(gold_path, out_path, none=True):
    """
    Doing output evaluation and print the result on the console.
    If none = False it is not considering none while counting matching
    Parameters
    ----------
    gold_path
    out_path
    none
    """

    test = 0
    with open(out_path, "r", encoding="utf-8") as results:
        reader_golden = read_correct_synsets(gold_path)
        reader_results = csv.reader(results, delimiter=',')

        items_in_results = []  # list of items in results
        items_in_golden = []  # list of items in gold

        for line_out in reader_results:
            items_in_results.append(line_out[-1])

        for elem in reader_golden:
            # Unwrapping the synset
            start = 'Synset(‘'
            end = '’)'

            if elem == 'None':
                items_in_golden.append(elem)
                #pass
            else:
                items_in_golden.append(find_between(elem, start, end))

        # counting equal elements
        index = 0
        contatore = 0
        print(len(items_in_golden))
        print(items_in_golden)
        print(len(items_in_results))
        print(items_in_results)
        while index < len(items_in_golden):
            if (items_in_results[index] == 'None' or items_in_golden[index] == 'None') and none==False:
                print('None')
                pass
            else:
                contatore += 1
                result = items_in_results[index]
                gold = items_in_golden[index]
            print(f'risultato:{result} ---- golden:{gold}')
            if result == gold:
                test += 1
            index += 1

        total_len = contatore

    print("\nPrecision: {0} / {1} Synsets -> {2:.2f} %".format(test, total_len, (test / total_len) * 100))

# %%
#Test del Frame Name

context_w = []  # the Framenet context
context_s = []  # the Wordnet context


frame_ids = get_frame_set_for_student('Demaria')
for fID in frame_ids:
    frame = fn.frame_by_id(fID)
    
frame.name

if "Motion" in frame.name:
    main_clause = "Motion"
elif "_" in frame.name:
    main_clause = get_main_clause(frame.name)
else:
    main_clause = frame.name
# The context in this case contains the frame name and his definition.
context_w = [main_clause, frame.definition]

print(context_w)
# Here, the context is a list of synset associated to the frame name.
# In each synset are usually present word, glosses and examples.
context_s = get_wordnet_context(main_clause)
print(context_s)
# Out:
# student: Demaria
# 	ID:  141	frame: Certainty
# 	ID: 2662	frame: Firing_point
# 	ID:  272	frame: Breathing
# 	ID: 1344	frame: Delivery
# 	ID:  238	frame: Motion_scenario
# ['Motion', 'This frame binds together the various parts of movement, from setting out, to traveling, to arriving.']
# {'gesture.n.02': ['gesture', [], 'beck', 'bow', 'curtsy', 'visual_communication'], 'movement.n.03': ['movement', [], 'approach', 'bending', 'Brownian_movement', 'happening'], 'motion.n.03': ['motion', 'the reflex motion of his eyebrows revealed his surprise'], 'motion.n.04': ['motion', 'they were in a state of steady motion'], 'motion.n.05': ['motion', 'he made a motion to adjourn'], 'motion.n.06': ['motion', 'police controlled the motion of the crowd'], 'apparent_motion.n.01': ['apparent_motion', 'the cinema relies on apparent motion'], 'gesticulate.v.01': ['gesticulate', 'He gestured his desire to leave']}

# %%
#Test dei FEs

context_w = []  # the Framenet context (now a list of list)
context_s = []  # the Wordnet context (now a list of dict)

frame_ids = get_frame_set_for_student('Demaria')
for fID in frame_ids:
    frame = fn.frame_by_id(fID)
    
for i in sorted(frame.FE):
    if "_" in i:
        main_clause = get_main_clause(i)
    else:
        main_clause = i
# The context in this case contains the frame name and his definition.
    fe = frame.FE[i]
    context_w.append([main_clause, fe.definition])

    
# Here, the context is a list of synset associated to the frame name.
# In each synset are usually present word, glosses and examples.
    context_s.append([get_wordnet_context(main_clause)])

print(context_w)
print()
print(context_s)
# Out:
# student: Demaria
# 	ID:  141	frame: Certainty
# 	ID: 2662	frame: Firing_point
# 	ID:  272	frame: Breathing
# 	ID: 1344	frame: Delivery
# 	ID:  238	frame: Motion_scenario
# [['Area', "The Area is the setting in which the Theme's movement takes place.   'Emily rose to her feet and moved restlessly around the room.'"], ['Cotheme', "The Cotheme is the second moving object, expressed as a direct object or an oblique.  'Pat accompanied me down the street.' 'The squirrel chased after the nut.'"], ['Distance', 'The Distance is any expression which characterizes the extent of motion.'], ['Duration', 'The amount of time for the movement is ongoing.'], ['Goal', "The Goal is the location the Theme ends up in.  'The car accelerated and moved into the slow lane, as he passed.'"], ['transportation', "The Mode_of_transportation expresses how the motion of the Theme is effected, by its body or by a vehicle which holds and conveys the Theme. Vehicles can move in any way and in any medium. They are usually expressed obliquely with 'in' or 'by'. "], ['Path', "The Path refers to (a part of the) ground that the Theme travels over or to a landmark the Theme travels past.  'The door opened , and he moved past Dad, into the hall.'"], ['Source', "The Source is the location the Theme initially occupies before its change of location.  'The policeman moved away from the door.'"], ['Speed', "The Speed is the rate at which motion occurs.  'The car moved along at 55 miles per hour.'"], ['Theme', "The Theme is the entity that changes location.   'The explosion made me move in a hurry.' "], ['Time', "This FE identifies the Time when the motion occurs.  'The truck moved at 10 o'clock.'"]]
#
# [[{'area.n.01': ['area', 'it was a mountainous area'], 'area.n.02': ['area', 'it was his area of specialization'], 'area.n.03': ['area', 'in the abdominal region'], 'sphere.n.01': ['sphere', 'his social sphere is limited'], 'area.n.05': ['area', 'the spacious cooking area provided plenty of room for servants'], 'area.n.06': ['area', 'the area of a rectangle']}], [{}], [{'distance.n.01': ['distance', [], 'elevation', 'there was snow at the higher elevations', 'farness', 'focal_distance', 'spacing'], 'distance.n.02': ['distance', 'I could see it in the distance'], 'distance.n.03': ['distance', 'the distance from New York to Chicago'], 'distance.n.04': ['distance', 'emotional distance'], 'distance.n.05': ['distance', 'the distance from birth to death'], 'distance.n.06': ['distance', 'if that happens it will be at some distance in the future'], 'distance.v.01': ['distance', 'we have to distance ourselves from these events in order to continue living'], 'outdistance.v.01': ['outdistance', 'He outdistanced the other runners']}], [{'duration.n.01': ['duration', [], 'clocking', 'it was a world record clocking', 'longueur', 'residence_time', 'time_period', 'a time period of 30 years'], 'duration.n.02': ['duration', [], 'time'], 'duration.n.03': ['duration', 'the ceremony was of short duration']}], [{'goal.n.01': ['goal', 'the ends justify the means'], 'finish.n.04': ['finish', 'a crowd assembled at the finish'], 'goal.n.03': ['goal', [], 'basket', 'net', 'game_equipment'], 'goal.n.04': ['goal', 'the winning goal came with less than a minute left to play']}], [{'transportation_system.n.01': ['transportation_system', [], 'air_transportation_system', 'highway_system', 'public_transit', 'facility', 'the assembly plant is an enormous facility'], 'transportation.n.02': ['transportation', [], 'airlift', 'carry', 'connection', 'the plane was late and he missed his connection in Atlanta', 'movement', 'the movement of cargo onto the vessel'], 'fare.n.02': ['fare', [], 'airfare', 'bus_fare', 'cab_fare', 'charge', 'the admission charge'], 'department_of_transportation.n.01': ['Department_of_Transportation', [], 'executive_department'], 'transportation.n.05': ['transportation', [], 'air_transportation', 'express', 'ferry', 'commercial_enterprise', 'computers are now widely used in business'], 'exile.n.03': ['exile', 'men in exile dream of hope']}], [{'way.n.05': ['way', 'the path of virtue'], 'path.n.02': ['path', [], 'bridle_path', 'crossing', 'lane', 'way', 'he said he was looking for the way out'], 'path.n.03': ['path', [], 'air_lane', 'beat', 'in the old days a policeman walked a beat and knew all his people by name', 'beeline', 'he made a beeline for the bathroom', 'line'], 'path.n.04': ['path', 'the hurricane demolished houses in its path']}], [{'beginning.n.04': ['beginning', 'the Italian beginning of the Renaissance'], 'source.n.02': ['source', 'the reporter had two sources for the story'], 'source.n.03': ['source', [], 'muse', 'Euterpe was his muse', 'taproot', 'the taproot of his resentment', 'inspiration'], 'source.n.04': ['source', [], 'Golconda', 'goldmine', 'facility', 'the assembly plant is an enormous facility'], 'informant.n.01': ['informant', [], 'informer', 'leaker', 'the president wanted to know who the leakers were', 'passive_source', 'communicator'], 'generator.n.03': ['generator', 'he was the generator of several complaints'], 'source.n.07': ['source', 'a heat source'], 'reservoir.n.04': ['reservoir', 'an infectious agent depends on a reservoir for its survival'], 'reference.n.08': ['reference', 'he carried an armful of references back to his desk'], 'source.v.01': ['source', 'She sourced a supply of carpet'], 'source.v.02': ['source', 'The writer carefully sourced her report']}], [{'speed.n.01': ['speed', [], 'airspeed', 'angular_velocity', 'escape_velocity', 'rate', 'they traveled at a rate of 55 miles per hour'], 'speed.n.02': ['speed', 'the project advanced with gratifying speed'], 'speed.n.03': ['speed', [], 'acceleratio ...

# %%
#Test dei FEs

context_w = []  # the Framenet context (now a list of list)
context_s = []  # the Wordnet context (now a list of dict)
LUs = []

frame_ids = get_frame_set_for_student('Demaria')
for fID in frame_ids:
    frame = fn.frame_by_id(fID)
    for i in sorted(frame.lexUnit):
        main_clause = i
        lu = frame.lexUnit[i]
        context_w.append([main_clause, lu.definition])
# Here, the context is a list of synset associated to the frame name.
# In each synset are usually present word, glosses and examples.
        context_s.append([get_wordnet_context(main_clause)])

print(context_w)
print()
print(context_s)
# Out:
# student: Demaria
# 	ID:  141	frame: Certainty
# 	ID: 2662	frame: Firing_point
# 	ID:  272	frame: Breathing
# 	ID: 1344	frame: Delivery
# 	ID:  238	frame: Motion_scenario
# [['believe.v', 'COD: feel sure of the truth of. '], ['certain.a', 'COD: completely convinced of something'], ['certainty.n', 'FN: the personal quality of being completely sure'], ['confidence.n', 'FN: the feeling of certainty about something'], ['confident.a', 'COD: feeling certainty about something'], ['convinced.a', 'FN: very certain of something.'], ['doubt.n', 'COD:  feeling of uncertainty or lack of conviction'], ['doubt.v', 'COD: feel uncertain about. '], ['doubtful.a', 'COD: uncertain. '], ['dubious.a', 'COD: hesitating or doubting'], ['know.v', 'FN: to hold a belief with confidence of its truth. Only in Certainty when there is contrastive stress on target; otherwise, belongs in Awareness.'], ['positive.a', 'COD: with no possibility of doubt; certain'], ['skeptic.n', 'COD: a person inclined to question or doubt accepted opinions.'], ['skeptical.a', 'FN: reserving judgement as to the truth of.'], ['skepticism.n', 'FN: a careful attitude of reserving judgement on the veractiy of. '], ['sure.a', 'COD: completely confident that one is right'], ['trust.v', 'FN: hold a belief'], ['uncertain.a', 'COD: not completely confident or sure'], ['uncertainty.n', 'FN: the state of being not completely confident or sure'], ['unsure.a', 'COD: lacking confidence'], ['firing point.n', 'FN: location from which a remote detonated bomb is activated.'], ['blow.v', 'COD: expel air through pursed lips.'], ['breath.n', 'COD: an inhalation or exhalation of air from the lungs. '], ['breathe.v', 'COD: take air into the lungs and then expel it as a regular physiological process. '], ['exhalation [act].n', 'FN: the act of breathing out.'], ['exhalation.n', 'FN: air expelled by breathing out.'], ['exhale.v', 'COD: breathe out.'], ['expire.v', 'COD:  exhale (air) from the lung.'], ['gasp.v', "COD: catch one's breath with an open mouth, owing to pain or astonishment. strain to obtain (air) by gasping. "], ['huff.v', 'COD: blow out noisily.'], ['inhalation [breath].n', 'FN: air which is taken in.'], ['inhalation.n', 'FN: the act of breathing in.'], ['inhale.v', 'COD: breathe in.'], ['inspire.v', 'FN: inhale'], ['insufflate.v', 'COD: blow or breathe (vapour, a powdered medicine, etc.) into or through a body cavity. '], ['pant.v', 'COD: breathe with short, quick breaths, typically from exertion or excitement.'], ['puff.v', 'COD: breathe in repeated short gasps'], ['respire.v', 'COD: breathe'], ['sigh.n', 'COD:  a long, deep, audible exhalation expressing sadness, tiredness, relief, etc. '], ['sigh.v', 'COD: emit a sigh'], ['suspire.v', 'COD: breathe'], ['deliver.v', 'FN: bring and hand over to the appropriate recipient.'], ['delivery.n', 'COD: the action of delivering something, especially letters or goods.']]
#
# [[{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}], [{}]]

# %%
if __name__ == "__main__":
    correct_synsets_path = Path('.')
    output_path = Path('.') / 'output'
    surnames = ['Demaria']
    fn_modes = ["Frame name", "FEs", "LUs"]

    with open(output_path / 'task2_results_no_stop.csv', "w", encoding="utf-8") as out:

        print("Assigning Synsets...")

        for surname in surnames:
            frame_ids = get_frame_set_for_student(surname)
            out.write("Student {0},\n".format(surname))
            # Retrive gold annotation
            surname_path = correct_synsets_path / (surname + '.txt')
            read_correct_synsets(surname_path)

            for fID in frame_ids:
                frame = fn.frame_by_id(fID)
                # calculate context of FN: ctx_w and WN: ctx_s
                ctx_w, ctx_s = populate_contexts(f=frame, mode=fn_modes[0])
                sense_name = bag_of_words(ctx_fn=ctx_w, ctx_wn=ctx_s)
                # Write it to file
                out.write("{0}, {1}, Wordnet Synset, {2}\n".format(fn_modes[0], frame.name, sense_name))

                # TODO
                ctx_w_FE, ctx_s_FE = populate_contexts(f=frame, mode=fn_modes[1])
                for (i,j) in zip(ctx_w_FE, ctx_s_FE):
                    sense_name = bag_of_words(ctx_fn=i, ctx_wn=j)
                    out.write("{0}, {1}, Wordnet Synset, {2}\n".format(fn_modes[1], i[0], sense_name))

                ctx_w_LU, ctx_s_LU = populate_contexts(f=frame, mode=fn_modes[2])
                for (i,j) in zip(ctx_w_LU, ctx_s_LU):
                    sense_name = bag_of_words(ctx_fn=i, ctx_wn=j)
                    out.write("{0}, {1}, Wordnet Synset, {2}\n".format(fn_modes[2], i[0], sense_name))

    evaluate_performance(gold_path=surname_path, out_path=path)
# Out:
# Assigning Synsets...
#
# student: Demaria
# 	ID:  141	frame: Certainty
# 	ID: 2662	frame: Firing_point
# 	ID:  272	frame: Breathing
# 	ID: 1344	frame: Delivery
# 	ID:  238	frame: Motion_scenario
# ['Certainty', "This frame concerns a Cognizer's certainty about the correctness of beliefs  or expectations. It only includes uses where a Cognizer is expressed.  'Lermontov was certain he would come to the party.'"]
# ['point', "A location from which a Detonator activates a distantly-located explosive device.  'Locating the firing point of remote control IEDs is no easy task.'  'The first task is to determine where he located his firing point.'"]
# ['Breathing', "An Agent causes Air to move in a direction, usually specifying either in or out of the body.  'Lee breathed the hot desert air.'"]
# ['Delivery', "A Deliverer hands off a Theme to a Recipient or (more indirectly) a Goal location, which is accessible to the Recipient.    'The staff of Ebags delivered the umbrella well ahead of schedule.'  'In each class a dove flew in and delivered a red rose to Ginny.'  'The Pontifical Delegation for the delivery of the Icon of the Kazan Mother of God will arrive tomorrow. '"]
# ['Motion', 'This frame binds together the various parts of movement, from setting out, to traveling, to arriving.']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-53-e3526242f08e> in <module>
#      35                     out.write("{0}, {1}, Wordnet Synset, {2}\n".format(fn_modes[2], i[0], sense_name))
#      36
# ---> 37     evaluate_performance(gold_path=surname_path, out_path=path)
#
# <ipython-input-46-40891be8801a> in evaluate_performance(gold_path, out_path)
#     151
#     152     test = 0
# --> 153     with open(out_path, "r", encoding="utf-8") as results:
#     154         reader_golden = read_correct_synsets(gold_path)
#     155         reader_results = csv.reader(results, delimiter=',')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/task2_results_Demaria.csv'

# %%
if __name__ == "__main__":
    correct_synsets_path = Path('.')
    output_path = Path('.') / 'output'
    surnames = ['Demaria']
    fn_modes = ["Frame name", "FEs", "LUs"]
    syn = []

    print("Assigning Synsets...")

    for surname in surnames:
        path = output_path / f'task2_results_{surname}.csv'
        with open(path, "w", encoding="utf-8") as out:

            frame_ids = get_frame_set_for_student(surname)
            # Retrive gold annotation
            surname_path = correct_synsets_path / (surname + '.txt')

            for fID in frame_ids:
                frame = fn.frame_by_id(fID)
                # calculate context of FN: ctx_w and WN: ctx_s
                ctx_w, ctx_s = populate_contexts(f=frame, mode=fn_modes[0])
                sense_name = bag_of_words(ctx_fn=ctx_w, ctx_wn=ctx_s)
                # Write it to file
                out.write("{0}, {1},Wordnet Synset,{2}\n".format(fn_modes[0], frame.name, sense_name))
                syn.append(str(sense_name))

                # Implemented (Demaria)
                ctx_w, ctx_s = populate_contexts(f=frame, mode=fn_modes[1])
                for (i, j) in zip(ctx_w, ctx_s):
                    sense_name = bag_of_words(ctx_fn=i, ctx_wn=j)
                    out.write("{0}, {1},Wordnet Synset,{2}\n".format(fn_modes[1][:-1], i[0], sense_name))
                    syn.append(str(sense_name))

                # Implemented (Gianotti)
                ctx_w_LU, ctx_s_LU = populate_contexts(f=frame, mode=fn_modes[2])
                for (i, j) in zip(ctx_w_LU, ctx_s_LU):
                    sense_name = bag_of_words(ctx_fn=i, ctx_wn=j)
                    out.write("{0}, {1},Wordnet Synset,{2}\n".format(fn_modes[2][:-1], i, sense_name))
                    syn.append(str(sense_name))

        evaluate_performance(gold_path=surname_path, out_path=path)
# Out:
# Assigning Synsets...
#
# student: Demaria
# 	ID:  141	frame: Certainty
# 	ID: 2662	frame: Firing_point
# 	ID:  272	frame: Breathing
# 	ID: 1344	frame: Delivery
# 	ID:  238	frame: Motion_scenario
# ['Certainty', "This frame concerns a Cognizer's certainty about the correctness of beliefs  or expectations. It only includes uses where a Cognizer is expressed.  'Lermontov was certain he would come to the party.'"]
# ['point', "A location from which a Detonator activates a distantly-located explosive device.  'Locating the firing point of remote control IEDs is no easy task.'  'The first task is to determine where he located his firing point.'"]
# ['Breathing', "An Agent causes Air to move in a direction, usually specifying either in or out of the body.  'Lee breathed the hot desert air.'"]
# ['Delivery', "A Deliverer hands off a Theme to a Recipient or (more indirectly) a Goal location, which is accessible to the Recipient.    'The staff of Ebags delivered the umbrella well ahead of schedule.'  'In each class a dove flew in and delivered a red rose to Ginny.'  'The Pontifical Delegation for the delivery of the Icon of the Kazan Mother of God will arrive tomorrow. '"]
# ['Motion', 'This frame binds together the various parts of movement, from setting out, to traveling, to arriving.']
# 111
# ['certainty.n.01', 'None', 'concessive.a.01', 'content.n.05', 'degree.n.01', 'explanation.n.01', 'None', 'manner.n.01', 'topic.n.02', 'believe.v.01', 'certain.a.03', 'certainty.n.01', 'confidence.n.01', 'confident.a.01', 'convinced.a.02', 'doubt.n.02', 'doubt.v.02', 'None', 'None', 'know.v.01', 'positive.a.01', 'skeptic.n.01', 'None', 'incredulity.n.01', 'certain.a.02', 'trust.v.01', 'uncertain.a.02', 'uncertainty.n.01', 'None', 'point.n.02', 'descriptor.n.01', 'detonator.n.01', 'None', 'name.n.01', 'localization.n.01', 'None', 'breathing.n.01', 'agentive_role.n.01', 'air.n.01', 'context.n.02', 'degree.n.01', 'delineative.s.01', 'distance.n.03', 'duration.n.01', 'cause.n.01', 'finish.n.04', 'instrument.n.02', 'None', 'manner.n.01', 'means.n.01', 'path.n.04', 'place.n.13', 'purpose.n.01', 'beginning.n.04', 'time.n.02', 'blow.v.02', 'breath.n.01', 'breathe.v.01', 'exhalation.n.02', 'halitus.n.01', 'exhale.v.01', 'exhale.v.01', 'pant.v.01', 'puff.v.08', 'inhalation.n.01', 'inhalant.n.02', 'inhale.v.01', 'inhale.v.02', 'insufflate.v.02', 'pant.v.02', 'puff.v.01', 'respire.v.02', 'sigh.n.01', 'sigh.v.01', 'sigh.v.01', 'delivery.n.01', 'beneficiary.n.01', 'context.n.02', 'container.n.01', 'None', 'deliveryman.n.01', 'delineative.s.01', 'None', 'explanation.n.01', 'finish.n.04', 'manner.n.01', 'means.n.01', 'pant.v.01', 'time_period.n.01', 'topographic_point.n.01', 'purpose.n.01', 'recipient.n.01', 'beginning.n.04', 'speed.n.02', 'subject.n.01', 'time.n.01', 'vehicle.n.02', 'deliver.v.02', 'delivery.n.01', 'motion.n.04', 'area.n.05', 'None', 'distance.n.03', 'duration.n.01', 'finish.n.04', 'transportation.n.02', 'path.n.04', 'beginning.n.04', 'speed.n.02', 'subject.n.01', 'time.n.01']
# 111
# ['certainty.n.01', 'None', 'concessive.a.01', 'content.v.02', 'degree.n.01', 'explanation.n.01', 'None', 'manner.n.01', 'subject.n.01', 'believe.v.01', 'certain.s.01', 'certainty.n.01', 'assurance.n.01', 'confident.a.01', 'convert.v.09', 'doubt.n.01', 'doubt.n.01', 'doubtful.s.01', 'doubtful.s.02', 'know.n.01', 'positive.a.01', 'skeptic.n.01', 'disbelieving.s.01', 'incredulity.n.01', 'certain.a.02', 'trust.n.01', 'uncertain.a.01', 'uncertainty.n.01', 'diffident.a.02', 'point.n.10', 'form.n.01', 'detonator.n.01', 'point.v.10', 'name.n.01', 'location.n.01', 'None', 'breathe.v.01', 'agent.n.01', 'air.n.02', 'circumstance.n.01', 'degree.n.01', 'delineative.s.01', 'distance.n.01', 'duration.n.01', 'cause.n.01', 'goal.n.01', 'instrument.n.01', 'cause.n.01', 'manner.n.01', 'means.n.01', 'way.n.05', 'topographic_point.n.01', 'purpose.n.01', 'beginning.n.04', 'clock_time.n.01', 'blow.n.01', 'breath.n.01', 'breathe.v.01', 'None', 'halitus.n.01', 'exhale.v.01', 'die.v.01', 'gasp.n.01', 'huff.n.01', 'None', 'inhalation.n.01', 'inhale.v.01', 'inspire.v.01', 'insufflate.v.01', 'pant.n.01', 'puff.n.01', 'respire.v.01', 'sigh.n.02', 'sigh.n.02', 'breathe.v.01', 'delivery.n.01', 'beneficiary.a.01', 'circumstance.n.01', 'container.n.01', 'None', 'deliverer.n.04', 'delineative.s.01', 'description.n.01', 'explanation.n.01', 'goal.n.01', 'manner.n.01', 'entail.v.01', 'path.n.03', 'iteration.n.01', 'topographic_point.n.01', 'purpose.n.01', 'recipient.n.01', 'source.v.02', 'travel_rapidly.v.01', 'subject.n.01', 'time.n.02', 'vehicle.n.02', 'deliver.v.01', 'delivery.n.01', 'movement.n.03', 'area.n.05', 'None', 'distance.n.01', 'duration.n.01', 'goal.n.01', 'transportation.n.05', 'way.n.05', 'source.v.02', 'speed.n.01', 'subject.n.01', 'time.v.02']
# risultato:certainty.n.01 ---- golden:certainty.n.01
# risultato:None ---- golden:None
# risultato:concessive.a.01 ---- golden:concessive.a.01
# risultato:content.v.02 ---- golden:content.n.05
# risultato:degree.n.01 ---- golden:degree.n.01
# risultato:explanation.n.01 ---- golden:explanation.n.01
# risultato:None ---- golden:None
# risultato:manner.n.01 ---- golden:manner.n.01
# risultato:subject.n.01 ---- golden:topic.n.02
# risultato:believe.v.01 ---- golden:believe.v.01
# risultato:certain.s.01 ---- golden:certain.a.03
# risultato:certainty.n.01 ---- golden:certainty.n.01
# risultato:assurance.n.01 ---- golden:confidence.n.01
# risultato:confident.a.01 ---- golden:confident.a.01
# risultato:convert.v.09 ---- golden:convinced.a.02
# risultato:doubt.n.01 ---- golden:doubt.n.02
# risultato:doubt.n.01 ---- golden:doubt.v.02
# risultato:doubtful.s.01 ---- golden:None
# risultato:doubtful.s.02 ---- golden:None
# risultato:know.n.01 ---- golden:know.v.01
# risultato:positive.a.01 ---- golden:positive.a.01
# risultato:skeptic.n.01 ---- golden:skeptic.n.01
# risultato:disbelieving.s.01 ---- golden:None
# risultato:incredulity.n.01 ---- golden:incredulity.n.01
# risultato:certain.a.02 ---- golden:certain.a.02
# risultato:trust.n.01 ---- golden:trust.v.01
# risultato:uncertain.a.01 ---- golden:uncertain.a.02
# risultato:uncertainty.n.01 ---- golden:uncertainty.n.01
# risultato:diffident.a.02 ---- golden:None
# risultato:point.n.10 ---- golden:point.n.02
# risultato:form.n.01 ---- golden:descriptor.n.01
# risultato:detonator.n.01 ---- golden:detonator.n.01
# risultato:point.v.10 ---- golden:None
# risultato:name.n.01 ---- golden:name.n.01
# risultato:location.n.01 ---- golden:localization.n.01
# risultato:None ---- golden:None
# risultato:breathe.v.01 ---- golden:breathing.n.01
# risultato:agent.n.01 ---- golden:agentive_role.n.01
# risultato:air.n.02 ---- golden:air.n.01
# risultato:circumstance.n.01 ---- golden:context.n.02
# risultato:degree.n.01 ---- golden:degree.n.01
# risultato:delineative.s.01 ---- golden:delineative.s.01
# risultato:distance.n.01 ---- golden:distance.n.03
# risultato:duration.n.01 ---- golden:duration.n.01
# risultato:cause.n.01 ---- golden:cause.n.01
# risultato:goal.n.01 ---- golden:finish.n.04
# risultato:instrument.n.01 ---- golden:instrument.n.02
# risultato:cause.n.01 ---- golden:None
# risultato:manner.n.01 ---- golden:manner.n.01
# risultato:means.n.01 ---- golden:means.n.01
# risultato:way.n.05 ---- golden:path.n.04
# risultato:topographic_point.n.01 ---- golden:place.n.13
# risultato:purpose.n.01 ---- golden:purpose.n.01
# risultato:beginning.n.04 ---- golden:beginning.n.04
# risultato:clock_time.n.01 ---- golden:time.n.02
# risultato:blow.n.01 ---- golden:blow.v.02
# risultato:breath.n.01 ---- golden:breath.n.01
# risultato:breathe.v.01 ---- golden:breathe.v.01
# risultato:None ---- golden:exhalation.n.02
# risultato:halitus.n.01 ---- golden:halitus.n.01
# risultato:exhale.v.01 ---- golden:exhale.v.01
# risultato:die.v.01 ---- golden:exhale.v.01
# risultato:gasp.n.01 ---- golden:pant.v.01
# risultato:huff.n.01 ---- golden:puff.v.08
# risultato:None ---- golden:inhalation.n.01
# risultato:inhalation.n.01 ---- golden:inhalant.n.02
# risultato:inhale.v.01 ---- golden:inhale.v.01
# risultato:inspire.v.01 ---- golden:inhale.v.02
# risultato:insufflate.v.01 ---- golden:insufflate.v.02
# risultato:pant.n.01 ---- golden:pant.v.02
# risultato:puff.n.01 ---- golden:puff.v.01
# risultato:respire.v.01 ---- golden:respire.v.02
# risultato:sigh.n.02 ---- golden:sigh.n.01
# risultato:sigh.n.02 ---- golden:sigh.v.01
# risultato:breathe.v.01 ---- golden:sigh.v.01
# risultato:delivery.n.01 ---- golden:delivery.n.01
# risultato:beneficiary.a.01 ---- golden:beneficiary.n.01
# risultato:circumstance.n.01 ---- golden:context.n.02
# risultato:container.n.01 ---- golden:container.n.01
# risultato:None ---- golden:None
# risultato:deliverer.n.04 ---- golden:deliveryman.n.01
# risultato:delineative.s.01 ---- golden:delineative.s.01
# risultato:description.n.01 ---- golden:None
# risultato:explanation.n.01 ---- golden:explanation.n.01
# risultato:goal.n.01 ---- golden:finish.n.04
# risultato:manner.n.01 ---- golden:manner.n.01
# risultato:entail.v.01 ---- golden:means.n.01
# risultato:path.n.03 ---- golden:pant.v.01
# risultato:iteration.n.01 ---- golden:time_period.n.01
# risultato:topographic_point.n.01 ---- golden:topographic_point.n.01
# risultato:purpose.n.01 ---- golden:purpose.n.01
# risultato:recipient.n.01 ---- golden:recipient.n.01
# risultato:source.v.02 ---- golden:beginning.n.04
# risultato:travel_rapidly.v.01 ---- golden:speed.n.02
# risultato:subject.n.01 ---- golden:subject.n.01
# risultato:time.n.02 ---- golden:time.n.01
# risultato:vehicle.n.02 ---- golden:vehicle.n.02
# risultato:deliver.v.01 ---- golden:deliver.v.02
# risultato:delivery.n.01 ---- golden:delivery.n.01
# risultato:movement.n.03 ---- golden:motion.n.04
# risultato:area.n.05 ---- golden:area.n.05
# risultato:None ---- golden:None
# risultato:distance.n.01 ---- golden:distance.n.03
# risultato:duration.n.01 ---- golden:duration.n.01
# risultato:goal.n.01 ---- golden:finish.n.04
# risultato:transportation.n.05 ---- golden:transportation.n.02
# risultato:way.n.05 ---- golden:path.n.04
# risultato:source.v.02 ---- golden:beginning.n.04
# risultato:speed.n.01 ---- golden:speed.n.02
# risultato:subject.n.01 ---- golden:subject.n.01
# risultato:time.v.02 ---- golden:time.n.01
#
# Precision: 47 / 111 Synsets -> 42.34 %

# %%
evaluate_performance(gold_path=surname_path, out_path=path, none=False)
# Out:
# 111
# ['certainty.n.01', 'None', 'concessive.a.01', 'content.n.05', 'degree.n.01', 'explanation.n.01', 'None', 'manner.n.01', 'topic.n.02', 'believe.v.01', 'certain.a.03', 'certainty.n.01', 'confidence.n.01', 'confident.a.01', 'convinced.a.02', 'doubt.n.02', 'doubt.v.02', 'None', 'None', 'know.v.01', 'positive.a.01', 'skeptic.n.01', 'None', 'incredulity.n.01', 'certain.a.02', 'trust.v.01', 'uncertain.a.02', 'uncertainty.n.01', 'None', 'point.n.02', 'descriptor.n.01', 'detonator.n.01', 'None', 'name.n.01', 'localization.n.01', 'None', 'breathing.n.01', 'agentive_role.n.01', 'air.n.01', 'context.n.02', 'degree.n.01', 'delineative.s.01', 'distance.n.03', 'duration.n.01', 'cause.n.01', 'finish.n.04', 'instrument.n.02', 'None', 'manner.n.01', 'means.n.01', 'path.n.04', 'place.n.13', 'purpose.n.01', 'beginning.n.04', 'time.n.02', 'blow.v.02', 'breath.n.01', 'breathe.v.01', 'exhalation.n.02', 'halitus.n.01', 'exhale.v.01', 'exhale.v.01', 'pant.v.01', 'puff.v.08', 'inhalation.n.01', 'inhalant.n.02', 'inhale.v.01', 'inhale.v.02', 'insufflate.v.02', 'pant.v.02', 'puff.v.01', 'respire.v.02', 'sigh.n.01', 'sigh.v.01', 'sigh.v.01', 'delivery.n.01', 'beneficiary.n.01', 'context.n.02', 'container.n.01', 'None', 'deliveryman.n.01', 'delineative.s.01', 'None', 'explanation.n.01', 'finish.n.04', 'manner.n.01', 'means.n.01', 'pant.v.01', 'time_period.n.01', 'topographic_point.n.01', 'purpose.n.01', 'recipient.n.01', 'beginning.n.04', 'speed.n.02', 'subject.n.01', 'time.n.01', 'vehicle.n.02', 'deliver.v.02', 'delivery.n.01', 'motion.n.04', 'area.n.05', 'None', 'distance.n.03', 'duration.n.01', 'finish.n.04', 'transportation.n.02', 'path.n.04', 'beginning.n.04', 'speed.n.02', 'subject.n.01', 'time.n.01']
# 111
# ['certainty.n.01', 'None', 'concessive.a.01', 'content.v.02', 'degree.n.01', 'explanation.n.01', 'None', 'manner.n.01', 'subject.n.01', 'believe.v.01', 'certain.s.01', 'certainty.n.01', 'assurance.n.01', 'confident.a.01', 'convert.v.09', 'doubt.n.01', 'doubt.n.01', 'doubtful.s.01', 'doubtful.s.02', 'know.n.01', 'positive.a.01', 'skeptic.n.01', 'disbelieving.s.01', 'incredulity.n.01', 'certain.a.02', 'trust.n.01', 'uncertain.a.01', 'uncertainty.n.01', 'diffident.a.02', 'point.n.10', 'form.n.01', 'detonator.n.01', 'point.v.10', 'name.n.01', 'location.n.01', 'None', 'breathe.v.01', 'agent.n.01', 'air.n.02', 'circumstance.n.01', 'degree.n.01', 'delineative.s.01', 'distance.n.01', 'duration.n.01', 'cause.n.01', 'goal.n.01', 'instrument.n.01', 'cause.n.01', 'manner.n.01', 'means.n.01', 'way.n.05', 'topographic_point.n.01', 'purpose.n.01', 'beginning.n.04', 'clock_time.n.01', 'blow.n.01', 'breath.n.01', 'breathe.v.01', 'None', 'halitus.n.01', 'exhale.v.01', 'die.v.01', 'gasp.n.01', 'huff.n.01', 'None', 'inhalation.n.01', 'inhale.v.01', 'inspire.v.01', 'insufflate.v.01', 'pant.n.01', 'puff.n.01', 'respire.v.01', 'sigh.n.02', 'sigh.n.02', 'breathe.v.01', 'delivery.n.01', 'beneficiary.a.01', 'circumstance.n.01', 'container.n.01', 'None', 'deliverer.n.04', 'delineative.s.01', 'description.n.01', 'explanation.n.01', 'goal.n.01', 'manner.n.01', 'entail.v.01', 'path.n.03', 'iteration.n.01', 'topographic_point.n.01', 'purpose.n.01', 'recipient.n.01', 'source.v.02', 'travel_rapidly.v.01', 'subject.n.01', 'time.n.02', 'vehicle.n.02', 'deliver.v.01', 'delivery.n.01', 'movement.n.03', 'area.n.05', 'None', 'distance.n.01', 'duration.n.01', 'goal.n.01', 'transportation.n.05', 'way.n.05', 'source.v.02', 'speed.n.01', 'subject.n.01', 'time.v.02']
# risultato:certainty.n.01 ---- golden:certainty.n.01
# None
# risultato:certainty.n.01 ---- golden:certainty.n.01
# risultato:concessive.a.01 ---- golden:concessive.a.01
# risultato:content.v.02 ---- golden:content.n.05
# risultato:degree.n.01 ---- golden:degree.n.01
# risultato:explanation.n.01 ---- golden:explanation.n.01
# None
# risultato:explanation.n.01 ---- golden:explanation.n.01
# risultato:manner.n.01 ---- golden:manner.n.01
# risultato:subject.n.01 ---- golden:topic.n.02
# risultato:believe.v.01 ---- golden:believe.v.01
# risultato:certain.s.01 ---- golden:certain.a.03
# risultato:certainty.n.01 ---- golden:certainty.n.01
# risultato:assurance.n.01 ---- golden:confidence.n.01
# risultato:confident.a.01 ---- golden:confident.a.01
# risultato:convert.v.09 ---- golden:convinced.a.02
# risultato:doubt.n.01 ---- golden:doubt.n.02
# risultato:doubt.n.01 ---- golden:doubt.v.02
# None
# risultato:doubt.n.01 ---- golden:doubt.v.02
# None
# risultato:doubt.n.01 ---- golden:doubt.v.02
# risultato:know.n.01 ---- golden:know.v.01
# risultato:positive.a.01 ---- golden:positive.a.01
# risultato:skeptic.n.01 ---- golden:skeptic.n.01
# None
# risultato:skeptic.n.01 ---- golden:skeptic.n.01
# risultato:incredulity.n.01 ---- golden:incredulity.n.01
# risultato:certain.a.02 ---- golden:certain.a.02
# risultato:trust.n.01 ---- golden:trust.v.01
# risultato:uncertain.a.01 ---- golden:uncertain.a.02
# risultato:uncertainty.n.01 ---- golden:uncertainty.n.01
# None
# risultato:uncertainty.n.01 ---- golden:uncertainty.n.01
# risultato:point.n.10 ---- golden:point.n.02
# risultato:form.n.01 ---- golden:descriptor.n.01
# risultato:detonator.n.01 ---- golden:detonator.n.01
# None
# risultato:detonator.n.01 ---- golden:detonator.n.01
# risultato:name.n.01 ---- golden:name.n.01
# risultato:location.n.01 ---- golden:localization.n.01
# None
# risultato:location.n.01 ---- golden:localization.n.01
# risultato:breathe.v.01 ---- golden:breathing.n.01
# risultato:agent.n.01 ---- golden:agentive_role.n.01
# risultato:air.n.02 ---- golden:air.n.01
# risultato:circumstance.n.01 ---- golden:context.n.02
# risultato:degree.n.01 ---- golden:degree.n.01
# risultato:delineative.s.01 ---- golden:delineative.s.01
# risultato:distance.n.01 ---- golden:distance.n.03
# risultato:duration.n.01 ---- golden:duration.n.01
# risultato:cause.n.01 ---- golden:cause.n.01
# risultato:goal.n.01 ---- golden:finish.n.04
# risultato:instrument.n.01 ---- golden:instrument.n.02
# None
# risultato:instrument.n.01 ---- golden:instrument.n.02
# risultato:manner.n.01 ---- golden:manner.n.01
# risultato:means.n.01 ---- golden:means.n.01
# risultato:way.n.05 ---- golden:path.n.04
# risultato:topographic_point.n.01 ---- golden:place.n.13
# risultato:purpose.n.01 ---- golden:purpose.n.01
# risultato:beginning.n.04 ---- golden:beginning.n.04
# risultato:clock_time.n.01 ---- golden:time.n.02
# risultato:blow.n.01 ---- golden:blow.v.02
# risultato:breath.n.01 ---- golden:breath.n.01
# risultato:breathe.v.01 ---- golden:breathe.v.01
# None
# risultato:breathe.v.01 ---- golden:breathe.v.01
# risultato:halitus.n.01 ---- golden:halitus.n.01
# risultato:exhale.v.01 ---- golden:exhale.v.01
# risultato:die.v.01 ---- golden:exhale.v.01
# risultato:gasp.n.01 ---- golden:pant.v.01
# risultato:huff.n.01 ---- golden:puff.v.08
# None
# risultato:huff.n.01 ---- golden:puff.v.08
# risultato:inhalation.n.01 ---- golden:inhalant.n.02
# risultato:inhale.v.01 ---- golden:inhale.v.01
# risultato:inspire.v.01 ---- golden:inhale.v.02
# risultato:insufflate.v.01 ---- golden:insufflate.v.02
# risultato:pant.n.01 ---- golden:pant.v.02
# risultato:puff.n.01 ---- golden:puff.v.01
# risultato:respire.v.01 ---- golden:respire.v.02
# risultato:sigh.n.02 ---- golden:sigh.n.01
# risultato:sigh.n.02 ---- golden:sigh.v.01
# risultato:breathe.v.01 ---- golden:sigh.v.01
# risultato:delivery.n.01 ---- golden:delivery.n.01
# risultato:beneficiary.a.01 ---- golden:beneficiary.n.01
# risultato:circumstance.n.01 ---- golden:context.n.02
# risultato:container.n.01 ---- golden:container.n.01
# None
# risultato:container.n.01 ---- golden:container.n.01
# risultato:deliverer.n.04 ---- golden:deliveryman.n.01
# risultato:delineative.s.01 ---- golden:delineative.s.01
# None
# risultato:delineative.s.01 ---- golden:delineative.s.01
# risultato:explanation.n.01 ---- golden:explanation.n.01
# risultato:goal.n.01 ---- golden:finish.n.04
# risultato:manner.n.01 ---- golden:manner.n.01
# risultato:entail.v.01 ---- golden:means.n.01
# risultato:path.n.03 ---- golden:pant.v.01
# risultato:iteration.n.01 ---- golden:time_period.n.01
# risultato:topographic_point.n.01 ---- golden:topographic_point.n.01
# risultato:purpose.n.01 ---- golden:purpose.n.01
# risultato:recipient.n.01 ---- golden:recipient.n.01
# risultato:source.v.02 ---- golden:beginning.n.04
# risultato:travel_rapidly.v.01 ---- golden:speed.n.02
# risultato:subject.n.01 ---- golden:subject.n.01
# risultato:time.n.02 ---- golden:time.n.01
# risultato:vehicle.n.02 ---- golden:vehicle.n.02
# risultato:deliver.v.01 ---- golden:deliver.v.02
# risultato:delivery.n.01 ---- golden:delivery.n.01
# risultato:movement.n.03 ---- golden:motion.n.04
# risultato:area.n.05 ---- golden:area.n.05
# None
# risultato:area.n.05 ---- golden:area.n.05
# risultato:distance.n.01 ---- golden:distance.n.03
# risultato:duration.n.01 ---- golden:duration.n.01
# risultato:goal.n.01 ---- golden:finish.n.04
# risultato:transportation.n.05 ---- golden:transportation.n.02
# risultato:way.n.05 ---- golden:path.n.04
# risultato:source.v.02 ---- golden:beginning.n.04
# risultato:speed.n.01 ---- golden:speed.n.02
# risultato:subject.n.01 ---- golden:subject.n.01
# risultato:time.v.02 ---- golden:time.n.01
#
# Precision: 51 / 97 Synsets -> 52.58 %

# %%
len(syn)
# Out:
# 111

# %%
while 'None' in syn:
    syn.remove('None')

# %%
len(syn)
# Out:
# 104

# %%
len(syn_name)
# Out:
# 104

# %%
syn == syn_name
# Out:
# False

# %%
new_syn = []
for (i, j) in zip(syn_name, syn):
    if i == '':
        new_syn.append('')
    else:
        new_syn.append(j)

# %%
#creo un array con solo i synsets name per ogni frame
new_list_synsets = [[],[],[],[],[]]
j = 0

for i in new_syn:
    if i != '' and j != 5:
        new_list_synsets[j].append(i)
    else:
        j += 1

# %%
new_list_synsets
# Out:
# [['certainty.n.01',
#   'concessive.a.01',
#   'content.v.02',
#   'degree.n.01',
#   'explanation.n.01',
#   'manner.n.01',
#   'subject.n.01',
#   'believe.v.01',
#   'certain.s.01',
#   'certainty.n.01',
#   'assurance.n.01',
#   'confident.a.01',
#   'convert.v.09',
#   'doubt.n.01',
#   'doubt.n.01',
#   'doubtful.s.01',
#   'doubtful.s.02',
#   'know.n.01',
#   'positive.a.01',
#   'skeptic.n.01',
#   'disbelieving.s.01',
#   'incredulity.n.01',
#   'certain.a.02'],
#  ['uncertain.a.01',
#   'uncertainty.n.01',
#   'diffident.a.02',
#   'point.n.10',
#   'form.n.01'],
#  ['point.v.10',
#   'name.n.01',
#   'location.n.01',
#   'breathe.v.01',
#   'agent.n.01',
#   'air.n.02',
#   'circumstance.n.01',
#   'degree.n.01',
#   'delineative.s.01',
#   'distance.n.01',
#   'duration.n.01',
#   'cause.n.01',
#   'goal.n.01',
#   'instrument.n.01',
#   'cause.n.01',
#   'manner.n.01',
#   'means.n.01',
#   'way.n.05',
#   'topographic_point.n.01',
#   'purpose.n.01',
#   'beginning.n.04',
#   'clock_time.n.01',
#   'blow.n.01',
#   'breath.n.01',
#   'breathe.v.01',
#   'halitus.n.01',
#   'exhale.v.01',
#   'die.v.01',
#   'gasp.n.01',
#   'huff.n.01',
#   'inhalation.n.01',
#   'inhale.v.01',
#   'inspire.v.01',
#   'insufflate.v.01',
#   'pant.n.01',
#   'puff.n.01',
#   'respire.v.01',
#   'sigh.n.02'],
#  ['breathe.v.01',
#   'delivery.n.01',
#   'beneficiary.a.01',
#   'circumstance.n.01',
#   'container.n.01',
#   'deliverer.n.04',
#   'delineative.s.01',
#   'description.n.01',
#   'explanation.n.01',
#   'goal.n.01',
#   'manner.n.01',
#   'entail.v.01',
#   'path.n.03',
#   'iteration.n.01',
#   'topographic_point.n.01',
#   'purpose.n.01',
#   'recipient.n.01',
#   'source.v.02',
#   'travel_rapidly.v.01',
#   'subject.n.01',
#   'time.n.02',
#   'vehicle.n.02'],
#  ['delivery.n.01',
#   'movement.n.03',
#   'area.n.05',
#   'distance.n.01',
#   'duration.n.01',
#   'goal.n.01',
#   'transportation.n.05',
#   'way.n.05',
#   'source.v.02',
#   'speed.n.01',
#   'subject.n.01']]

# %%
list_synsets==new_list_synsets
# Out:
# False

# %%
#Creo un array con le definizioni per ogni synset
new_def_list = [[],[],[],[],[]]

j = 0

for ss in new_list_synsets:
    for i in ss:
        if j != 5:
            s1 = wn.synset(i)
            new_def_list[j].append(s1.definition())
    j +=1

new_def_list
# Out:
# [['the state of being certain',
#   'of or pertaining to concession',
#   'make content',
#   'a position on a scale of intensity or amount or quality',
#   'a statement that makes something comprehensible by describing the relevant structure or operation or circumstances etc.',
#   'how something is done or how it happens',
#   'the subject matter of a conversation or discussion',
#   'accept as true; take to be true',
#   'definite but not specified or identified',
#   'the state of being certain',
#   'freedom from doubt; belief in yourself and your abilities',
#   'having or marked by confidence or assurance',
#   'make (someone) agree, understand, or realize the truth or validity of something',
#   'the state of being unsure of something',
#   'the state of being unsure of something',
#   'open to doubt or suspicion; ; ; ; - Karen Horney',
#   'fraught with uncertainty or doubt',
#   'the fact of being aware of information that is known to few people',
#   'characterized by or displaying affirmation or acceptance or certainty etc.',
#   'someone who habitually doubts accepted beliefs',
#   'denying or questioning the tenets of especially a religion',
#   'doubt about the truth of something',
#   'having or feeling no doubt or uncertainty; confident and assured'],
#  ['lacking or indicating lack of confidence or assurance',
#   'being unsettled or in doubt or dependent on chance',
#   'lacking self-confidence',
#   'the unit of counting in scoring a game or contest',
#   'the phonological or orthographic sound or appearance of a word that can be used to describe or identify something'],
#  ['be positionable in a specified manner',
#   'a language unit by which a person or thing is known',
#   'a point or extent in space',
#   'draw air into, and expel out of, the lungs',
#   'an active and efficient cause; capable of producing a certain effect',
#   'the region above the ground',
#   'a condition that accompanies or influences some event or activity',
#   'a position on a scale of intensity or amount or quality',
#   'depicted in a recognizable manner',
#   'the property created by the space between two objects or points',
#   'the period of time during which something continues',
#   'events that provide the generative force that is the origin of something',
#   'the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it',
#   'a device that requires skill for proper use',
#   'events that provide the generative force that is the origin of something',
#   'how something is done or how it happens',
#   'how a result is obtained or an end is achieved',
#   'a course of conduct',
#   'a point located with respect to surface features of some region',
#   'an anticipated outcome that is intended or that guides your planned actions',
#   'the place where something begins, where it springs into being',
#   'a reading of a point in time as given by a clock',
#   'a powerful stroke with the fist or a weapon',
#   'the process of taking in and expelling air during breathing',
#   'draw air into, and expel out of, the lungs',
#   'exhaled breath',
#   'expel air',
#   'pass from physical life and lose all bodily attributes and functions necessary to sustain life',
#   'a short labored intake of breath with the mouth open',
#   'a state of irritation or annoyance',
#   'the act of inhaling; the drawing in of air (or other gases) as in breathing',
#   'draw deep into the lungs in by breathing',
#   'heighten or intensify',
#   'breathe or blow onto as a ritual or sacramental act, especially so as to symbolize the action of the Holy Spirit',
#   'the noise made by a short puff of steam (as from an engine)',
#   'a short light gust of air',
#   'breathe easily again, as after exertion or anxiety',
#   'a sound like a person sighing'],
#  ['draw air into, and expel out of, the lungs',
#   'the act of delivering or distributing something (as goods or mail)',
#   'having or arising from a benefice',
#   'a condition that accompanies or influences some event or activity',
#   'any object that can be used to hold things (especially a large metal boxlike object of standardized dimensions that can be loaded from one form of transport to another)',
#   'a person who gives up or transfers money or goods',
#   'depicted in a recognizable manner',
#   'a statement that represents something in words',
#   'a statement that makes something comprehensible by describing the relevant structure or operation or circumstances etc.',
#   'the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it',
#   'how something is done or how it happens',
#   'have as a logical consequence',
#   'an established line of travel or access',
#   '(computer science) a single execution of a set of instructions that are to be repeated',
#   'a point located with respect to surface features of some region',
#   'an anticipated outcome that is intended or that guides your planned actions',
#   'a person who receives something',
#   'specify the origin of',
#   'move very fast',
#   'the subject matter of a conversation or discussion',
#   'a period of time considered as a resource under your control and sufficient to accomplish something',
#   'a medium for the expression or achievement of something'],
#  ['the act of delivering or distributing something (as goods or mail)',
#   'a natural event that involves a change in the position or location of something',
#   'a part of a structure having some specific characteristic or function',
#   'the property created by the space between two objects or points',
#   'the period of time during which something continues',
#   'the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it',
#   'the commercial enterprise of moving goods and materials',
#   'a course of conduct',
#   'specify the origin of',
#   'distance travelled per unit time',
#   'the subject matter of a conversation or discussion']]

# %%
#concateno le definizioni di ogni frame

j = 0
frase = ''
frase1 = ''
frase2 = ''
frase3 = ''
frase4 = ''

for d in new_def_list:
    for f in d:
        if j == 0:
            frase = frase + f + ' '
        if j == 1:
            frase1 = frase1 + f + ' '
        if j == 2:
            frase2 = frase2 + f + ' '
        if j == 3:
            frase3 = frase3 + f + ' '
        if j == 4:
            frase4 = frase4 + f + ' '
    j = j + 1

# %%
#Creo le BoW per ogni frase

new_Certainty_bow = bag_of_word(str(frase))
new_Firing_point_bow = bag_of_word(str(frase1))
new_Breathing_bow = bag_of_word(str(frase2))
new_Delivery_bow = bag_of_word(str(frase3))
new_Motion_scenario_bow = bag_of_word(str(frase4))

# %%
print(new_Certainty_bow)
print_sep()
print(new_Firing_point_bow)
print_sep()
print(new_Breathing_bow)
print_sep()
print(new_Delivery_bow)
print_sep()
print(new_Motion_scenario_bow)
# Out:
# {'happens', 'someone', 'truth', 'feeling', 'ability', 'Horney', '.', 'assured', 'tenet', 'marked', 'take', 'something', 'circumstance', 'especially', 'certain', 'state', 'content', 'conversation', 'position', 'intensity', 'realize', 'comprehensible', 'describing', 'true', 'operation', 'agree', 'open', 'scale', 'freedom', 'people', 'information', 'Karen', 'quality', 'accept', 'aware', 'matter', 'acceptance', 'make', 'suspicion', 'confidence', 'concession', 'belief', 'subject', 'relevant', 'specified', 'understand', 'uncertainty', 'known', 'characterized', 'denying', 'confident', 'accepted', 'amount', 'religion', 'discussion', 'identified', '-', 'validity', 'doubt', 'assurance', 'pertaining', 'definite', 'affirmation', 'etc', 'structure', 'done', 'habitually', 'statement', 'questioning', 'fact', 'unsure', 'certainty', 'displaying', 'fraught'}
#
# _________________________________________________________
#
#
# {'scoring', 'used', 'indicating', 'chance', 'lack', 'something', 'counting', 'self-confidence', 'word', 'appearance', 'unit', 'game', 'identify', 'confidence', 'lacking', 'unsettled', 'sound', 'contest', 'describe', 'phonological', 'doubt', 'assurance', 'orthographic', 'dependent'}
#
# _________________________________________________________
#
#
# {'producing', 'happens', 'provide', 'especially', 'state', 'continues', 'time', 'intensity', 'two', 'gas', 'use', 'effect', 'efficient', 'clock', 'active', 'known', 'sound', 'achieve', 'deep', 'action', 'cause', 'object', 'condition', 'capable', 'Spirit', 'fist', 'terminates', 'reading', 'guide', 'life', 'expelling', 'depicted', 'breathing', 'result', 'process', 'expel', 'end', 'region', 'recognizable', 'intended', 'ground', 'sacramental', 'exhaled', 'light', 'easily', 'steam', 'position', 'obtained', 'breath', 'open', 'thing', 'feature', 'outcome', 'stroke', 'sustain', 'spring', 'force', 'bodily', 'Holy', 'accompanies', 'labored', 'function', 'created', 'weapon', 'necessary', 'intake', 'done', 'engine', 'respect', 'person', 'property', 'symbolize', 'place', 'breathe', 'puff', 'something', 'language', 'certain', 'act', 'point', 'short', 'inhaling', 'blow', 'exertion', 'event', 'drawing', 'planned', 'unit', 'powerful', 'surface', 'quality', 'achieved', 'draw', 'gust', 'lung', 'specified', 'taking', 'plan', 'like', 'located', 'influence', 'device', 'begin', 'period', 'intensify', 'affair', 'sighing', 'onto', 'irritation', 'extent', 'noise', 'anxiety', 'course', 'skill', 'activity', 'attribute', 'origin', 'behavior', 'scale', 'mouth', 'conduct', 'manner', 'generative', 'proper', 'made', 'anticipated', 'positionable', 'space', 'ritual', 'amount', 'physical', 'pas', 'air', 'annoyance', 'given', 'requires', 'heighten', 'lose'}
#
# _________________________________________________________
#
#
# {'happens', 'especially', 'state', 'word', 'logical', 'computer', 'considered', 'time', 'comprehensible', 'describing', 'benefice', 'expression', 'line', 'make', 'relevant', 'achieve', 'action', 'access', 'object', 'condition', 'terminates', 'fast', 'guide', 'instruction', 'depicted', 'large', 'good', 'expel', 'used', 'recognizable', 'intended', 'region', 'delivering', 'accomplish', 'standardized', 'execution', 'consequence', 'operation', 'one', 'thing', 'feature', 'outcome', 'form', 'move', 'boxlike', 'another', 'represents', 'accompanies', 'hold', 'set', 'metal', 'science', 'distributing', 'done', 'structure', 'transfer', 'respect', 'person', 'specify', 'something', 'single', 'act', 'point', 'event', 'planned', 'surface', 'achieved', 'matter', 'draw', 'lung', 'plan', 'transport', 'located', 'discussion', 'influence', 'sufficient', 'period', 'give', 'affair', 'statement', 'money', 'travel', 'established', '.', 'circumstance', 'conversation', 'activity', 'origin', 'behavior', 'control', 'manner', 'arising', 'repeated', 'resource', 'anticipated', 'subject', 'achievement', 'dimension', 'receives', 'mail', 'loaded', 'air', 'etc', 'medium'}
#
# _________________________________________________________
#
#
# {'good', 'specific', 'intended', 'distance', 'delivering', 'involves', 'something', 'state', 'course', 'act', 'continues', 'point', 'position', 'characteristic', 'time', 'travelled', 'conversation', 'two', 'event', 'unit', 'origin', 'behavior', 'enterprise', 'conduct', 'achieved', 'matter', 'subject', 'space', 'natural', 'achieve', 'plan', 'function', 'mail', 'per', 'part', 'created', 'object', 'discussion', 'distributing', 'material', 'period', 'terminates', 'change', 'structure', 'affair', 'moving', 'commercial', 'location', 'specify', 'property'}

# %%
def new_evaluate_performance(lista_annotati, lista_result):
    
    lunghezza = len(lista_annotati) + len(lista_result)
    uguali = 0
    
    for i in lista_annotati:
        for j in lista_result:
            if i == j:
                uguali += 1
                #print(f'uguali:{uguali}')    
    
    result = round((2*uguali/lunghezza)*100,2)


    print("Precisione: " + str(result) + "%")

# %%
print(new_evaluate_performance(Certainty_bow, new_Certainty_bow))
print(new_evaluate_performance(Firing_point_bow, new_Firing_point_bow))
print(new_evaluate_performance(Breathing_bow, new_Breathing_bow))
print(new_evaluate_performance(Delivery_bow, new_Delivery_bow))
print(new_evaluate_performance(Motion_scenario_bow, new_Motion_scenario_bow))
# Out:
# Precisione: 64.47%
# None
# Precisione: 37.74%
# None
# Precisione: 41.48%
# None
# Precisione: 63.59%
# None
# Precisione: 43.01%
# None
